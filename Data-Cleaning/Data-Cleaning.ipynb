# %%
#Packages for NLP
import nltk
from nltk.corpus import gutenberg, stopwords
from nltk.collocations import *
from nltk import FreqDist
from nltk import word_tokenize
import string
import pandas as pd
import swifter
import pickle
import re
import matplotlib.pyplot as plt

# %%
#Define stopwords
stopwords_list = stopwords.words('english')
stopwords_list += list(string.punctuation)

# %%
stopwords_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
#Create a function to remove verse and chorus inside brackets
#remove \n and lower all texts
def remove_verse_count(song):
    pattern = '\[.*?\]'
    p = re.compile(pattern)
    return p.sub("",song.replace('\n', ' ').lower())

# %%
#Load in a Dataframe all lyrics and artist names
tracks_df = pd.read_pickle('../Data-Cleaning/tracks_df.pkl')
tracks_df.shape
# Out:
# (55010, 5)

# %%
#Check my lurics
tracks_df.Lyrics[4]
# Out:
# "[Verse 1]\nThe harsh realities of life have taken toll\nEven Jesus Christ forsake my soul\nPlease tell me what price to pay to make it whole\nTake control, I'm makin' dough but not enough to blow\nJO's, they lust my flows, but ayo, I don't trust a soul\nThat's all I know or need to, these evil streets'll meet you\nHalfway and eat you alive tryin' to survive illegal\nI'll leave you lost, mount you on a cross\nWhip you like a horse, sacrifice your life to a higher force\nThen I'll stomp your corpse\nIt's the Bronx of course, recognize the accent\nOne of the last livin' still-in-action general assassins\nCatchin' any wreck, blastin' any TEC, smashin' any chest\nPassin' any test; Charles Manson in the flesh\nAny last requests before you meet your maker?\nSow what you reap or wake up\nShakin' up a storm, like Anita Baker\nI'll take you straight to Hell and fill your heart with hate\nIncarcerate your fate in Satan's fiery lake, then I lock the gate\nMake no mistake, this shit as real as J
# ...

# %%
#Droping rows without lyrics
tracks_df.dropna(subset = ['Lyrics'],inplace = True)

# %%
len(tracks_df)
# Out:
# 55007

# %%
#cleaning my lyrics
tracks_df['Cleaned_lyrics']= tracks_df.Lyrics.swifter.apply(remove_verse_count)
# Out:
# /Users/fabricemesidor/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...

# %%
tracks_df.head()
# Out:
#                              Artist  \
# 0                       Frank Ocean
# 1  DJ Jazzy Jeff & The Fresh Prince
# 2                            Eminem
# 3                 Machine Gun Kelly
# 4                           Big Pun
#
#                                                Title  \
# 0                                            Trouble
# 1                                      Time to Chill
# 2  Walk On Water/Stan/Love The Way You Lie (SNL M...
# 3                                              Candy
# 4                                 You Ain’t a Killer
#
#                          Album        Year  \
# 0                         None  2012-01-01
# 1  He’s The DJ, I’m The Rapper  1988-03-29
# 2                         None  2017-11-18
# 3                 Hotel Diablo  2019-07-05
# 4           Capital Punishment  1998-04-28
#
#                                               Lyrics  \
# 0  Go, go, go\n\n[Verse 1]\nForbidden from the be...
# ...

# %%
tracks_df['Lyric_words']= tracks_df.Cleaned_lyrics.apply(lambda x: word_tokenize(x))

# %%
tracks_df.head()
# Out:
#                              Artist  \
# 0                       Frank Ocean
# 1  DJ Jazzy Jeff & The Fresh Prince
# 2                            Eminem
# 3                 Machine Gun Kelly
# 4                           Big Pun
#
#                                                Title  \
# 0                                            Trouble
# 1                                      Time to Chill
# 2  Walk On Water/Stan/Love The Way You Lie (SNL M...
# 3                                              Candy
# 4                                 You Ain’t a Killer
#
#                          Album        Year  \
# 0                         None  2012-01-01
# 1  He’s The DJ, I’m The Rapper  1988-03-29
# 2                         None  2017-11-18
# 3                 Hotel Diablo  2019-07-05
# 4           Capital Punishment  1998-04-28
#
#                                               Lyrics  \
# 0  Go, go, go\n\n[Verse 1]\nForbidden from the be...
# ...

# %%
word_tokenize(tracks_df.Cleaned_lyrics[1])
# Out:
# ['for',
#  'years',
#  'i',
#  'have',
#  'been',
#  'waitin',
#  'and',
#  'hesitatin',
#  'to',
#  'make',
#  'a',
#  'rap',
#  'record',
#  ',',
#  'that',
#  'had',
#  'the',
#  'pace',
#  'of',
#  'a',
#  'slow',
#  'song',
#  ',',
#  'quiet',
#  'storm',
#  ',',
#  'chillin',
#  'while',
#  'the',
#  'fire',
#  'is',
#  'warm',
#  'you',
#  'and',
#  'your',
#  'girl',
#  ',',
#  'with',
#  'this',
#  'record',
#  'on',
#  'your',
#  'radio',
#  'or',
#  'stereo',
#  ',',
#  'i',
#  'do',
#  "n't",
#  'know',
#  'i',
#  'love',
#  'you',
#  'so',
#  'is',
#  'what',
#  'you',
#  "'ll",
#  'be',
#  'sayin',
#  ',',
#  'while',
#  'this',
#  'record',
#  "'s",
#  'playin',
#  'you',
#  'reminscin',
#  'and',
#  'kissin',
#  'your',
#  'girl',
#  'relax',
#  ',',
#  'lay',
#  'back',
#  ',',
#  'unwind',
#  ',',
#  'because',
#  'now',
#  'it',
#  "'s",
#  'time',
#  'to',
#  'chill',
#  'setting',
#  'the',
#  'mood',
#  ',',
#  'by',
#  'the',
#  'use',
#  'of',
#  'this',
# ...
