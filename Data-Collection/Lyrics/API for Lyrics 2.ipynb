# %% [markdown]
# #### Helpers

# %%
import lyricsgenius as genius
from tqdm import tqdm
import time
import credentials as cd

# %%
#Authentification
api = genius.Genius(client_access_token=cd.access_token)

# %% [markdown]
# ### Functions

# %%
#building a search function to find a defined number of songs for an artist
def search_song(artist,number_song):
        results= api.search_artist(artist, max_songs=number_song)
        return results

# %%
#Function to find songs titles
def find_song_title(results):
    return [results.songs]

# %%
#Function to find songs lyrics
def save_lyrics(artist,number_song):
    return search_song(artist,number_song).save_lyrics()

# %% [markdown]
# ### Getting songs from the artists list

# %%
# Load file with all artists
import pickle

with open('../hip-hop-artist-ranker.pkl', 'rb') as f:
    artists_list = pickle.load(f)

# %%
#Checking correct list was imported
len(artists_list)
# Out:
# 814

# %%
#Saving lyrics for 50 artists
for x in tqdm(range(265,275)):
    time.sleep(0.5)
    print('-'*10+'Getting the # '+ str(x+1)+' artist'+'-'*10)
    save_lyrics(artists_list[x],500)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ----------Getting the # 266 artist----------
# Searching for songs by Doug E. Fresh...
#
# Changing artist name to 'Doug E. Fresh & The Get Fresh Crew'
# Song 1: "La Di Da Di"
# Song 2: "The Show"
# Song 3: "Keep Risin’ to the Top"
# Song 4: "Play This Only at Night"
# Song 5: "All the Way to Heaven"
# Song 6: "Cut That Zero"
# Song 7: "I’m Gettin’ Ready"
# Song 8: "The Plane (So High)"
# Song 9: "Abortion"
# Song 10: "Guess Who?"
# Song 11: "Nuthin’"
# Song 12: "Crazy ’Bout Cars"
# Song 13: "Africa (Goin’ Back Home)"
# Song 14: "The Greatest Entertainer"
# Song 15: "Lovin’ Every Minute Of It (The Cyclone Ride)"
# Song 16: "She Was The Type Of A Girl"
# Song 17: "On the Strength"
# Song 18: "Leave It Up To The Cut Professor"
# Song 19: "D.E.F. = Doug E. Fresh"
# Song 20: "Chill Will Cuttin’ It Up"
# Song 21: "Every Body Got to Get Some"
#  10%|█         | 1/10 [00:50<07:36, 50.70s/it]
# Song 22: "Ev’ry Body Loves a Star"
# Done. Found 22 songs.
# Wrote La Di Da Di to lyrics_douge.freshthegetfreshcrew_ladidadi.json.
# Wrote The Show to lyrics_douge.freshthegetfreshcrew_theshow.json.
# Wrote Keep Risin’ to the Top to lyrics_douge.freshthegetfreshcrew_keeprisintothetop.json.
# Wrote Play This Only at Night to lyrics_douge.freshthegetfreshcrew_playthisonlyatnight.json.
# Wrote All the Way to Heaven to lyrics_douge.freshthegetfreshcrew_allthewaytoheaven.json.
# Wrote Cut That Zero to lyrics_douge.freshthegetfreshcrew_cutthatzero.json.
# Wrote I’m Gettin’ Ready to lyrics_douge.freshthegetfreshcrew_imgettinready.json.
# Wrote The Plane (So High) to lyrics_douge.freshthegetfreshcrew_theplanesohigh.json.
# Wrote Abortion to lyrics_douge.freshthegetfreshcrew_abortion.json.
# Wrote Guess Who? to lyrics_douge.freshthegetfreshcrew_guesswho.json.
# Wrote Nuthin’ to lyrics_douge.freshthegetfreshcrew_nuthin.json.
# Wrote Crazy ’Bout Cars to lyrics_douge.freshthegetfreshcrew_crazyboutcars.json.
# Wrote Africa (Goin’ Back Home) to lyrics_douge.freshthegetfreshcrew_africagoinbackhome.json.
# Wrote The Greatest Entertainer to lyrics_douge.freshthegetfreshcrew_thegreatestentertainer.json.
# Wrote Lovin’ Every Minute Of It (The Cyclone Ride) to lyrics_douge.freshthegetfreshcrew_lovineveryminuteofitthecycloneride.json.
# Wrote She Was The Type Of A Girl to lyrics_douge.freshthegetfreshcrew_shewasthetypeofagirl.json.
# Wrote On the Strength to lyrics_douge.freshthegetfreshcrew_onthestrength.json.
# Wrote Leave It Up To The Cut Professor to lyrics_douge.freshthegetfreshcrew_leaveituptothecutprofessor.json.
# Wrote D.E.F. = Doug E. Fresh to lyrics_douge.freshthegetfreshcrew_d.e.f.douge.fresh.json.
# Wrote Chill Will Cuttin’ It Up to lyrics_douge.freshthegetfreshcrew_chillwillcuttinitup.json.
# Wrote Every Body Got to Get Some to lyrics_douge.freshthegetfreshcrew_everybodygottogetsome.json.
# Wrote Ev’ry Body Loves a Star to lyrics_douge.freshthegetfreshcrew_evrybodylovesastar.json.
# ----------Getting the # 267 artist----------
# Searching for songs by Offset...
#
# Song 1: "Clout"
# Song 2: "Red Room"
# Song 3: "Legacy"
# Song 4: "Father of 4"
# Song 5: "How Did I Get Here"
# Song 6: "Monday"
# Song 7: "Don’t Lose Me"
# Song 8: "Lick"
# Song 9: "Wild Wild West"
# Song 10: "Quarter Milli"
# Song 11: "North Star"
# "Interview" is not valid. Skipping.
# Song 12: "On Fleek"
# Song 13: "Made Men"
# Song 14: "Tats on My Face"
# Song 15: "Came a Long Way"
# Song 16: "Truck Loads"
# Song 17: "After Dark"
# Song 18: "First Day Out"
# Song 19: "Str8 Drop"
# Song 20: "Underrated"
# Song 21: "Cinco De Mayo"
# Song 22: "Pink Toes (Demo)"
# Song 23: "Sleep Walking"
# Song 24: "One Shot Two Shot"
# Song 25: "Work"
# "Streets on Lock 5 [Tracklist + Cover Art]" is not valid. Skipping.
# Song 26: "Hot Spot"
# Song 27: "Wanna Be Me"
# Song 28: "Too Easy"
# Song 29: "100 Bricks"
# Song 30: "Stay Up"
# Song 31: "In Her Throat"
# Song 32: "My Choices"
# Song 33: "Ball Player"
# Song 34: "Uon Want Problems"
# Song 35: "Power Moves - 2452531"
# Song 36: "1st Day Out"
# Song 37: "Drip (OG Version)"
# Song 38: "Diplomat"
# Song 39: "Oprah Winfrey"
# Song 40: "Big Bank Take Lil Bank"
# Song 41: "Need Some More"
# Song 42: "Run Up My Money"
# Song 43: "Man Down"
# Song 44: "She gon’ drown in all this water(snippet)"
# Song 45: "Too Deep"
# Song 46: "Capital One"
# Song 47: "Never been a lame"
# Song 48: "Glitch"
# Song 49: "Chanel"
# Song 50: "Auto"
# Song 51: "Runnin Up Da Money"
# Song 52: "Solitaire*"
# Song 53: "Different Shit"
# Song 54: "Bad*"
#  20%|██        | 2/10 [19:34<49:40, 372.55s/it]
# Done. Found 54 songs.
# Wrote Clout to lyrics_offset_clout.json.
# Wrote Red Room to lyrics_offset_redroom.json.
# Wrote Legacy to lyrics_offset_legacy.json.
# Wrote Father of 4 to lyrics_offset_fatherof4.json.
# Wrote How Did I Get Here to lyrics_offset_howdidigethere.json.
# Wrote Monday to lyrics_offset_monday.json.
# Wrote Don’t Lose Me to lyrics_offset_dontloseme.json.
# Wrote Lick to lyrics_offset_lick.json.
# Wrote Wild Wild West to lyrics_offset_wildwildwest.json.
# Wrote Quarter Milli to lyrics_offset_quartermilli.json.
# Wrote North Star to lyrics_offset_northstar.json.
# Wrote On Fleek to lyrics_offset_onfleek.json.
# Wrote Made Men to lyrics_offset_mademen.json.
# Wrote Tats on My Face to lyrics_offset_tatsonmyface.json.
# Wrote Came a Long Way to lyrics_offset_camealongway.json.
# Wrote Truck Loads to lyrics_offset_truckloads.json.
# Wrote After Dark to lyrics_offset_afterdark.json.
# Wrote First Day Out to lyrics_offset_firstdayout.json.
# Wrote Str8 Drop to lyrics_offset_str8drop.json.
# Wrote Underrated to lyrics_offset_underrated.json.
# Wrote Cinco De Mayo to lyrics_offset_cincodemayo.json.
# Wrote Pink Toes (Demo) to lyrics_offset_pinktoesdemo.json.
# Wrote Sleep Walking to lyrics_offset_sleepwalking.json.
# Wrote One Shot Two Shot to lyrics_offset_oneshottwoshot.json.
# Wrote Work to lyrics_offset_work.json.
# Wrote Hot Spot to lyrics_offset_hotspot.json.
# Wrote Wanna Be Me to lyrics_offset_wannabeme.json.
# Wrote Too Easy to lyrics_offset_tooeasy.json.
# Wrote 100 Bricks to lyrics_offset_100bricks.json.
# Wrote Stay Up to lyrics_offset_stayup.json.
# Wrote In Her Throat to lyrics_offset_inherthroat.json.
# Wrote My Choices to lyrics_offset_mychoices.json.
# Wrote Ball Player to lyrics_offset_ballplayer.json.
# Wrote Uon Want Problems to lyrics_offset_uonwantproblems.json.
# Wrote Power Moves - 2452531 to lyrics_offset_powermoves2452531.json.
# Wrote 1st Day Out to lyrics_offset_1stdayout.json.
# Wrote Drip (OG Version) to lyrics_offset_dripogversion.json.
# Wrote Diplomat to lyrics_offset_diplomat.json.
# Wrote Oprah Winfrey to lyrics_offset_oprahwinfrey.json.
# Wrote Big Bank Take Lil Bank to lyrics_offset_bigbanktakelilbank.json.
# Wrote Need Some More to lyrics_offset_needsomemore.json.
# Wrote Run Up My Money to lyrics_offset_runupmymoney.json.
# Wrote Man Down to lyrics_offset_mandown.json.
# Wrote She gon’ drown in all this water(snippet) to lyrics_offset_shegondrowninallthiswatersnippet.json.
# Wrote Too Deep to lyrics_offset_toodeep.json.
# Wrote Capital One to lyrics_offset_capitalone.json.
# Wrote Never been a lame to lyrics_offset_neverbeenalame.json.
# Wrote Glitch to lyrics_offset_glitch.json.
# Wrote Chanel to lyrics_offset_chanel.json.
# Wrote Auto to lyrics_offset_auto.json.
# Wrote Runnin Up Da Money to lyrics_offset_runninupdamoney.json.
# Wrote Solitaire* to lyrics_offset_solitaire.json.
# Wrote Different Shit to lyrics_offset_differentshit.json.
# Wrote Bad* to lyrics_offset_bad.json.
# ----------Getting the # 268 artist----------
# Searching for songs by Goody Mob...
#
# Changing artist name to 'Good Morning'
# Song 1: "Warned You"
# Song 2: "You"
# Song 3: "Don’t Come Home Today"
# Song 4: "Once You Know"
# Song 5: "Wednesday"
# Song 6: "On the Street"
# Song 7: "Oppsie"
# Song 8: "Radiovoice"
# Song 9: "To Be Won"
# Song 10: "Escalator"
# Song 11: "Cab Deg"
# Song 12: "Time To Try Again"
# Song 13: "Before My Ears Explode"
# Song 14: "Boy, I’m Just A Loser For Your Love"
# Song 15: "$10"
# Song 16: "Step Aside"
# Song 17: "Cosmic Sass"
# Song 18: "After You"
# Song 19: "Give Me Something To Do"
# Song 20: "Just a Man"
# Song 21: "The Great Start"
# Song 22: "Who’s To Blame"
# Song 23: "In The Way"
# Song 24: "Blue Tick"
# Song 25: "For a Little While"
# Song 26: "You Up?"
# Song 27: "Overslept"
# Song 28: "Credentials (Lester & Eliza)"
# Song 29: "Whine Time"
# Song 30: "Look Around"
# Song 31: "Mirror Freak"
# Song 32: "Still Commit Crimes"
# Song 33: "Plant Matta"
# Song 34: "Sub"
# Song 35: "People Say"
# Song 36: "Take It Easy For Me, Stranger"
# Song 37: "Garden"
# Song 38: "I’ll Kill U (Dreams Are Horrorshows)"
# Song 39: "You Said That To Me Tuesday"
# Song 40: "A Vessel"
# Song 41: "You Can’t Think About It Always"
# Song 42: "Classic Quip"
# Song 43: "Best Supporting Actor"
# Song 44: "Pat"
# Song 45: "But We’re Not There Yet"
# Song 46: "War On Me"
#  30%|███       | 3/10 [21:02<33:31, 287.40s/it]
# Song 47: "Run"
# Done. Found 47 songs.
# Wrote Warned You to lyrics_goodmorning_warnedyou.json.
# Wrote You to lyrics_goodmorning_you.json.
# Wrote Don’t Come Home Today to lyrics_goodmorning_dontcomehometoday.json.
# Wrote Once You Know to lyrics_goodmorning_onceyouknow.json.
# Wrote Wednesday to lyrics_goodmorning_wednesday.json.
# Wrote On the Street to lyrics_goodmorning_onthestreet.json.
# Wrote Oppsie to lyrics_goodmorning_oppsie.json.
# Wrote Radiovoice to lyrics_goodmorning_radiovoice.json.
# Wrote To Be Won to lyrics_goodmorning_tobewon.json.
# Wrote Escalator to lyrics_goodmorning_escalator.json.
# Wrote Cab Deg to lyrics_goodmorning_cabdeg.json.
# Wrote Time To Try Again to lyrics_goodmorning_timetotryagain.json.
# Wrote Before My Ears Explode to lyrics_goodmorning_beforemyearsexplode.json.
# Wrote Boy, I’m Just A Loser For Your Love to lyrics_goodmorning_boyimjustaloserforyourlove.json.
# Wrote $10 to lyrics_goodmorning_10.json.
# Wrote Step Aside to lyrics_goodmorning_stepaside.json.
# Wrote Cosmic Sass to lyrics_goodmorning_cosmicsass.json.
# Wrote After You to lyrics_goodmorning_afteryou.json.
# Wrote Give Me Something To Do to lyrics_goodmorning_givemesomethingtodo.json.
# Wrote Just a Man to lyrics_goodmorning_justaman.json.
# Wrote The Great Start to lyrics_goodmorning_thegreatstart.json.
# Wrote Who’s To Blame to lyrics_goodmorning_whostoblame.json.
# Wrote In The Way to lyrics_goodmorning_intheway.json.
# Wrote Blue Tick to lyrics_goodmorning_bluetick.json.
# Wrote For a Little While to lyrics_goodmorning_foralittlewhile.json.
# Wrote You Up? to lyrics_goodmorning_youup.json.
# Wrote Overslept to lyrics_goodmorning_overslept.json.
# Wrote Credentials (Lester & Eliza) to lyrics_goodmorning_credentialslestereliza.json.
# Wrote Whine Time to lyrics_goodmorning_whinetime.json.
# Wrote Look Around to lyrics_goodmorning_lookaround.json.
# Wrote Mirror Freak to lyrics_goodmorning_mirrorfreak.json.
# Wrote Still Commit Crimes to lyrics_goodmorning_stillcommitcrimes.json.
# Wrote Plant Matta to lyrics_goodmorning_plantmatta.json.
# Wrote Sub to lyrics_goodmorning_sub.json.
# Wrote People Say to lyrics_goodmorning_peoplesay.json.
# Wrote Take It Easy For Me, Stranger to lyrics_goodmorning_takeiteasyformestranger.json.
# Wrote Garden to lyrics_goodmorning_garden.json.
# Wrote I’ll Kill U (Dreams Are Horrorshows) to lyrics_goodmorning_illkilludreamsarehorrorshows.json.
# Wrote You Said That To Me Tuesday to lyrics_goodmorning_yousaidthattometuesday.json.
# Wrote A Vessel to lyrics_goodmorning_avessel.json.
# Wrote You Can’t Think About It Always to lyrics_goodmorning_youcantthinkaboutitalways.json.
# Wrote Classic Quip to lyrics_goodmorning_classicquip.json.
# Wrote Best Supporting Actor to lyrics_goodmorning_bestsupportingactor.json.
# Wrote Pat to lyrics_goodmorning_pat.json.
# Wrote But We’re Not There Yet to lyrics_goodmorning_butwerenotthereyet.json.
# Wrote War On Me to lyrics_goodmorning_waronme.json.
# Wrote Run to lyrics_goodmorning_run.json.
# ----------Getting the # 269 artist----------
# Searching for songs by N.O.R.E....
#
# Song 1: "Banned From TV"
# Song 2: "Oye Mi Canto"
# Song 3: "Superthug"
# Song 4: "Tadow"
# Song 5: "Nothin’"
# Song 6: "Sometimes"
# Song 7: "Uno Más"
# Song 8: "Finito"
# Song 9: "Scared Money"
# Song 10: "N.O.R.E."
# Song 11: "Lehhhgooo"
# Song 12: "She Tried"
# Song 13: "Come Thru"
# Song 14: "Body in the Trunk"
# Song 15: "The Change (Freestyle Cypher)"
# Song 16: "Built Pyramids"
# Song 17: "Google That"
# Song 18: "She Tried (Remix)"
# Song 19: "I Love My Life"
# Song 20: "Blood Money Pt. 3"
# Song 21: "Don’t Know"
# Song 22: "Esta Loca (Mathematics)"
# Song 23: "Bloody Money Pt. 2"
# Song 24: "Mas Maiz"
# Song 25: "Grimey"
# Song 26: "Dreaming"
# Song 27: "Play That Shit (We Don’t Play That)"
# Song 28: "Baby Girl"
# Song 29: "Uno Más Remix"
# Song 30: "Hed"
# Song 31: "She’s Mine"
# Song 32: "Oh No"
# Song 33: "Real or Fake Niggas"
# Song 34: "Nothin’ (Remix)"
# Song 35: "The Problem (Lawwwddd)"
# Song 36: "Fake Friends"
# Song 37: "What the Fuck is Up?"
# Song 38: "Sour Diesel"
# Song 39: "Big Chain"
# Song 40: "Moments"
# Song 41: "It’s Not a Game"
# Song 42: "Oh No (Remix)"
# Song 43: "Put ’Em Up"
# Song 44: "All Alone"
# Song 45: "The Assignment"
# Song 46: "Fiesta"
# Song 47: "The Change"
# Song 48: "40 Island"
# Song 49: "The Way We Live"
# Song 50: "LaLa"
# Song 51: "Oye Mi Canto (Remix)"
# Song 52: "I Wanna Fuck You"
# Song 53: "Da Story"
# Song 54: "N.O.R.E. y La Familia - Ya Tu Sabe"
# Song 55: "Buckets"
# Song 56: "Bendicion"
# Song 57: "Thiz Iz Hip Hop"
# Song 58: "The Life of a... (Gangsta)"
# Song 59: "Big D"
# Song 60: "Cocaine Business (Hysteria)"
# Song 61: "I’m a G"
# Song 62: "My Alias"
# Song 63: "Halfway Thugs Part 2"
# Song 64: "The Jump Off"
# Song 65: "Want Me Dead"
# Song 66: "Jesus Take The Wheel"
# Song 67: "Full Mode"
# Song 68: "My City"
# Song 69: "War Song"
# Song 70: "Get Down (Ooou Ooou)"
# Song 71: "I’ma Get You"
# Song 72: "Gangsta’s Watch"
# Song 73: "No Reason"
# Song 74: "Live My Life"
# Song 75: "Thug Poetry"
# Song 76: "Going Legit"
# Song 77: "Love Ya Moms"
# Song 78: "Woof"
# Song 79: "Stay Flawless"
# Song 80: "In The Beginning"
# Song 81: "Let Me Be Great"
# Song 82: "Talk 2 Em"
# Song 83: "Faces of Death"
# Song 84: "Student of The Game"
# Song 85: "Hit Me Slime"
# Song 86: "Hold Me Down"
# Song 87: "Mr. CEO"
# Song 88: "Drink Champ"
# Song 89: "Plug Brothers: Moguls"
# Song 90: "Floatin’ in the Sky"
# Song 91: "Head Bussa"
# Song 92: "If You Want It"
# Song 93: "Black Clouds"
# Song 94: "First Day Home"
# Song 95: "Half-Baked"
# Song 96: "Da Hustla"
# Song 97: "Don’t Love No Bitches"
# Song 98: "Petty"
# Song 99: "Eat Pussy"
# Song 100: "Don’t Know What to Do"
# Song 101: "Flagrant Cops"
# Song 102: "God’s Angel"
# Song 103: "Consider This"
# "God’s Favorite [Credits]" is not valid. Skipping.
# Song 104: "Nahmeanuheard"
# Song 105: "Wanna Be Like Him"
# Song 106: "Nahmeanuheard (Remix)"
# Song 107: "Parade"
# Song 108: "Nothing"
# Song 109: "Rap Rushmore"
# Song 110: "Vente Mami"
# Song 111: "Banned From Another Club"
# Song 112: "Thirsty"
# Song 113: "Set It Off (Remix)"
# Song 114: "Camouflage Unicorns"
# Song 115: "Hablar de amor"
# Song 116: "God’s Favorite"
# Song 117: "Oye Mi Canto (radio Edit)"
# Song 118: "Wethuggedout"
# Song 119: "Play That Shit"
# Song 120: "Mathematics (Esta Loca)"
# Song 121: "Blood Money Part 3"
# Song 122: "Now I Pray"
# Song 123: "Set It Off"
# Song 124: "Queens"
# Song 125: "The Life of a...(Gangsta) Capone"
# Song 126: "Animal Thug (Interlude)"
# Song 127: "Lion"
# Song 128: "Hed (interlude)"
# Song 129: "Badman"
# Song 130: "Like The Way"
# Song 131: "Throw ’Em Under the Bus"
# Song 132: "That’s a GoodBelt"
# Song 133: "Hare Krishna"
# Song 134: "Hot 97 Freestyle"
# Song 135: "Fuck U Freestyle"
# Song 136: "What I Had To Do"
# Song 137: "Mazel Tov"
# Song 138: "Vitamins"
# Song 139: "Electrolytes (Remix)"
# Song 140: "Holla Back Slime"
# "Oye Mi Canto [Instrumental]" is not valid. Skipping.
# "The Pigeon (Skit)" is not valid. Skipping.
# Song 141: "Diablo B"
# Song 142: "Outta My Mind"
# Song 143: "Only Bad Ones"
# "Animal Thug Goes Hollywood (Skit)" is not valid. Skipping.
# Song 144: "Fowl Niggaz"
# Song 145: "Medical Theory (Get High)"
# Song 146: "Cheatin’"
# Song 147: "#Facts"
# Song 148: "Slime Season"
# Song 149: "One Love"
# Song 150: "Issues"
# Song 151: "Still Getting It"
# Song 152: "Powder Water"
# Song 153: "Cowboys and Indians"
# Song 154: "Nothin’ - Album Version (Edited)"
# "Killa - Tracklist + Cover" is not valid. Skipping.
# Song 155: "Police Rush the Spot"
# Song 156: "What the Fuck Is Up? (feat. Scarlet O’Harlem)"
# Song 157: "Wethuggedout (feat. Missy Elliott)"
# Song 158: "Stand Tall"
# Song 159: "Scared Money (Remix)"
# Song 160: "Hospital / Funeral Intro"
# Song 161: "Dimelo"
# Song 162: "Oh no - explict"
# Song 163: "Outro"
# Song 164: "If U Want It"
# Song 165: "We Don’t"
# Song 166: "Freestyle (DJ Green Lantern)"
# Song 167: "Da Hustla (feat. Musalini & Maze)"
# Song 168: "Hold Me Down (feat. Final Chapter & Troy Outlaw)"
# Song 169: "Real or Fake Niggas (feat. Final Chapter)"
# Song 170: "Going Legit (feat. Musalini)"
# "Da Tunnel (Skit)" is not valid. Skipping.
# Song 171: "I’ma Smack This Muthafucka"
# "Food Stamps Skit" is not valid. Skipping.
# Song 172: "Amber Rose Speaks"
# "Hustle Skit" is not valid. Skipping.
# Song 173: "Blam"
# Song 174: "Shoulders Move"
# "Pharrell Podcast Skit" is not valid. Skipping.
# Song 175: "We Don’t Give A Fuck"
#  40%|████      | 4/10 [33:34<42:39, 426.57s/it]
# Done. Found 175 songs.
# Wrote Banned From TV to lyrics_n.o.r.e._bannedfromtv.json.
# Wrote Oye Mi Canto to lyrics_n.o.r.e._oyemicanto.json.
# Wrote Superthug to lyrics_n.o.r.e._superthug.json.
# Wrote Tadow to lyrics_n.o.r.e._tadow.json.
# Wrote Nothin’ to lyrics_n.o.r.e._nothin.json.
# Wrote Sometimes to lyrics_n.o.r.e._sometimes.json.
# Wrote Uno Más to lyrics_n.o.r.e._unomás.json.
# Wrote Finito to lyrics_n.o.r.e._finito.json.
# Wrote Scared Money to lyrics_n.o.r.e._scaredmoney.json.
# Wrote N.O.R.E. to lyrics_n.o.r.e._n.o.r.e..json.
# Wrote Lehhhgooo to lyrics_n.o.r.e._lehhhgooo.json.
# Wrote She Tried to lyrics_n.o.r.e._shetried.json.
# Wrote Come Thru to lyrics_n.o.r.e._comethru.json.
# Wrote Body in the Trunk to lyrics_n.o.r.e._bodyinthetrunk.json.
# Wrote The Change (Freestyle Cypher) to lyrics_n.o.r.e._thechangefreestylecypher.json.
# Wrote Built Pyramids to lyrics_n.o.r.e._builtpyramids.json.
# Wrote Google That to lyrics_n.o.r.e._googlethat.json.
# Wrote She Tried (Remix) to lyrics_n.o.r.e._shetriedremix.json.
# Wrote I Love My Life to lyrics_n.o.r.e._ilovemylife.json.
# Wrote Blood Money Pt. 3 to lyrics_n.o.r.e._bloodmoneypt.3.json.
# Wrote Don’t Know to lyrics_n.o.r.e._dontknow.json.
# Wrote Esta Loca (Mathematics) to lyrics_n.o.r.e._estalocamathematics.json.
# Wrote Bloody Money Pt. 2 to lyrics_n.o.r.e._bloodymoneypt.2.json.
# Wrote Mas Maiz to lyrics_n.o.r.e._masmaiz.json.
# Wrote Grimey to lyrics_n.o.r.e._grimey.json.
# Wrote Dreaming to lyrics_n.o.r.e._dreaming.json.
# Wrote Play That Shit (We Don’t Play That) to lyrics_n.o.r.e._playthatshitwedontplaythat.json.
# Wrote Baby Girl to lyrics_n.o.r.e._babygirl.json.
# Wrote Uno Más Remix to lyrics_n.o.r.e._unomásremix.json.
# Wrote Hed to lyrics_n.o.r.e._hed.json.
# Wrote She’s Mine to lyrics_n.o.r.e._shesmine.json.
# Wrote Oh No to lyrics_n.o.r.e._ohno.json.
# Wrote Real or Fake Niggas to lyrics_n.o.r.e._realorfakeniggas.json.
# Wrote Nothin’ (Remix) to lyrics_n.o.r.e._nothinremix.json.
# Wrote The Problem (Lawwwddd) to lyrics_n.o.r.e._theproblemlawwwddd.json.
# Wrote Fake Friends to lyrics_n.o.r.e._fakefriends.json.
# Wrote What the Fuck is Up? to lyrics_n.o.r.e._whatthefuckisup.json.
# Wrote Sour Diesel to lyrics_n.o.r.e._sourdiesel.json.
# Wrote Big Chain to lyrics_n.o.r.e._bigchain.json.
# Wrote Moments to lyrics_n.o.r.e._moments.json.
# Wrote It’s Not a Game to lyrics_n.o.r.e._itsnotagame.json.
# Wrote Oh No (Remix) to lyrics_n.o.r.e._ohnoremix.json.
# Wrote Put ’Em Up to lyrics_n.o.r.e._putemup.json.
# Wrote All Alone to lyrics_n.o.r.e._allalone.json.
# Wrote The Assignment to lyrics_n.o.r.e._theassignment.json.
# Wrote Fiesta to lyrics_n.o.r.e._fiesta.json.
# Wrote The Change to lyrics_n.o.r.e._thechange.json.
# Wrote 40 Island to lyrics_n.o.r.e._40island.json.
# Wrote The Way We Live to lyrics_n.o.r.e._thewaywelive.json.
# Wrote LaLa to lyrics_n.o.r.e._lala.json.
# Wrote Oye Mi Canto (Remix) to lyrics_n.o.r.e._oyemicantoremix.json.
# Wrote I Wanna Fuck You to lyrics_n.o.r.e._iwannafuckyou.json.
# Wrote Da Story to lyrics_n.o.r.e._dastory.json.
# Wrote N.O.R.E. y La Familia - Ya Tu Sabe to lyrics_n.o.r.e._n.o.r.e.ylafamiliayatusabe.json.
# Wrote Buckets to lyrics_n.o.r.e._buckets.json.
# Wrote Bendicion to lyrics_n.o.r.e._bendicion.json.
# Wrote Thiz Iz Hip Hop to lyrics_n.o.r.e._thizizhiphop.json.
# Wrote The Life of a... (Gangsta) to lyrics_n.o.r.e._thelifeofa...gangsta.json.
# Wrote Big D to lyrics_n.o.r.e._bigd.json.
# Wrote Cocaine Business (Hysteria) to lyrics_n.o.r.e._cocainebusinesshysteria.json.
# Wrote I’m a G to lyrics_n.o.r.e._imag.json.
# Wrote My Alias to lyrics_n.o.r.e._myalias.json.
# Wrote Halfway Thugs Part 2 to lyrics_n.o.r.e._halfwaythugspart2.json.
# Wrote The Jump Off to lyrics_n.o.r.e._thejumpoff.json.
# Wrote Want Me Dead to lyrics_n.o.r.e._wantmedead.json.
# Wrote Jesus Take The Wheel to lyrics_n.o.r.e._jesustakethewheel.json.
# Wrote Full Mode to lyrics_n.o.r.e._fullmode.json.
# Wrote My City to lyrics_n.o.r.e._mycity.json.
# Wrote War Song to lyrics_n.o.r.e._warsong.json.
# Wrote Get Down (Ooou Ooou) to lyrics_n.o.r.e._getdownooouooou.json.
# Wrote I’ma Get You to lyrics_n.o.r.e._imagetyou.json.
# Wrote Gangsta’s Watch to lyrics_n.o.r.e._gangstaswatch.json.
# Wrote No Reason to lyrics_n.o.r.e._noreason.json.
# Wrote Live My Life to lyrics_n.o.r.e._livemylife.json.
# Wrote Thug Poetry to lyrics_n.o.r.e._thugpoetry.json.
# Wrote Going Legit to lyrics_n.o.r.e._goinglegit.json.
# Wrote Love Ya Moms to lyrics_n.o.r.e._loveyamoms.json.
# Wrote Woof to lyrics_n.o.r.e._woof.json.
# Wrote Stay Flawless to lyrics_n.o.r.e._stayflawless.json.
# Wrote In The Beginning to lyrics_n.o.r.e._inthebeginning.json.
# Wrote Let Me Be Great to lyrics_n.o.r.e._letmebegreat.json.
# Wrote Talk 2 Em to lyrics_n.o.r.e._talk2em.json.
# Wrote Faces of Death to lyrics_n.o.r.e._facesofdeath.json.
# Wrote Student of The Game to lyrics_n.o.r.e._studentofthegame.json.
# Wrote Hit Me Slime to lyrics_n.o.r.e._hitmeslime.json.
# Wrote Hold Me Down to lyrics_n.o.r.e._holdmedown.json.
# Wrote Mr. CEO to lyrics_n.o.r.e._mr.ceo.json.
# Wrote Drink Champ to lyrics_n.o.r.e._drinkchamp.json.
# Wrote Plug Brothers: Moguls to lyrics_n.o.r.e._plugbrothersmoguls.json.
# Wrote Floatin’ in the Sky to lyrics_n.o.r.e._floatininthesky.json.
# Wrote Head Bussa to lyrics_n.o.r.e._headbussa.json.
# Wrote If You Want It to lyrics_n.o.r.e._ifyouwantit.json.
# Wrote Black Clouds to lyrics_n.o.r.e._blackclouds.json.
# Wrote First Day Home to lyrics_n.o.r.e._firstdayhome.json.
# Wrote Half-Baked to lyrics_n.o.r.e._halfbaked.json.
# Wrote Da Hustla to lyrics_n.o.r.e._dahustla.json.
# Wrote Don’t Love No Bitches to lyrics_n.o.r.e._dontlovenobitches.json.
# Wrote Petty to lyrics_n.o.r.e._petty.json.
# Wrote Eat Pussy to lyrics_n.o.r.e._eatpussy.json.
# Wrote Don’t Know What to Do to lyrics_n.o.r.e._dontknowwhattodo.json.
# Wrote Flagrant Cops to lyrics_n.o.r.e._flagrantcops.json.
# Wrote God’s Angel to lyrics_n.o.r.e._godsangel.json.
# Wrote Consider This to lyrics_n.o.r.e._considerthis.json.
# Wrote Nahmeanuheard to lyrics_n.o.r.e._nahmeanuheard.json.
# Wrote Wanna Be Like Him to lyrics_n.o.r.e._wannabelikehim.json.
# Wrote Nahmeanuheard (Remix) to lyrics_n.o.r.e._nahmeanuheardremix.json.
# Wrote Parade to lyrics_n.o.r.e._parade.json.
# Wrote Nothing to lyrics_n.o.r.e._nothing.json.
# Wrote Rap Rushmore to lyrics_n.o.r.e._raprushmore.json.
# Wrote Vente Mami to lyrics_n.o.r.e._ventemami.json.
# Wrote Banned From Another Club to lyrics_n.o.r.e._bannedfromanotherclub.json.
# Wrote Thirsty to lyrics_n.o.r.e._thirsty.json.
# Wrote Set It Off (Remix) to lyrics_n.o.r.e._setitoffremix.json.
# Wrote Camouflage Unicorns to lyrics_n.o.r.e._camouflageunicorns.json.
# Wrote Hablar de amor to lyrics_n.o.r.e._hablardeamor.json.
# Wrote God’s Favorite to lyrics_n.o.r.e._godsfavorite.json.
# Wrote Oye Mi Canto (radio Edit) to lyrics_n.o.r.e._oyemicantoradioedit.json.
# Wrote Wethuggedout to lyrics_n.o.r.e._wethuggedout.json.
# Wrote Play That Shit to lyrics_n.o.r.e._playthatshit.json.
# Wrote Mathematics (Esta Loca) to lyrics_n.o.r.e._mathematicsestaloca.json.
# Wrote Blood Money Part 3 to lyrics_n.o.r.e._bloodmoneypart3.json.
# Wrote Now I Pray to lyrics_n.o.r.e._nowipray.json.
# Wrote Set It Off to lyrics_n.o.r.e._setitoff.json.
# Wrote Queens to lyrics_n.o.r.e._queens.json.
# Wrote The Life of a...(Gangsta) Capone to lyrics_n.o.r.e._thelifeofa...gangstacapone.json.
# Wrote Animal Thug (Interlude) to lyrics_n.o.r.e._animalthuginterlude.json.
# Wrote Lion to lyrics_n.o.r.e._lion.json.
# Wrote Hed (interlude) to lyrics_n.o.r.e._hedinterlude.json.
# Wrote Badman to lyrics_n.o.r.e._badman.json.
# Wrote Like The Way to lyrics_n.o.r.e._liketheway.json.
# Wrote Throw ’Em Under the Bus to lyrics_n.o.r.e._throwemunderthebus.json.
# Wrote That’s a GoodBelt to lyrics_n.o.r.e._thatsagoodbelt.json.
# Wrote Hare Krishna to lyrics_n.o.r.e._harekrishna.json.
# Wrote Hot 97 Freestyle to lyrics_n.o.r.e._hot97freestyle.json.
# Wrote Fuck U Freestyle to lyrics_n.o.r.e._fuckufreestyle.json.
# Wrote What I Had To Do to lyrics_n.o.r.e._whatihadtodo.json.
# Wrote Mazel Tov to lyrics_n.o.r.e._mazeltov.json.
# Wrote Vitamins to lyrics_n.o.r.e._vitamins.json.
# Wrote Electrolytes (Remix) to lyrics_n.o.r.e._electrolytesremix.json.
# Wrote Holla Back Slime to lyrics_n.o.r.e._hollabackslime.json.
# Wrote Diablo B to lyrics_n.o.r.e._diablob.json.
# Wrote Outta My Mind to lyrics_n.o.r.e._outtamymind.json.
# Wrote Only Bad Ones to lyrics_n.o.r.e._onlybadones.json.
# Wrote Fowl Niggaz to lyrics_n.o.r.e._fowlniggaz.json.
# Wrote Medical Theory (Get High) to lyrics_n.o.r.e._medicaltheorygethigh.json.
# Wrote Cheatin’ to lyrics_n.o.r.e._cheatin.json.
# Wrote #Facts to lyrics_n.o.r.e._facts.json.
# Wrote Slime Season to lyrics_n.o.r.e._slimeseason.json.
# Wrote One Love to lyrics_n.o.r.e._onelove.json.
# Wrote Issues to lyrics_n.o.r.e._issues.json.
# Wrote Still Getting It to lyrics_n.o.r.e._stillgettingit.json.
# Wrote Powder Water to lyrics_n.o.r.e._powderwater.json.
# Wrote Cowboys and Indians to lyrics_n.o.r.e._cowboysandindians.json.
# Wrote Nothin’ - Album Version (Edited) to lyrics_n.o.r.e._nothinalbumversionedited.json.
# Wrote Police Rush the Spot to lyrics_n.o.r.e._policerushthespot.json.
# Wrote What the Fuck Is Up? (feat. Scarlet O’Harlem) to lyrics_n.o.r.e._whatthefuckisupfeat.scarletoharlem.json.
# Wrote Wethuggedout (feat. Missy Elliott) to lyrics_n.o.r.e._wethuggedoutfeat.missyelliott.json.
# Wrote Stand Tall to lyrics_n.o.r.e._standtall.json.
# Wrote Scared Money (Remix) to lyrics_n.o.r.e._scaredmoneyremix.json.
# Wrote Hospital / Funeral Intro to lyrics_n.o.r.e._hospitalfuneralintro.json.
# Wrote Dimelo to lyrics_n.o.r.e._dimelo.json.
# Wrote Oh no - explict to lyrics_n.o.r.e._ohnoexplict.json.
# Wrote Outro to lyrics_n.o.r.e._outro.json.
# Wrote If U Want It to lyrics_n.o.r.e._ifuwantit.json.
# Wrote We Don’t to lyrics_n.o.r.e._wedont.json.
# Wrote Freestyle (DJ Green Lantern) to lyrics_n.o.r.e._freestyledjgreenlantern.json.
# Wrote Da Hustla (feat. Musalini & Maze) to lyrics_n.o.r.e._dahustlafeat.musalinimaze.json.
# Wrote Hold Me Down (feat. Final Chapter & Troy Outlaw) to lyrics_n.o.r.e._holdmedownfeat.finalchaptertroyoutlaw.json.
# Wrote Real or Fake Niggas (feat. Final Chapter) to lyrics_n.o.r.e._realorfakeniggasfeat.finalchapter.json.
# Wrote Going Legit (feat. Musalini) to lyrics_n.o.r.e._goinglegitfeat.musalini.json.
# Wrote I’ma Smack This Muthafucka to lyrics_n.o.r.e._imasmackthismuthafucka.json.
# Wrote Amber Rose Speaks to lyrics_n.o.r.e._amberrosespeaks.json.
# Wrote Blam to lyrics_n.o.r.e._blam.json.
# Wrote Shoulders Move to lyrics_n.o.r.e._shouldersmove.json.
# Wrote We Don’t Give A Fuck to lyrics_n.o.r.e._wedontgiveafuck.json.
# ----------Getting the # 270 artist----------
# Searching for songs by JME...
#
# Changing artist name to 'Jme'
# Song 1: "Man Don’t Care"
# Song 2: "96 Fuckries"
# Song 3: "Integrity"
# Song 4: "96 Bars Of Revenge"
# Song 5: "Don’t @ Me"
# Song 6: "Taking Over? (It Ain’t Working)"
# Song 7: "Test Me"
# Song 8: "Work"
# Song 9: "Serious"
# Song 10: "If You Don’t Know"
# Song 11: "Pulse 8"
# Song 12: "The Very Best"
# Song 13: "Jme"
# Song 14: "Murking"
# Song 15: "Game"
# Song 16: "Calm"
# Song 17: "No You Ain’t"
# Song 18: "Amen"
# Song 19: "Break You Down"
# Song 20: "AWOH"
# Song 21: "The Money"
# Song 22: "Punch In The Face"
# Song 23: "Same Thing"
# Song 24: "Banger"
# Song 25: "Styley"
# Song 26: "P"
# Song 27: "Again"
# Song 28: "96 Bars of Jme"
# Song 29: "Serious (Remix)"
# Song 30: "CD is Dead"
# Song 31: "Don’t Get Rude"
# Song 32: "R U Dumb?"
# Song 33: "Food"
# Song 34: "Blam!"
# Song 35: "Over Me"
# Song 36: "Westwood Freestyle"
# Song 37: "Jme and the Fox"
# Song 38: "Pick Up The Mic"
# Song 39: "123"
# Song 40: "Twitter Freestyle"
# Song 41: "I’m The Best"
# Song 42: "Standard"
# Song 43: "Boy Better Know"
# Song 44: "Juju Riddim"
# Song 45: "Sidetracked"
# Song 46: "T.R.O.N"
# Song 47: "Mike Lowery"
# Song 48: "Deadout"
# Song 49: "Famalam"
# Song 50: "Old School"
# Song 51: "Darker (Intro)"
# Song 52: "Music Ting"
# Song 53: "Freestyle"
# Song 54: "Still Tippin’ (Remix)"
# Song 55: "Ghost Train"
# Song 56: "That’s Hype"
# Song 57: "Poomplex"
# Song 58: "A.B.E (All Black Everything)"
# Song 59: "Shh Hut Yuh Muh"
# Song 60: "Famous"
# Song 61: "Don’t Chat To Me"
# Song 62: "Mr V Cinema Freestyle"
# Song 63: "Sun, Sea and Sand"
# Song 64: "Road Runner"
# Song 65: "Power"
# Song 66: "Understand"
# Song 67: "Hospital"
# Song 68: "Anger Room"
# Song 69: "Blind"
# Song 70: "It’s Not a Long Ting"
# Song 71: "I Love Music"
# Song 72: "Show"
# Song 73: "MSN Riddim"
# Song 74: "Deceived"
# Song 75: "Just Being Me"
# Song 76: "Shut Up And Dance"
# Song 77: "Eat Junk"
# Song 78: "Go On My Own"
# Song 79: "Certified Badman"
# Song 80: "Still Tippin’"
# Song 81: "Mirror On A Plane"
# Song 82: "Be Me"
# Song 83: "Money On My Brain"
# Song 84: "Ghetto Superstar"
# Song 85: "Myspace Freestyle"
# Song 86: "Flippin’ Hell"
# Song 87: "They Call Me"
# Song 88: "What You Need"
# Song 89: "Guess What"
# Song 90: "A Little Insight"
# Song 91: "Deceased"
# Song 92: "Go Prague or Go Rome"
# Song 93: "Pence"
# Song 94: "Hyping"
# Song 95: "Oh"
# Song 96: "Boogiedown Bass"
# Song 97: "LDN (Remix)"
# Song 98: "Nothing Goes Past Me"
# Song 99: "96 Ambitions"
# Song 100: "The Future"
# Song 101: "Derkhead Intro"
# Song 102: "W.O.T.S"
# Song 103: "Bull in a China Shop"
# Song 104: "Education"
# Song 105: "Don’t Chat"
# Song 106: "ASOS presents Nike Air Max Day"
# Song 107: "Show You (Remix)"
# Song 108: "Mario’s Flag"
# Song 109: "Final Boss"
# Song 110: "That’s Not Me (Twitter Remixes)"
# Song 111: "Rice & Peas"
# Song 112: "Introduction [Poomplex]"
# "Gonna Get Deep (Skit)" is not valid. Skipping.
# Song 113: "It’s Over"
# Song 114: "Subbuteo"
# Song 115: "Step Steady"
# "Best Friends (Skit)" is not valid. Skipping.
# Song 116: "Jme Staggering"
# Song 117: "Ray Mandem"
# Song 118: "Skeng"
# Song 119: "Shame"
# "Girl Left Me (Skit)" is not valid. Skipping.
# "Clubbing is Weird (Skit)" is not valid. Skipping.
# Song 120: "African Zulu Warrior"
# Song 121: "London Freestyle"
# Song 122: "Scotland"
# "W.O.T.S (Instrumental)" is not valid. Skipping.
# Song 123: "Production"
# "96 Bars of Revenge (Instrumental)" is not valid. Skipping.
# Song 124: "Machines"
# Song 125: "Holiday"
# Song 126: "Staggering"
# Song 127: "Shut Yuh Muh"
# Song 128: "Calm Down"
# Song 129: "Trust Me"
# Song 130: "Mash"
# Song 131: "Closer To You"
# Song 132: "Show You"
# Song 133: "Mayhem"
# Song 134: "Flow"
# Song 135: "Three Thousand Ghosts"
# Song 136: "I’m Gone"
# Song 137: "So Amazing Tropical"
# Song 138: "Total Mayhem"
# Song 139: "Melody And Voice"
# Song 140: "Ring My Bell"
# Song 141: "Hustle"
# Song 142: "JME007"
# Song 143: "Plazma"
# Song 144: "Baraka / Blue Portal"
# Song 145: "Weight"
# Song 146: "Dun No D Myspace"
# Song 147: "What’s Going On"
# Song 148: "Step Sequencer"
# Song 149: "Impact MT Bold"
# Song 150: "Gangsters (JME Mix)"
# Song 151: "Back 2 Basics"
# Song 152: "Jme’s iQ"
# "CD is Dead (Instrumental)" is not valid. Skipping.
# Song 153: "Raptor"
# Song 154: "So Skenged"
# "AWOH “Boy Better Know” (Instrumental)" is not valid. Skipping.
# "Flippin’ Hell (Instrumental)" is not valid. Skipping.
# Song 155: "Central London"
# Song 156: "Impact"
# "Old School (Instrumental)" is not valid. Skipping.
# Song 157: "Fruity 6"
# Song 158: "Versace Shades"
# "Don’t Chat To Me (Instrumental)" is not valid. Skipping.
#  50%|█████     | 5/10 [44:09<40:46, 489.25s/it]
# Song 159: "Give the Hint (Young Blood Production)"
# Done. Found 159 songs.
# Wrote Man Don’t Care to lyrics_jme_mandontcare.json.
# Wrote 96 Fuckries to lyrics_jme_96fuckries.json.
# Wrote Integrity to lyrics_jme_integrity.json.
# Wrote 96 Bars Of Revenge to lyrics_jme_96barsofrevenge.json.
# Wrote Don’t @ Me to lyrics_jme_dontme.json.
# Wrote Taking Over? (It Ain’t Working) to lyrics_jme_takingoveritaintworking.json.
# Wrote Test Me to lyrics_jme_testme.json.
# Wrote Work to lyrics_jme_work.json.
# Wrote Serious to lyrics_jme_serious.json.
# Wrote If You Don’t Know to lyrics_jme_ifyoudontknow.json.
# Wrote Pulse 8 to lyrics_jme_pulse8.json.
# Wrote The Very Best to lyrics_jme_theverybest.json.
# Wrote Jme to lyrics_jme_jme.json.
# Wrote Murking to lyrics_jme_murking.json.
# Wrote Game to lyrics_jme_game.json.
# Wrote Calm to lyrics_jme_calm.json.
# Wrote No You Ain’t to lyrics_jme_noyouaint.json.
# Wrote Amen to lyrics_jme_amen.json.
# Wrote Break You Down to lyrics_jme_breakyoudown.json.
# Wrote AWOH to lyrics_jme_awoh.json.
# Wrote The Money to lyrics_jme_themoney.json.
# Wrote Punch In The Face to lyrics_jme_punchintheface.json.
# Wrote Same Thing to lyrics_jme_samething.json.
# Wrote Banger to lyrics_jme_banger.json.
# Wrote Styley to lyrics_jme_styley.json.
# Wrote P to lyrics_jme_p.json.
# Wrote Again to lyrics_jme_again.json.
# Wrote 96 Bars of Jme to lyrics_jme_96barsofjme.json.
# Wrote Serious (Remix) to lyrics_jme_seriousremix.json.
# Wrote CD is Dead to lyrics_jme_cdisdead.json.
# Wrote Don’t Get Rude to lyrics_jme_dontgetrude.json.
# Wrote R U Dumb? to lyrics_jme_rudumb.json.
# Wrote Food to lyrics_jme_food.json.
# Wrote Blam! to lyrics_jme_blam.json.
# Wrote Over Me to lyrics_jme_overme.json.
# Wrote Westwood Freestyle to lyrics_jme_westwoodfreestyle.json.
# Wrote Jme and the Fox to lyrics_jme_jmeandthefox.json.
# Wrote Pick Up The Mic to lyrics_jme_pickupthemic.json.
# Wrote 123 to lyrics_jme_123.json.
# Wrote Twitter Freestyle to lyrics_jme_twitterfreestyle.json.
# Wrote I’m The Best to lyrics_jme_imthebest.json.
# Wrote Standard to lyrics_jme_standard.json.
# Wrote Boy Better Know to lyrics_jme_boybetterknow.json.
# Wrote Juju Riddim to lyrics_jme_jujuriddim.json.
# Wrote Sidetracked to lyrics_jme_sidetracked.json.
# Wrote T.R.O.N to lyrics_jme_t.r.o.n.json.
# Wrote Mike Lowery to lyrics_jme_mikelowery.json.
# Wrote Deadout to lyrics_jme_deadout.json.
# Wrote Famalam to lyrics_jme_famalam.json.
# Wrote Old School to lyrics_jme_oldschool.json.
# Wrote Darker (Intro) to lyrics_jme_darkerintro.json.
# Wrote Music Ting to lyrics_jme_musicting.json.
# Wrote Freestyle to lyrics_jme_freestyle.json.
# Wrote Still Tippin’ (Remix) to lyrics_jme_stilltippinremix.json.
# Wrote Ghost Train to lyrics_jme_ghosttrain.json.
# Wrote That’s Hype to lyrics_jme_thatshype.json.
# Wrote Poomplex to lyrics_jme_poomplex.json.
# Wrote A.B.E (All Black Everything) to lyrics_jme_a.b.eallblackeverything.json.
# Wrote Shh Hut Yuh Muh to lyrics_jme_shhhutyuhmuh.json.
# Wrote Famous to lyrics_jme_famous.json.
# Wrote Don’t Chat To Me to lyrics_jme_dontchattome.json.
# Wrote Mr V Cinema Freestyle to lyrics_jme_mrvcinemafreestyle.json.
# Wrote Sun, Sea and Sand to lyrics_jme_sunseaandsand.json.
# Wrote Road Runner to lyrics_jme_roadrunner.json.
# Wrote Power to lyrics_jme_power.json.
# Wrote Understand to lyrics_jme_understand.json.
# Wrote Hospital to lyrics_jme_hospital.json.
# Wrote Anger Room to lyrics_jme_angerroom.json.
# Wrote Blind to lyrics_jme_blind.json.
# Wrote It’s Not a Long Ting to lyrics_jme_itsnotalongting.json.
# Wrote I Love Music to lyrics_jme_ilovemusic.json.
# Wrote Show to lyrics_jme_show.json.
# Wrote MSN Riddim to lyrics_jme_msnriddim.json.
# Wrote Deceived to lyrics_jme_deceived.json.
# Wrote Just Being Me to lyrics_jme_justbeingme.json.
# Wrote Shut Up And Dance to lyrics_jme_shutupanddance.json.
# Wrote Eat Junk to lyrics_jme_eatjunk.json.
# Wrote Go On My Own to lyrics_jme_goonmyown.json.
# Wrote Certified Badman to lyrics_jme_certifiedbadman.json.
# Wrote Still Tippin’ to lyrics_jme_stilltippin.json.
# Wrote Mirror On A Plane to lyrics_jme_mirroronaplane.json.
# Wrote Be Me to lyrics_jme_beme.json.
# Wrote Money On My Brain to lyrics_jme_moneyonmybrain.json.
# Wrote Ghetto Superstar to lyrics_jme_ghettosuperstar.json.
# Wrote Myspace Freestyle to lyrics_jme_myspacefreestyle.json.
# Wrote Flippin’ Hell to lyrics_jme_flippinhell.json.
# Wrote They Call Me to lyrics_jme_theycallme.json.
# Wrote What You Need to lyrics_jme_whatyouneed.json.
# Wrote Guess What to lyrics_jme_guesswhat.json.
# Wrote A Little Insight to lyrics_jme_alittleinsight.json.
# Wrote Deceased to lyrics_jme_deceased.json.
# Wrote Go Prague or Go Rome to lyrics_jme_gopragueorgorome.json.
# Wrote Pence to lyrics_jme_pence.json.
# Wrote Hyping to lyrics_jme_hyping.json.
# Wrote Oh to lyrics_jme_oh.json.
# Wrote Boogiedown Bass to lyrics_jme_boogiedownbass.json.
# Wrote LDN (Remix) to lyrics_jme_ldnremix.json.
# Wrote Nothing Goes Past Me to lyrics_jme_nothinggoespastme.json.
# Wrote 96 Ambitions to lyrics_jme_96ambitions.json.
# Wrote The Future to lyrics_jme_thefuture.json.
# Wrote Derkhead Intro to lyrics_jme_derkheadintro.json.
# Wrote W.O.T.S to lyrics_jme_w.o.t.s.json.
# Wrote Bull in a China Shop to lyrics_jme_bullinachinashop.json.
# Wrote Education to lyrics_jme_education.json.
# Wrote Don’t Chat to lyrics_jme_dontchat.json.
# Wrote ASOS presents Nike Air Max Day to lyrics_jme_asospresentsnikeairmaxday.json.
# Wrote Show You (Remix) to lyrics_jme_showyouremix.json.
# Wrote Mario’s Flag to lyrics_jme_mariosflag.json.
# Wrote Final Boss to lyrics_jme_finalboss.json.
# Wrote That’s Not Me (Twitter Remixes) to lyrics_jme_thatsnotmetwitterremixes.json.
# Wrote Rice & Peas to lyrics_jme_ricepeas.json.
# Wrote Introduction [Poomplex] to lyrics_jme_introductionpoomplex.json.
# Wrote It’s Over to lyrics_jme_itsover.json.
# Wrote Subbuteo to lyrics_jme_subbuteo.json.
# Wrote Step Steady to lyrics_jme_stepsteady.json.
# Wrote Jme Staggering to lyrics_jme_jmestaggering.json.
# Wrote Ray Mandem to lyrics_jme_raymandem.json.
# Wrote Skeng to lyrics_jme_skeng.json.
# Wrote Shame to lyrics_jme_shame.json.
# Wrote African Zulu Warrior to lyrics_jme_africanzuluwarrior.json.
# Wrote London Freestyle to lyrics_jme_londonfreestyle.json.
# Wrote Scotland to lyrics_jme_scotland.json.
# Wrote Production to lyrics_jme_production.json.
# Wrote Machines to lyrics_jme_machines.json.
# Wrote Holiday to lyrics_jme_holiday.json.
# Wrote Staggering to lyrics_jme_staggering.json.
# Wrote Shut Yuh Muh to lyrics_jme_shutyuhmuh.json.
# Wrote Calm Down to lyrics_jme_calmdown.json.
# Wrote Trust Me to lyrics_jme_trustme.json.
# Wrote Mash to lyrics_jme_mash.json.
# Wrote Closer To You to lyrics_jme_closertoyou.json.
# Wrote Show You to lyrics_jme_showyou.json.
# Wrote Mayhem to lyrics_jme_mayhem.json.
# Wrote Flow to lyrics_jme_flow.json.
# Wrote Three Thousand Ghosts to lyrics_jme_threethousandghosts.json.
# Wrote I’m Gone to lyrics_jme_imgone.json.
# Wrote So Amazing Tropical to lyrics_jme_soamazingtropical.json.
# Wrote Total Mayhem to lyrics_jme_totalmayhem.json.
# Wrote Melody And Voice to lyrics_jme_melodyandvoice.json.
# Wrote Ring My Bell to lyrics_jme_ringmybell.json.
# Wrote Hustle to lyrics_jme_hustle.json.
# Wrote JME007 to lyrics_jme_jme007.json.
# Wrote Plazma to lyrics_jme_plazma.json.
# Wrote Baraka / Blue Portal to lyrics_jme_barakablueportal.json.
# Wrote Weight to lyrics_jme_weight.json.
# Wrote Dun No D Myspace to lyrics_jme_dunnodmyspace.json.
# Wrote What’s Going On to lyrics_jme_whatsgoingon.json.
# Wrote Step Sequencer to lyrics_jme_stepsequencer.json.
# Wrote Impact MT Bold to lyrics_jme_impactmtbold.json.
# Wrote Gangsters (JME Mix) to lyrics_jme_gangstersjmemix.json.
# Wrote Back 2 Basics to lyrics_jme_back2basics.json.
# Wrote Jme’s iQ to lyrics_jme_jmesiq.json.
# Wrote Raptor to lyrics_jme_raptor.json.
# Wrote So Skenged to lyrics_jme_soskenged.json.
# Wrote Central London to lyrics_jme_centrallondon.json.
# Wrote Impact to lyrics_jme_impact.json.
# Wrote Fruity 6 to lyrics_jme_fruity6.json.
# Wrote Versace Shades to lyrics_jme_versaceshades.json.
# Wrote Give the Hint (Young Blood Production) to lyrics_jme_givethehintyoungbloodproduction.json.
# ----------Getting the # 271 artist----------
# Searching for songs by J Dilla...
#
# Changing artist name to 'J Dilla'
# Song 1: "So Far to Go"
# Song 2: "Won’t Do"
# Song 3: "Baby"
# Song 4: "Fuck the Police"
# Song 5: "E=MC²"
# Song 6: "Workinonit"
# Song 7: "Come Get It"
# Song 8: "Think Twice"
# Song 9: "Sniper Elite"
# Song 10: "Love"
# Song 11: "Last Donut of the Night"
# Song 12: "Time: The Donut of the Heart"
# Song 13: "Stop!"
# Song 14: "Lightworks"
# Song 15: "Don’t Cry"
# Song 16: "Waves"
# Song 17: "Two Can Win"
# Song 18: "Nothing Like This"
# Song 19: "The Sickness"
# Song 20: "Donuts (Outro)"
# Song 21: "Crushin’ (Yeeeeaah!)"
# Song 22: "Anti-American Graffiti"
# Song 23: "So Far"
# Song 24: "Welcome to the Show"
# Song 25: "Dillatroit"
# Song 26: "Bye."
# Song 27: "The Shining Pt. 1 (Diamonds)"
# Song 28: "Dilla Bot vs. The Hybrid"
# Song 29: "One for Ghost"
# Song 30: "Shake It Down"
# Song 31: "Reality T.V."
# Song 32: "Light My Fire"
# Song 33: "Mash"
# Song 34: "Dime Piece (Remix)"
# Song 35: "Fire Wood Drumstix"
# Song 36: "The $"
# Song 37: "Gangsta Boogie"
# Song 38: "The Introduction"
# Song 39: "Jungle Love"
# Song 40: "Jay Dee’s Revenge"
# Song 41: "The New"
# Song 42: "Take Notice"
# Song 43: "Wild"
# Song 44: "Reckless Driving"
# Song 45: "The Ex"
# Song 46: "Trucks"
# Song 47: "It’s Like That"
# Song 48: "U-Love"
# Song 49: "People"
# Song 50: "Beej-N-Dem, Pt. 2"
# Song 51: "Let’s Take It Back"
# Song 52: "Pause"
# Song 53: "The Diff’rence"
# Song 54: "Hi."
# Song 55: "Make ’Em NV"
# Song 56: "Geek Down"
# Song 57: "Gobstopper"
# Song 58: "Airworks"
# Song 59: "Glazed"
# Song 60: "The Anthem"
# Song 61: "Dilla Says Go"
# Song 62: "Welcome 2 Detroit"
# Song 63: "Walkinonit"
# Song 64: "Love Movin’"
# Song 65: "One Eleven"
# Song 66: "The Clapper"
# Song 67: "Y’all Ain’t Ready"
# Song 68: "Featuring Phat Kat"
# Song 69: "The Twister (Huh, What)"
# Song 70: "Smoke"
# Song 71: "Stepson of the Clapper"
# Song 72: "The Factory"
# Song 73: "Dime Piece"
# Song 74: "Love Jones"
# Song 75: "Geek Down (Donuts)"
# Song 76: "24K Rap"
# "The Diary [Artwork + Tracklist]" is not valid. Skipping.
# Song 77: "Give It Up"
# Song 78: "Thunder"
# Song 79: "Give Em What They Want"
# Song 80: "The Shining, Pt. 2 (Ice)"
# Song 81: "Intro (Alt.)"
# Song 82: "Body Movin’"
# Song 83: "R U Listenin’?"
# Song 84: "Reality Check"
# Song 85: "Fight Club"
# Song 86: "B.B.E. (Big Booty Express)"
# Song 87: "KJay and We Out"
# Song 88: "Over the Breaks"
# Song 89: "Shouts (Alt.)"
# Song 90: "The Diary"
# Song 91: "Runnin’"
# Song 92: "Milk Money"
# Song 93: "Say It"
# Song 94: "Drive Me Wild"
# Song 95: "Detroit Madness"
# Song 96: "Motor City 17"
# Song 97: "The Creep (The O)"
# Song 98: "Intro (Ruff Draft)"
# Song 99: "One"
# Song 100: "Yesterday"
# Song 101: "Big Thangs"
# Song 102: "Ride With It"
# Song 103: "Say My Name"
# Song 104: "Dillatronic 09"
# Song 105: "Shouts"
# Song 106: "African Rhythms"
# Song 107: "Rico Suave Bossa Nova"
# Song 108: "Flyyyyy"
# Song 109: "King"
# Song 110: "Diamonds"
# Song 111: "Mythsysizer"
# Song 112: "Do ya thang"
# Song 113: "Can’t You See"
# Song 114: "Pay Day"
# Song 115: "Detroit Game"
# Song 116: "Brazilian Groove"
# Song 117: "Make It Fast"
# "Sometimes (Remix Instrumental)" is not valid. Skipping.
# Song 118: "Coastin’"
# Song 119: "Believe in God"
# Song 120: "Dillatronic 01"
# Song 121: "Dillatronic 41"
# Song 122: "See That Boy Fly"
# Song 123: "KJay FM Dedication"
# Song 124: "Motor City 1"
# Song 125: "Dreamy"
# Song 126: "651"
# Song 127: "Rebirth Is Necessary"
# Song 128: "Trashy"
# Song 129: "OMG I Love You"
# Song 130: "Oh Oh"
# Song 131: "Motor City 9"
# Song 132: "Blood Sport"
# Song 133: "City Of Boom"
# Song 134: "In the Streets"
# Song 135: "Digi Dirt"
# Song 136: "Doo Doo"
# Song 137: "551"
# Song 138: "Spacecowboy vs. Bobble Head"
# Song 139: "10,000 Watts"
# Song 140: "CaDILLAc"
# Song 141: "Earl"
# Song 142: "Big City"
# Song 143: "The Look"
# "Mr. Shakes (Skit)" is not valid. Skipping.
# Song 144: "In the Night / While You Slept (I Crept)"
# Song 145: "Plastic dreams"
# Song 146: "Dewitt To Do It"
# Song 147: "DD.001"
# Song 148: "751"
# Song 149: "Dillatronic 22"
# Song 150: "Motor City 8"
# Song 151: "Lazer Gunne Funke"
# Song 152: "DD.024"
# Song 153: "It’s Dope"
# Song 154: "On Stilts"
# Song 155: "DD.09"
# "So Far To Go (Instrumental)" is not valid. Skipping.
# Song 156: "663"
# Song 157: "Make It Fast (Unadulterated Mix)"
# Song 158: "865"
# Song 159: "369"
# "Jay Dee 19 - Instrumental" is not valid. Skipping.
# Song 160: "Feel the Beat"
# Song 161: "DD.002"
# Song 162: "F*ck The Police"
# Song 163: "367"
# Song 164: "Dillatronic 35"
# Song 165: "Glamour Sho75 (09)"
# Song 166: "1069"
# "Jay Dee 2 - Instrumental" is not valid. Skipping.
# Song 167: "161"
# Song 168: "Motor City 3"
# "Jay Dee 29 - Instrumental" is not valid. Skipping.
# Song 169: "Motor City 2"
# Song 170: "Circus"
# Song 171: "Get Down"
# Song 172: "Motor City 6"
# Song 173: "1071"
# Song 174: "DD.17"
# Song 175: "Kamaal"
# Song 176: "764"
# Song 177: "DD.12"
# Song 178: "Motor City 7"
# Song 179: "DD.004"
# "Jay Dee 30 - Instrumental" is not valid. Skipping.
# Song 180: "Dillatronic 31"
# Song 181: "Requiem"
# Song 182: "DD.007"
# Song 183: "DD.18"
# Song 184: "368"
# Song 185: "Kaklow (Jump On It)"
# Song 186: "DD.13"
# "So Real (Instrumental)" is not valid. Skipping.
# Song 187: "Feat. Phat Kat"
# Song 188: "DD.006"
# Song 189: "Dillatronic 15"
# Song 190: "562"
# Song 191: "Sensitive Tip"
# Song 192: "DD.022"
# Song 193: "Motor City 14"
# Song 194: "Motor City 5"
# Song 195: "261"
# Song 196: "1067"
# Song 197: "J"
# Song 198: "851"
# Song 199: "I Told Y’all"
# Song 200: "Drop"
# Song 201: "DD.11"
# Song 202: "9th Caller"
# Song 203: "1074"
# Song 204: "Dillatronic 29"
# Song 205: "Motor City 15"
# "Jay Dee 38 - Instrumental" is not valid. Skipping.
# Song 206: "DD.003"
# Song 207: "DD.19"
# "Jay Dee 36 - Instrumental" is not valid. Skipping.
# Song 208: "951"
# "Jay Dee 1 - Instrumental" is not valid. Skipping.
# "Instrumentals in to Mental’s" is not valid. Skipping.
# Song 209: "Dillatronic 02"
# "Jay Dee 21 - Instrumental" is not valid. Skipping.
# Song 210: "Dillatronic 17"
# Song 211: "DD.021"
# Song 212: "JLJ Intro"
# "The Best that Ever Did It (Instrumental)" is not valid. Skipping.
# Song 213: "Dillatronic 13"
# Song 214: "Motor City 4"
# Song 215: "On The One"
# Song 216: "DD.008"
# Song 217: "Busta"
# Song 218: "Vibe Out"
# Song 219: "The $ (Madlib remix)"
# Song 220: "DD.023"
# Song 221: "Itis like that"
# Song 222: "DD.14"
# Song 223: "DD.005"
# Song 224: "Motor City 12"
# Song 225: "Motor City 11"
# Song 226: "Dillatronic 11"
# "Jay Dee 3 - Instrumental" is not valid. Skipping.
# "Jay Dee 10 - Instrumental" is not valid. Skipping.
# Song 227: "Jay Dee 02"
# Song 228: "Motor City 13"
# Song 229: "966"
# "Jay Dee 16 - Instrumental" is not valid. Skipping.
# "Jay Dee 11 - Instrumental" is not valid. Skipping.
# Song 230: "The Skip"
# "Nothing Like This (instrumental)" is not valid. Skipping.
# Song 231: "Coming Back"
# "Jay Dee 34 - Instrumental" is not valid. Skipping.
# Song 232: "Dillatronic 05"
# Song 233: "Expensive Whip"
# Song 234: "1070"
# "DTFT - Instrumental" is not valid. Skipping.
# "Jay Dee 7 - Instrumental" is not valid. Skipping.
# Song 235: "Dillatronic 33"
# Song 236: "Dillatronic 36"
# "Jay Dee 8 - Instrumental" is not valid. Skipping.
# "Jay Dee 37 - Instrumental" is not valid. Skipping.
# Song 237: "160"
# Song 238: "Dillatronic 08"
# Song 239: "Dillatronic 06"
# Song 240: "DD.16"
# Song 241: "Motor City 18"
# Song 242: "Motor City 10"
# Song 243: "Dillatronic 34"
# Song 244: "L.L."
# Song 245: "Dillatronic 23"
# "Jay Dee 33 - Instrumental" is not valid. Skipping.
# Song 246: "DD.20"
# "Feel This Shit (Instrumental)" is not valid. Skipping.
# Song 247: "Dillatronic 26"
# Song 248: "Dillatronic 18"
# Song 249: "The Dee"
# Song 250: "Dillatronic 12"
# Song 251: "Dillatronic 39"
# "City of Boom (Instrumental)" is not valid. Skipping.
# Song 252: "Oblighetto"
# "Jay Dee 20 - Instrumental" is not valid. Skipping.
# "Jay Dee 23 - Instrumental" is not valid. Skipping.
# "Jay Dee 4 - Instrumental" is not valid. Skipping.
# Song 253: "Dillatronic 24"
# Song 254: "Dillatronic 32"
# Song 255: "Lightworking"
# Song 256: "1072"
# "Jay Dee 26 - Instrumental" is not valid. Skipping.
# "All Good - Instrumental" is not valid. Skipping.
# Song 257: "Dillatronic 16"
# Song 258: "Dillatronic 10"
# "Jay Dee 9 - Instrumental" is not valid. Skipping.
# "Jay Dee 35 - Instrumental" is not valid. Skipping.
# Song 259: "Dillatronic 40"
# "Say It (Instrumental)" is not valid. Skipping.
# Song 260: "Dillatronic 28"
# "Jay Dee 14 - Instrumental" is not valid. Skipping.
# Song 261: "DD.10"
# "Jay Dee 25 - Instrumental" is not valid. Skipping.
# Song 262: "Dillatronic 38"
# Song 263: "Somethin’ That Means Somethin’"
# Song 264: "DD.15"
# Song 265: "Dillatronic 14"
# "Jay Dee 31 - Instrumental" is not valid. Skipping.
# ...
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_fullyloadedclipfreestyle.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostcost.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_fastlane.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_uhohh.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_canubelieveit.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_leavingthegame.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_throwdown.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_diamondlife.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_and1kevingarnettcommercial.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_shootyoudown.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_comeclean.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_rudeboyhiphop.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_beatstomyrhyme.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostthing.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_popout.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_blowyourmindremix.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_bringitin.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_freestylekingz.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_reckless.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_whattheywant.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_wegettin.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_itsok.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_gsense.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_stylesfeat.jadakiss.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_intro.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostkill.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_bringdemghost.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_senseistyle.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_innercityghost.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_takeitback.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_freestyle1.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_comeonecomeallrockremix.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostmurder.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_letsgo.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_dontturnaway.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_heroinbars.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_freestyle2.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_outro.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_imageefeat.rell.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_imononefreestyle.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_myparty.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostwork.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_funkflexfreestyle.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_problemchild.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_playthegame.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_blockfear.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_samescriptures.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_openup.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_livebythegun.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_empirestatehigh.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_untouchableghostghostwalls.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_theoldfromthenew.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_airofthenight.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_whatwhywherewhen.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_givemeyourghost.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostbands.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_trueghost.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_shownofffreestyle.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_bangtime.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_thinklox.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_getyourdreamsmash.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_dontfront.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_therealstylesp.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_enjoytheatmosphere.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostriverstotheriches.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_wedontplayfeat.lloydbanks.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_penitentiarychances.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_poppinbottles.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_welcometony.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostblunts.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_imabeast.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_fly.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_superstarghost.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostgetdown.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_prhymeghost.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_lemonaderemix.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_worldsgreatest.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_sex.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_thatstreetlife.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_thismoment.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostzilla.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_keystothecrib.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_itsokfeat.jadakiss.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostdillatheredfreestyle.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_dontfadeem.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_daddygetthatcashfeat.lilmo.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_institutionalized.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostinanutshell.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_onemorestep.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_bonustracksodeep.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_stylesp106parksthebackroomfreestyle.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_tellyport.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_bnbanger.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_sexbeatles.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_backonmynewshit.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_nightshift.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_takeyouback.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_getyourweightup.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_shooter.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_together.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_dontturnawayfeat.pharrell.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_heartbeatz.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_itisokfeat.jadakiss.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_nothingtolose.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_streetsht.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ms.jackson.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_whereimfrom.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_themusicsucks.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_verymorning.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_realgold.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_stopschemin.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_compromise.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_enemyofthestate.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_mr.beanladen.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_procrastinator.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_convowithshawtyinterlude.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_highspeed.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_hereiam.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_donitturnawayfeat.pharrell.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_nywilkommenterrorist.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_ghostshit.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_thestart.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_nmeisyou.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_introsupergangsterextraordinarygentleman.json already exists. Overwrite?
# (y/n):
# Skipping file save.
#
# lyrics_stylesp_salutetoknockout.json already exists. Overwrite?
# (y/n):
#  90%|█████████ | 9/10 [2:19:20<19:24, 1164.65s/it]
# Skipping file save.
#
# ----------Getting the # 275 artist----------
# Searching for songs by Living Legends...
#
# Song 1: "Never Fallin"
# Song 2: "Remember Who You Are"
# Song 3: "Moving At the Speed of Life"
# Song 4: "Nothing Less"
# Song 5: "After Hours (Extended Euromix)"
# Song 6: "Night Prowler"
# Song 7: "Artsy"
# Song 8: "Another Day"
# Song 9: "Wise is the Way"
# Song 10: "She Wants Me"
# Song 11: "Purple Kush"
# Song 12: "Flawless"
# Song 13: "Rabbit Hole"
# Song 14: "After I’m Gone"
# Song 15: "Good Fun"
# Song 16: "War Games"
# Song 17: "Dirty Faces"
# Song 18: "Addicted"
# Song 19: "2010"
# Song 20: "Nowyouno"
# Song 21: "Gift Wrap"
# Song 22: "The Man Who Sold the World (Part 2)"
# Song 23: "Common Ground"
# Song 24: "Brand New"
# Song 25: "Forces of Nature"
# Song 26: "Even Though"
# Song 27: "It’s Us"
# Song 28: "Black Glass"
# Song 29: "Gotta Question For Ya"
# Song 30: "Shining Symbol"
# Song 31: "Real Slow the Fast Way"
# Song 32: "Loose Cannon"
# Song 33: "That Looks Good"
# Song 34: "You Hear About It"
# Song 35: "What Would I Be"
# Song 36: "Busted"
# Song 37: "War And Peace"
# Song 38: "Down For Nothin’"
# Song 39: "Not Here"
# Song 40: "No Strings"
# Song 41: "One-Two"
# Song 42: "The Truth"
# Song 43: "Telepathy"
# Song 44: "Whatizit"
# Song 45: "Soap Boxin"
# Song 46: "Nitroglycerin (Nigen Revisited)"
# Song 47: "Rabbit Hole (intro)"
# Song 48: "Trojan Horse"
# Song 49: "Stop & Retaliate"
# Song 50: "The Controls"
# Song 51: "Friends are calling"
# 100%|██████████| 10/10 [2:21:10<00:00, 848.25s/it]
# Done. Found 51 songs.
# Wrote Never Fallin to lyrics_livinglegends_neverfallin.json.
# Wrote Remember Who You Are to lyrics_livinglegends_rememberwhoyouare.json.
# Wrote Moving At the Speed of Life to lyrics_livinglegends_movingatthespeedoflife.json.
# Wrote Nothing Less to lyrics_livinglegends_nothingless.json.
# Wrote After Hours (Extended Euromix) to lyrics_livinglegends_afterhoursextendedeuromix.json.
# Wrote Night Prowler to lyrics_livinglegends_nightprowler.json.
# Wrote Artsy to lyrics_livinglegends_artsy.json.
# Wrote Another Day to lyrics_livinglegends_anotherday.json.
# Wrote Wise is the Way to lyrics_livinglegends_wiseistheway.json.
# Wrote She Wants Me to lyrics_livinglegends_shewantsme.json.
# Wrote Purple Kush to lyrics_livinglegends_purplekush.json.
# Wrote Flawless to lyrics_livinglegends_flawless.json.
# Wrote Rabbit Hole to lyrics_livinglegends_rabbithole.json.
# Wrote After I’m Gone to lyrics_livinglegends_afterimgone.json.
# Wrote Good Fun to lyrics_livinglegends_goodfun.json.
# Wrote War Games to lyrics_livinglegends_wargames.json.
# Wrote Dirty Faces to lyrics_livinglegends_dirtyfaces.json.
# Wrote Addicted to lyrics_livinglegends_addicted.json.
# Wrote 2010 to lyrics_livinglegends_2010.json.
# Wrote Nowyouno to lyrics_livinglegends_nowyouno.json.
# Wrote Gift Wrap to lyrics_livinglegends_giftwrap.json.
# Wrote The Man Who Sold the World (Part 2) to lyrics_livinglegends_themanwhosoldtheworldpart2.json.
# Wrote Common Ground to lyrics_livinglegends_commonground.json.
# Wrote Brand New to lyrics_livinglegends_brandnew.json.
# Wrote Forces of Nature to lyrics_livinglegends_forcesofnature.json.
# Wrote Even Though to lyrics_livinglegends_eventhough.json.
# Wrote It’s Us to lyrics_livinglegends_itsus.json.
# Wrote Black Glass to lyrics_livinglegends_blackglass.json.
# Wrote Gotta Question For Ya to lyrics_livinglegends_gottaquestionforya.json.
# Wrote Shining Symbol to lyrics_livinglegends_shiningsymbol.json.
# Wrote Real Slow the Fast Way to lyrics_livinglegends_realslowthefastway.json.
# Wrote Loose Cannon to lyrics_livinglegends_loosecannon.json.
# Wrote That Looks Good to lyrics_livinglegends_thatlooksgood.json.
# Wrote You Hear About It to lyrics_livinglegends_youhearaboutit.json.
# Wrote What Would I Be to lyrics_livinglegends_whatwouldibe.json.
# Wrote Busted to lyrics_livinglegends_busted.json.
# Wrote War And Peace to lyrics_livinglegends_warandpeace.json.
# Wrote Down For Nothin’ to lyrics_livinglegends_downfornothin.json.
# Wrote Not Here to lyrics_livinglegends_nothere.json.
# Wrote No Strings to lyrics_livinglegends_nostrings.json.
# Wrote One-Two to lyrics_livinglegends_onetwo.json.
# Wrote The Truth to lyrics_livinglegends_thetruth.json.
# Wrote Telepathy to lyrics_livinglegends_telepathy.json.
# Wrote Whatizit to lyrics_livinglegends_whatizit.json.
# Wrote Soap Boxin to lyrics_livinglegends_soapboxin.json.
# Wrote Nitroglycerin (Nigen Revisited) to lyrics_livinglegends_nitroglycerinnigenrevisited.json.
# Wrote Rabbit Hole (intro) to lyrics_livinglegends_rabbitholeintro.json.
# Wrote Trojan Horse to lyrics_livinglegends_trojanhorse.json.
# Wrote Stop & Retaliate to lyrics_livinglegends_stopretaliate.json.
# Wrote The Controls to lyrics_livinglegends_thecontrols.json.
# Wrote Friends are calling to lyrics_livinglegends_friendsarecalling.json.
