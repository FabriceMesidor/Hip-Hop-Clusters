# %% [markdown]
# #### Helpers

# %%
import lyricsgenius as genius
from tqdm import tqdm
import time
import credentials as cd

# %%
#Authentification
api = genius.Genius(client_access_token=cd.access_token)

# %% [markdown]
# ### Functions

# %%
#building a search function to find a defined number of songs for an artist
def search_song(artist,number_song):
        results= api.search_artist(artist, max_songs=number_song)
        return results

# %%
#Function to find songs titles
def find_song_title(results):
    return [results.songs]

# %%
#Function to find songs lyrics
def save_lyrics(artist,number_song):
    return search_song(artist,number_song).save_lyrics()

# %% [markdown]
# ### Getting songs from the artists list

# %%
# Load file with all artists
import pickle

with open('../hip-hop-artist-ranker.pkl', 'rb') as f:
    artists_list = pickle.load(f)

# %%
#Checking correct list was imported
len(artists_list)
# Out:
# 814

# %%
#Saving lyrics for 50 artists
for x in tqdm(range(142,150)):
    time.sleep(0.5)
    print('-'*10+'Getting the # '+ str(x+1)+' artist'+'-'*10)
    save_lyrics(artists_list[x],500)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ----------Getting the # 141 artist----------
# Searching for songs by Queen Latifah...
#
# Song 1: "U.N.I.T.Y."
# Song 2: "Living Single theme song"
# Song 3: "I Know Where I’ve Been"
# Song 4: "Ladies First"
# Song 5: "Big, Blonde and Beautiful"
# Song 6: "Just Another Day..."
# Song 7: "When You’re Good To Mama"
# Song 8: "Come So Far (Got So Far To Go) (”Hairspray”)"
# Song 9: "Name Callin’ Part 2"
# Song 10: "Cell Block Tango (He Had it Comin’)"
# Song 11: "Fix Me, Jesus"
# Song 12: "Name Callin’"
# Song 13: "Evil That Men Do"
# Song 14: "Fly Girl"
# Song 15: "Black Hand Side"
# Song 16: "Jersey"
# Song 17: "He’s Everything"
# Song 18: "Wrath of My Madness"
# Song 19: "I Can’t Understand"
# Song 20: "Latifah’s Had It Up 2 Here"
# Song 21: "Rough..."
# Song 22: "Weekend Love"
# Song 23: "Coochie Bang..."
# Song 24: "Higher Medley"
# Song 25: "Come Into My House"
# Song 26: "Listen 2 Me"
# Song 27: "Mama Gave Birth to the Soul Children"
# Song 28: "Dance for Me"
# Song 29: "Princess of the Posse"
# Song 30: "How Do I Love Thee"
# Song 31: "Bring The Flavor"
# Song 32: "Do Your Thing"
# Song 33: "No Work"
# Song 34: "Ladies First (Radio Edit)"
# Song 35: "Go Head"
# Song 36: "Latifah’s Law"
# Song 37: "Mercy, Mercy, Mercy"
# Song 38: "Mood Is Right"
# Song 39: "I Know Where You’ve Been"
# Song 40: "Winki’s Theme"
# Song 41: "California Dreamin’"
# Song 42: "Superstar"
# Song 43: "Nuff’ of the Ruff’ Stuff’"
# Song 44: "Elements I’m Among"
# Song 45: "It’s Alright"
# Song 46: "Hello Stranger"
# Song 47: "A King and Queen Creation"
# Song 48: "Black on Black Love"
# Song 49: "Life"
# Song 50: "Bananas (Who You Gonna Call?)"
# Song 51: "Cell Block Tango"
# Song 52: "The Pros"
# Song 53: "Queen of Royal Badness"
# Song 54: "Paper"
# Song 55: "Champion"
# Song 56: "Give Me Your Love"
# Song 57: "Hard Times"
# Song 58: "Inside Out"
# Song 59: "Court Is in Session"
# Song 60: "Georgia Rose"
# Song 61: "People"
# Song 62: "Just a Flow (Interlude)"
# Song 63: "I Don’t Know"
# Song 64: "Don’t Cry Baby"
# Song 65: "Brownsville"
# Song 66: "Simply Beautiful"
# Song 67: "Oh Happy Day"
# Song 68: "Poetry Man"
# Song 69: "Baby Get Lost"
# Song 70: "I Put A Spell On You"
# Song 71: "What Ya Gonna Do"
# Song 72: "I’m Gonna Live Till I Die"
# Song 73: "Fast Car"
# Song 74: "Parlay"
# Song 75: "Turn You On"
# Song 76: "4 the D.J.’s (Interlude)"
# Song 77: "I’m Not In Love"
# Song 78: "Lush Life"
# Song 79: "No/Yes"
# Song 80: "Cue The Rain"
# Song 81: "I Want a Little Sugar in My Bowl"
# Song 82: "How Long (Betcha’ Got a Chick on the Side)"
# Song 83: "The Lady Is a Tramp"
# Song 84: "Close Your Eyes"
# Song 85: "The Same Love That Made Me Laugh"
# Song 86: "Moody’s Mood For Love"
# Song 87: "If I Had You"
# Song 88: "Quiet Nights Of Quiet Stars"
# Song 89: "Princess Of The Posse (DJ Mark The 45 King Remix)"
# Song 90: "Goin’ Out Of My Head"
# Song 91: "Gone Away"
# Song 92: "Dance For Me (Ultimatum Remix)"
# Song 93: "The World"
# Song 94: "Fly Girl (Brixton Bass Mix)"
# Song 95: "Trav’lin’ Light"
# Song 96: "Wrath Of My Madness (Soulshock Remix)"
# Song 97: "Not enough"
# Song 98: "What Love Has Joined Together"
# "No/Yes (Skit)" is not valid. Skipping.
# Song 99: "Nature of a Sista"
# "Phone Call (Skit)" is not valid. Skipping.
# Song 100: "I Love Being Here with You"
# Song 101: "Corcovado (quiet nights of quiet stars)"
# Song 102: "Wrath Of My Madness (DJ Premier Remix)"
# Song 103: "Just Another Day... (New Jack Remix)"
# Song 104: "Mr. Big Stuff"
# Song 105: "Be Anything (But Be Mine)"
# Song 106: "Wrath of My Madness (Premier Remix) (dirty)"
# Song 107: "Let Her Live (France and Japan Bonus Track)"
#  10%|█         | 1/10 [03:28<31:17, 208.58s/it]
# Done. Found 107 songs.
# Wrote U.N.I.T.Y. to lyrics_queenlatifah_u.n.i.t.y..json.
# Wrote Living Single theme song to lyrics_queenlatifah_livingsinglethemesong.json.
# Wrote I Know Where I’ve Been to lyrics_queenlatifah_iknowwhereivebeen.json.
# Wrote Ladies First to lyrics_queenlatifah_ladiesfirst.json.
# Wrote Big, Blonde and Beautiful to lyrics_queenlatifah_bigblondeandbeautiful.json.
# Wrote Just Another Day... to lyrics_queenlatifah_justanotherday....json.
# Wrote When You’re Good To Mama to lyrics_queenlatifah_whenyouregoodtomama.json.
# Wrote Come So Far (Got So Far To Go) (”Hairspray”) to lyrics_queenlatifah_comesofargotsofartogohairspray.json.
# Wrote Name Callin’ Part 2 to lyrics_queenlatifah_namecallinpart2.json.
# Wrote Cell Block Tango (He Had it Comin’) to lyrics_queenlatifah_cellblocktangohehaditcomin.json.
# Wrote Fix Me, Jesus to lyrics_queenlatifah_fixmejesus.json.
# Wrote Name Callin’ to lyrics_queenlatifah_namecallin.json.
# Wrote Evil That Men Do to lyrics_queenlatifah_evilthatmendo.json.
# Wrote Fly Girl to lyrics_queenlatifah_flygirl.json.
# Wrote Black Hand Side to lyrics_queenlatifah_blackhandside.json.
# Wrote Jersey to lyrics_queenlatifah_jersey.json.
# Wrote He’s Everything to lyrics_queenlatifah_heseverything.json.
# Wrote Wrath of My Madness to lyrics_queenlatifah_wrathofmymadness.json.
# Wrote I Can’t Understand to lyrics_queenlatifah_icantunderstand.json.
# Wrote Latifah’s Had It Up 2 Here to lyrics_queenlatifah_latifahshaditup2here.json.
# Wrote Rough... to lyrics_queenlatifah_rough....json.
# Wrote Weekend Love to lyrics_queenlatifah_weekendlove.json.
# Wrote Coochie Bang... to lyrics_queenlatifah_coochiebang....json.
# Wrote Higher Medley to lyrics_queenlatifah_highermedley.json.
# Wrote Come Into My House to lyrics_queenlatifah_comeintomyhouse.json.
# Wrote Listen 2 Me to lyrics_queenlatifah_listen2me.json.
# Wrote Mama Gave Birth to the Soul Children to lyrics_queenlatifah_mamagavebirthtothesoulchildren.json.
# Wrote Dance for Me to lyrics_queenlatifah_danceforme.json.
# Wrote Princess of the Posse to lyrics_queenlatifah_princessoftheposse.json.
# Wrote How Do I Love Thee to lyrics_queenlatifah_howdoilovethee.json.
# Wrote Bring The Flavor to lyrics_queenlatifah_bringtheflavor.json.
# Wrote Do Your Thing to lyrics_queenlatifah_doyourthing.json.
# Wrote No Work to lyrics_queenlatifah_nowork.json.
# Wrote Ladies First (Radio Edit) to lyrics_queenlatifah_ladiesfirstradioedit.json.
# Wrote Go Head to lyrics_queenlatifah_gohead.json.
# Wrote Latifah’s Law to lyrics_queenlatifah_latifahslaw.json.
# Wrote Mercy, Mercy, Mercy to lyrics_queenlatifah_mercymercymercy.json.
# Wrote Mood Is Right to lyrics_queenlatifah_moodisright.json.
# Wrote I Know Where You’ve Been to lyrics_queenlatifah_iknowwhereyouvebeen.json.
# Wrote Winki’s Theme to lyrics_queenlatifah_winkistheme.json.
# Wrote California Dreamin’ to lyrics_queenlatifah_californiadreamin.json.
# Wrote Superstar to lyrics_queenlatifah_superstar.json.
# Wrote Nuff’ of the Ruff’ Stuff’ to lyrics_queenlatifah_nuffoftheruffstuff.json.
# Wrote Elements I’m Among to lyrics_queenlatifah_elementsimamong.json.
# Wrote It’s Alright to lyrics_queenlatifah_itsalright.json.
# Wrote Hello Stranger to lyrics_queenlatifah_hellostranger.json.
# Wrote A King and Queen Creation to lyrics_queenlatifah_akingandqueencreation.json.
# Wrote Black on Black Love to lyrics_queenlatifah_blackonblacklove.json.
# Wrote Life to lyrics_queenlatifah_life.json.
# Wrote Bananas (Who You Gonna Call?) to lyrics_queenlatifah_bananaswhoyougonnacall.json.
# Wrote Cell Block Tango to lyrics_queenlatifah_cellblocktango.json.
# Wrote The Pros to lyrics_queenlatifah_thepros.json.
# Wrote Queen of Royal Badness to lyrics_queenlatifah_queenofroyalbadness.json.
# Wrote Paper to lyrics_queenlatifah_paper.json.
# Wrote Champion to lyrics_queenlatifah_champion.json.
# Wrote Give Me Your Love to lyrics_queenlatifah_givemeyourlove.json.
# Wrote Hard Times to lyrics_queenlatifah_hardtimes.json.
# Wrote Inside Out to lyrics_queenlatifah_insideout.json.
# Wrote Court Is in Session to lyrics_queenlatifah_courtisinsession.json.
# Wrote Georgia Rose to lyrics_queenlatifah_georgiarose.json.
# Wrote People to lyrics_queenlatifah_people.json.
# Wrote Just a Flow (Interlude) to lyrics_queenlatifah_justaflowinterlude.json.
# Wrote I Don’t Know to lyrics_queenlatifah_idontknow.json.
# Wrote Don’t Cry Baby to lyrics_queenlatifah_dontcrybaby.json.
# Wrote Brownsville to lyrics_queenlatifah_brownsville.json.
# Wrote Simply Beautiful to lyrics_queenlatifah_simplybeautiful.json.
# Wrote Oh Happy Day to lyrics_queenlatifah_ohhappyday.json.
# Wrote Poetry Man to lyrics_queenlatifah_poetryman.json.
# Wrote Baby Get Lost to lyrics_queenlatifah_babygetlost.json.
# Wrote I Put A Spell On You to lyrics_queenlatifah_iputaspellonyou.json.
# Wrote What Ya Gonna Do to lyrics_queenlatifah_whatyagonnado.json.
# Wrote I’m Gonna Live Till I Die to lyrics_queenlatifah_imgonnalivetillidie.json.
# Wrote Fast Car to lyrics_queenlatifah_fastcar.json.
# Wrote Parlay to lyrics_queenlatifah_parlay.json.
# Wrote Turn You On to lyrics_queenlatifah_turnyouon.json.
# Wrote 4 the D.J.’s (Interlude) to lyrics_queenlatifah_4thed.j.sinterlude.json.
# Wrote I’m Not In Love to lyrics_queenlatifah_imnotinlove.json.
# Wrote Lush Life to lyrics_queenlatifah_lushlife.json.
# Wrote No/Yes to lyrics_queenlatifah_noyes.json.
# Wrote Cue The Rain to lyrics_queenlatifah_cuetherain.json.
# Wrote I Want a Little Sugar in My Bowl to lyrics_queenlatifah_iwantalittlesugarinmybowl.json.
# Wrote How Long (Betcha’ Got a Chick on the Side) to lyrics_queenlatifah_howlongbetchagotachickontheside.json.
# Wrote The Lady Is a Tramp to lyrics_queenlatifah_theladyisatramp.json.
# Wrote Close Your Eyes to lyrics_queenlatifah_closeyoureyes.json.
# Wrote The Same Love That Made Me Laugh to lyrics_queenlatifah_thesamelovethatmademelaugh.json.
# Wrote Moody’s Mood For Love to lyrics_queenlatifah_moodysmoodforlove.json.
# Wrote If I Had You to lyrics_queenlatifah_ifihadyou.json.
# Wrote Quiet Nights Of Quiet Stars to lyrics_queenlatifah_quietnightsofquietstars.json.
# Wrote Princess Of The Posse (DJ Mark The 45 King Remix) to lyrics_queenlatifah_princessofthepossedjmarkthe45kingremix.json.
# Wrote Goin’ Out Of My Head to lyrics_queenlatifah_goinoutofmyhead.json.
# Wrote Gone Away to lyrics_queenlatifah_goneaway.json.
# Wrote Dance For Me (Ultimatum Remix) to lyrics_queenlatifah_danceformeultimatumremix.json.
# Wrote The World to lyrics_queenlatifah_theworld.json.
# Wrote Fly Girl (Brixton Bass Mix) to lyrics_queenlatifah_flygirlbrixtonbassmix.json.
# Wrote Trav’lin’ Light to lyrics_queenlatifah_travlinlight.json.
# Wrote Wrath Of My Madness (Soulshock Remix) to lyrics_queenlatifah_wrathofmymadnesssoulshockremix.json.
# Wrote Not enough to lyrics_queenlatifah_notenough.json.
# Wrote What Love Has Joined Together to lyrics_queenlatifah_whatlovehasjoinedtogether.json.
# Wrote Nature of a Sista to lyrics_queenlatifah_natureofasista.json.
# Wrote I Love Being Here with You to lyrics_queenlatifah_ilovebeingherewithyou.json.
# Wrote Corcovado (quiet nights of quiet stars) to lyrics_queenlatifah_corcovadoquietnightsofquietstars.json.
# Wrote Wrath Of My Madness (DJ Premier Remix) to lyrics_queenlatifah_wrathofmymadnessdjpremierremix.json.
# Wrote Just Another Day... (New Jack Remix) to lyrics_queenlatifah_justanotherday...newjackremix.json.
# Wrote Mr. Big Stuff to lyrics_queenlatifah_mr.bigstuff.json.
# Wrote Be Anything (But Be Mine) to lyrics_queenlatifah_beanythingbutbemine.json.
# Wrote Wrath of My Madness (Premier Remix) (dirty) to lyrics_queenlatifah_wrathofmymadnesspremierremixdirty.json.
# Wrote Let Her Live (France and Japan Bonus Track) to lyrics_queenlatifah_letherlivefranceandjapanbonustrack.json.
# ----------Getting the # 142 artist----------
# Searching for songs by Kodak Black...
#
# Song 1: "Tunnel Vision"
# Song 2: "No Flockin"
# Song 3: "Roll in Peace"
# Song 4: "ZEZE"
# Song 5: "SKRT"
# Song 6: "There He Go"
# Song 7: "Skrilla"
# Song 8: "Codeine Dreaming"
# Song 9: "Transportin’"
# Song 10: "Too Many Years"
# Song 11: "Like Dat"
# Song 12: "Calling My Spirit"
# Song 13: "I.M.Y (I Miss You)"
# Song 14: "Baby Girl"
# Song 15: "Institution"
# Song 16: "Patty Cake"
# Song 17: "Testimony"
# Song 18: "Malcolm X.X.X."
# Song 19: "Versatile"
# Song 20: "Conscience"
# Song 21: "Don’t Wanna Breathe"
# Song 22: "First Day Out"
# Song 23: "G to the A"
# Song 24: "Pimpin Ain’t Eazy"
# Song 25: "If I’m Lyin, I’m Flyin"
# Song 26: "Everything 1K"
# Song 27: "Snot Thot"
# Song 28: "Already"
# Song 29: "Water"
# Song 30: "201519971800"
# Song 31: "Young Prodigy"
# Song 32: "Halloween"
# Song 33: "Can I"
# Song 34: "Gave It All I Got"
# Song 35: "Expeditiously"
# Song 36: "If You Ain’t Ridin’"
# Song 37: "Vibin In This Bih"
# Song 38: "Slayed"
# Song 39: "Honey Bun"
# Song 40: "Day for Day"
# Song 41: "6th Sense"
# Song 42: "Signs"
# Song 43: "News Or Something (Freestyle)"
# Song 44: "Purp"
# Song 45: "Gnarly"
# Song 46: "Fresh Out / My Struggle"
# Song 47: "Coolin and Booted"
# Song 48: "Could of Been Different"
# Song 49: "Christmas in Miami"
# Song 50: "Project Baby"
# Song 51: "Unexplainable"
# Song 52: "Corrlinks and JPay"
# Song 53: "Take One"
# Song 54: "Need a Break"
# Song 55: "Built My Legacy"
# Song 56: "HollyHood"
# Song 57: "From the Cradle"
# Song 58: "Roll in Peace (Remix)"
# Song 59: "Running Outta Love"
# Song 60: "MoshPit"
# Song 61: "Today"
# Song 62: "Save You"
# Song 63: "Close to the Grave"
# Song 64: "Down South"
# Song 65: "Heart"
# Song 66: "Dream Doll"
# Song 67: "No Flockin 2 (Bodak Orange)"
# Song 68: "Up in Here"
# Song 69: "Identity Theft"
# Song 70: "Side Nigga"
# Song 71: "Reminiscing"
# Song 72: "Free Cool Pt.2"
# Song 73: "Deep In These Streets"
# Song 74: "Fuck With You"
# Song 75: "Me, Myself & I"
# Song 76: "Roll N Peace 2"
# Song 77: "Big Bank"
# Song 78: "Change My Ways"
# Song 79: "Still Hittin Licks"
# Song 80: "XXL Freshman Freestyle: Kodak Black"
# Song 81: "1800 Nights (Kno The Meaning Freestyle)"
# Song 82: "First Love"
# Song 83: "4th Quarter"
# Song 84: "Off the Land"
# Song 85: "Loyal"
# Song 86: "Molly"
# Song 87: "When Vultures Cry"
# Song 88: "Snap Shit"
# Song 89: "U Ain’t Never"
# Song 90: "Cut Throat"
# Song 91: "Misunderstood"
# Song 92: "In Too Deep"
# Song 93: "Bill And Jill"
# Song 94: "Boss My Life Up"
# Song 95: "Top Off Benz"
# Song 96: "Hungry"
# Song 97: "I’m That Nigga"
# Song 98: "I Need Love"
# Song 99: "Shit On Me"
# Song 100: "Fall Thru"
# Song 101: "Brand New Glizzy"
# Song 102: "Why They Call You Kodak"
# Song 103: "ThankFul"
# Song 104: "Acting Weird"
# Song 105: "Why You Always Gotta Go"
# Song 106: "Needing Something"
# Song 107: "From The Ugly"
# Song 108: "Gospel"
# Song 109: "Erykah Badu"
# Song 110: "Roll in Peace (Demo)"
# Song 111: "Me for Me"
# Song 112: "Spaz Out"
# Song 113: "Just A Wrap (Freestyle)"
# Song 114: "No CoDefendant"
# Song 115: "Time Never Mattered (Seeing Demons) (Do Not Disturb Freestyle)"
# Song 116: "No Meds"
# Song 117: "This Forever"
# Song 118: "Versatile 2"
# Song 119: "Candy Paint"
# Song 120: "Twenty 8"
# Song 121: "In the Flesh"
# Song 122: "Real Nigga Files"
# Song 123: "Transgression"
# Song 124: "30"
# Song 125: "The Recipe"
# Song 126: "Feb 14"
# Song 127: "I N U"
# Song 128: "Chances"
# Song 129: "My Klik"
# Song 130: "Ambition (I’m 14 And Already Thinking About Death)"
# Song 131: "Hate Being Alone"
# Song 132: "Ran Up A Check"
# Song 133: "Boost My Ego"
# Song 134: "Poetical G"
# Song 135: "No Feelings"
# Song 136: "Pride"
# Song 137: "Feeling Like"
# Song 138: "Cell Therapy (Freestyle)"
# Song 139: "This Life"
# Song 140: "I Need A Beat"
# Song 141: "You Do That Shit"
# Song 142: "Get Up"
# Song 143: "Free Cool"
# Song 144: "Real Shit"
# Song 145: "About You Without You"
# Song 146: "Corrupted"
# Song 147: "Fed Up"
# Song 148: "Letter"
# Song 149: "Blood Sweat Tears Revenge"
# Song 150: "10 Toes Down"
# Song 151: "Back On My Feet"
# Song 152: "Project Baby 2"
# Song 153: "Honest (Freestyle)"
# Song 154: "Helluva Love"
# Song 155: "Laudy"
# Song 156: "Rock Bottom"
# Song 157: "Kicking In"
# Song 158: "I Be On The Way"
# Song 159: "I Get Lonely"
# Song 160: "Heart Of The Projects"
# Song 161: "Up Late"
# Song 162: "I Wanna Rock"
# Song 163: "Catch Flight"
# Song 164: "Call You"
# Song 165: "Still in the Streets"
# Song 166: "Str8 Bars Freestyle"
# Song 167: "Believe This Shit"
# Song 168: "Cognitive"
# Song 169: "Shake Back"
# "Lil Uzi Vert, Lil Yachty, Kodak Black, 21 Savage & Denzel Curry’s 2016 XXL Freshmen Interview" is not valid. Skipping.
# Song 170: "My Cousin"
# Song 171: "Jewels (Whole Time)"
# Song 172: "I Just Might"
# Song 173: "Fuck It"
# Song 174: "Now Time"
# Song 175: "Killing It"
# Song 176: "Manuvering"
# Song 177: "My Wrist"
# Song 178: "Yung Niggaz"
# Song 179: "Mama"
# Song 180: "Wake N Bake"
# Song 181: "Pelican"
# Song 182: "Shoulda Woulda"
# Song 183: "Love Of My Life"
# Song 184: "Projects"
# Song 185: "M.O.H. (Money Over Hoes)"
# Song 186: "Black Cat (Kunta Kentae)"
# Song 187: "18"
# Song 188: "Rugrats"
# Song 189: "1k"
# Song 190: "Time and a Place"
# Song 191: "Here It Is"
# Song 192: "Sticky 1"
# Song 193: "Meant For Me"
# Song 194: "Take Me Away"
# Song 195: "Better Days"
# Song 196: "Never Imagine"
# Song 197: "Again"
# Song 198: "Benji’s"
# Song 199: "Thug Holiday (Freestyle)"
# Song 200: "I Remember"
# Song 201: "ProjectBaby Freestyle"
# Song 202: "Kill The Beat"
# Song 203: "Switchin’ Gears"
# Song 204: "Talk About It"
# Song 205: "Hatin On Me"
# Song 206: "Wet"
# Song 207: "Off A 14"
# Song 208: "Ain’t No Fakin’ It"
# Song 209: "Crazy"
# Song 210: "Paper Cha$in Haitian"
# Song 211: "I’m On"
# Song 212: "Stand Firm"
# Song 213: "Going Viral"
# Song 214: "Jail House Blues"
# Song 215: "Rodeo"
# Song 216: "Get It Up"
# Song 217: "Antisocial"
# Song 218: "Dead Time"
# Song 219: "The News"
# Song 220: "5 on it Freestyle"
# Song 221: "Right Now"
# Song 222: "Glow Up"
# Song 223: "Broward Paradise"
# Song 224: "Won’t Go Back"
# Song 225: "Conditioned (10 Toes Down Challenge)"
# Song 226: "Destin"
# Song 227: "Luv 2 Flex"
# Song 228: "My Time"
# Song 229: "I Get The Bag"
# Song 230: "Mystery"
# Song 231: "4th of July"
# Song 232: "Paper Boy"
# Song 233: "Don’t Understand"
# Song 234: "Down N Out (Freestyle)"
# Song 235: "10ToesDown Challenge Conditioned"
# Song 236: "Stay Solid"
# Song 237: "KKK"
# Song 238: "Lil Shoota Love"
# Song 239: "Too Many Years (Baauer Rewind)"
# Song 240: "KoKo (CoCo Remix)"
# Song 241: "Heart & Mind"
# Song 242: "Team No Sleep"
# "Skit" is not valid. Skipping.
# Song 243: "Where Ya At (First Day Out Anthem)"
# Song 244: "Jail Cell Song (I Don’t Know Where I’m Heading)"
# "Crack Baby Skit" is not valid. Skipping.
# Song 245: "MoshPit (Demo)"
# Song 246: "Afterlife"
# Song 247: "No Flocking 2"
# Song 248: "Testimony (Traduzione Italiana)"
# Song 249: "I Go"
# Song 250: "Tunnel Vision (Traduzione Italiana)"
# Song 251: "Every Time"
# Song 252: "Versace (Freestyle)"
# Song 253: "Need to Blow"
# Song 254: "Open Letter (Freestyle)"
# Song 255: "Idk"
# Song 256: "Untitled 2"
#  20%|██        | 2/10 [14:41<46:22, 347.85s/it]
# Done. Found 256 songs.
# Wrote Tunnel Vision to lyrics_kodakblack_tunnelvision.json.
# Wrote No Flockin to lyrics_kodakblack_noflockin.json.
# Wrote Roll in Peace to lyrics_kodakblack_rollinpeace.json.
# Wrote ZEZE to lyrics_kodakblack_zeze.json.
# Wrote SKRT to lyrics_kodakblack_skrt.json.
# Wrote There He Go to lyrics_kodakblack_therehego.json.
# Wrote Skrilla to lyrics_kodakblack_skrilla.json.
# Wrote Codeine Dreaming to lyrics_kodakblack_codeinedreaming.json.
# Wrote Transportin’ to lyrics_kodakblack_transportin.json.
# Wrote Too Many Years to lyrics_kodakblack_toomanyyears.json.
# Wrote Like Dat to lyrics_kodakblack_likedat.json.
# Wrote Calling My Spirit to lyrics_kodakblack_callingmyspirit.json.
# Wrote I.M.Y (I Miss You) to lyrics_kodakblack_i.m.yimissyou.json.
# Wrote Baby Girl to lyrics_kodakblack_babygirl.json.
# Wrote Institution to lyrics_kodakblack_institution.json.
# Wrote Patty Cake to lyrics_kodakblack_pattycake.json.
# Wrote Testimony to lyrics_kodakblack_testimony.json.
# Wrote Malcolm X.X.X. to lyrics_kodakblack_malcolmx.x.x..json.
# Wrote Versatile to lyrics_kodakblack_versatile.json.
# Wrote Conscience to lyrics_kodakblack_conscience.json.
# Wrote Don’t Wanna Breathe to lyrics_kodakblack_dontwannabreathe.json.
# Wrote First Day Out to lyrics_kodakblack_firstdayout.json.
# Wrote G to the A to lyrics_kodakblack_gtothea.json.
# Wrote Pimpin Ain’t Eazy to lyrics_kodakblack_pimpinainteazy.json.
# Wrote If I’m Lyin, I’m Flyin to lyrics_kodakblack_ifimlyinimflyin.json.
# Wrote Everything 1K to lyrics_kodakblack_everything1k.json.
# Wrote Snot Thot to lyrics_kodakblack_snotthot.json.
# Wrote Already to lyrics_kodakblack_already.json.
# Wrote Water to lyrics_kodakblack_water.json.
# Wrote 201519971800 to lyrics_kodakblack_201519971800.json.
# Wrote Young Prodigy to lyrics_kodakblack_youngprodigy.json.
# Wrote Halloween to lyrics_kodakblack_halloween.json.
# Wrote Can I to lyrics_kodakblack_cani.json.
# Wrote Gave It All I Got to lyrics_kodakblack_gaveitalligot.json.
# Wrote Expeditiously to lyrics_kodakblack_expeditiously.json.
# Wrote If You Ain’t Ridin’ to lyrics_kodakblack_ifyouaintridin.json.
# Wrote Vibin In This Bih to lyrics_kodakblack_vibininthisbih.json.
# Wrote Slayed to lyrics_kodakblack_slayed.json.
# Wrote Honey Bun to lyrics_kodakblack_honeybun.json.
# Wrote Day for Day to lyrics_kodakblack_dayforday.json.
# Wrote 6th Sense to lyrics_kodakblack_6thsense.json.
# Wrote Signs to lyrics_kodakblack_signs.json.
# Wrote News Or Something (Freestyle) to lyrics_kodakblack_newsorsomethingfreestyle.json.
# Wrote Purp to lyrics_kodakblack_purp.json.
# Wrote Gnarly to lyrics_kodakblack_gnarly.json.
# Wrote Fresh Out / My Struggle to lyrics_kodakblack_freshoutmystruggle.json.
# Wrote Coolin and Booted to lyrics_kodakblack_coolinandbooted.json.
# Wrote Could of Been Different to lyrics_kodakblack_couldofbeendifferent.json.
# Wrote Christmas in Miami to lyrics_kodakblack_christmasinmiami.json.
# Wrote Project Baby to lyrics_kodakblack_projectbaby.json.
# Wrote Unexplainable to lyrics_kodakblack_unexplainable.json.
# Wrote Corrlinks and JPay to lyrics_kodakblack_corrlinksandjpay.json.
# Wrote Take One to lyrics_kodakblack_takeone.json.
# Wrote Need a Break to lyrics_kodakblack_needabreak.json.
# Wrote Built My Legacy to lyrics_kodakblack_builtmylegacy.json.
# Wrote HollyHood to lyrics_kodakblack_hollyhood.json.
# Wrote From the Cradle to lyrics_kodakblack_fromthecradle.json.
# Wrote Roll in Peace (Remix) to lyrics_kodakblack_rollinpeaceremix.json.
# Wrote Running Outta Love to lyrics_kodakblack_runningouttalove.json.
# Wrote MoshPit to lyrics_kodakblack_moshpit.json.
# Wrote Today to lyrics_kodakblack_today.json.
# Wrote Save You to lyrics_kodakblack_saveyou.json.
# Wrote Close to the Grave to lyrics_kodakblack_closetothegrave.json.
# Wrote Down South to lyrics_kodakblack_downsouth.json.
# Wrote Heart to lyrics_kodakblack_heart.json.
# Wrote Dream Doll to lyrics_kodakblack_dreamdoll.json.
# Wrote No Flockin 2 (Bodak Orange) to lyrics_kodakblack_noflockin2bodakorange.json.
# Wrote Up in Here to lyrics_kodakblack_upinhere.json.
# Wrote Identity Theft to lyrics_kodakblack_identitytheft.json.
# Wrote Side Nigga to lyrics_kodakblack_sidenigga.json.
# Wrote Reminiscing to lyrics_kodakblack_reminiscing.json.
# Wrote Free Cool Pt.2 to lyrics_kodakblack_freecoolpt.2.json.
# Wrote Deep In These Streets to lyrics_kodakblack_deepinthesestreets.json.
# Wrote Fuck With You to lyrics_kodakblack_fuckwithyou.json.
# Wrote Me, Myself & I to lyrics_kodakblack_memyselfi.json.
# Wrote Roll N Peace 2 to lyrics_kodakblack_rollnpeace2.json.
# Wrote Big Bank to lyrics_kodakblack_bigbank.json.
# Wrote Change My Ways to lyrics_kodakblack_changemyways.json.
# Wrote Still Hittin Licks to lyrics_kodakblack_stillhittinlicks.json.
# Wrote XXL Freshman Freestyle: Kodak Black to lyrics_kodakblack_xxlfreshmanfreestylekodakblack.json.
# Wrote 1800 Nights (Kno The Meaning Freestyle) to lyrics_kodakblack_1800nightsknothemeaningfreestyle.json.
# Wrote First Love to lyrics_kodakblack_firstlove.json.
# Wrote 4th Quarter to lyrics_kodakblack_4thquarter.json.
# Wrote Off the Land to lyrics_kodakblack_offtheland.json.
# Wrote Loyal to lyrics_kodakblack_loyal.json.
# Wrote Molly to lyrics_kodakblack_molly.json.
# Wrote When Vultures Cry to lyrics_kodakblack_whenvulturescry.json.
# Wrote Snap Shit to lyrics_kodakblack_snapshit.json.
# Wrote U Ain’t Never to lyrics_kodakblack_uaintnever.json.
# Wrote Cut Throat to lyrics_kodakblack_cutthroat.json.
# Wrote Misunderstood to lyrics_kodakblack_misunderstood.json.
# Wrote In Too Deep to lyrics_kodakblack_intoodeep.json.
# Wrote Bill And Jill to lyrics_kodakblack_billandjill.json.
# Wrote Boss My Life Up to lyrics_kodakblack_bossmylifeup.json.
# Wrote Top Off Benz to lyrics_kodakblack_topoffbenz.json.
# Wrote Hungry to lyrics_kodakblack_hungry.json.
# Wrote I’m That Nigga to lyrics_kodakblack_imthatnigga.json.
# Wrote I Need Love to lyrics_kodakblack_ineedlove.json.
# Wrote Shit On Me to lyrics_kodakblack_shitonme.json.
# Wrote Fall Thru to lyrics_kodakblack_fallthru.json.
# Wrote Brand New Glizzy to lyrics_kodakblack_brandnewglizzy.json.
# Wrote Why They Call You Kodak to lyrics_kodakblack_whytheycallyoukodak.json.
# Wrote ThankFul to lyrics_kodakblack_thankful.json.
# Wrote Acting Weird to lyrics_kodakblack_actingweird.json.
# Wrote Why You Always Gotta Go to lyrics_kodakblack_whyyoualwaysgottago.json.
# Wrote Needing Something to lyrics_kodakblack_needingsomething.json.
# Wrote From The Ugly to lyrics_kodakblack_fromtheugly.json.
# Wrote Gospel to lyrics_kodakblack_gospel.json.
# Wrote Erykah Badu to lyrics_kodakblack_erykahbadu.json.
# Wrote Roll in Peace (Demo) to lyrics_kodakblack_rollinpeacedemo.json.
# Wrote Me for Me to lyrics_kodakblack_meforme.json.
# Wrote Spaz Out to lyrics_kodakblack_spazout.json.
# Wrote Just A Wrap (Freestyle) to lyrics_kodakblack_justawrapfreestyle.json.
# Wrote No CoDefendant to lyrics_kodakblack_nocodefendant.json.
# Wrote Time Never Mattered (Seeing Demons) (Do Not Disturb Freestyle) to lyrics_kodakblack_timenevermatteredseeingdemonsdonotdisturbfreestyle.json.
# Wrote No Meds to lyrics_kodakblack_nomeds.json.
# Wrote This Forever to lyrics_kodakblack_thisforever.json.
# Wrote Versatile 2 to lyrics_kodakblack_versatile2.json.
# Wrote Candy Paint to lyrics_kodakblack_candypaint.json.
# Wrote Twenty 8 to lyrics_kodakblack_twenty8.json.
# Wrote In the Flesh to lyrics_kodakblack_intheflesh.json.
# Wrote Real Nigga Files to lyrics_kodakblack_realniggafiles.json.
# Wrote Transgression to lyrics_kodakblack_transgression.json.
# Wrote 30 to lyrics_kodakblack_30.json.
# Wrote The Recipe to lyrics_kodakblack_therecipe.json.
# Wrote Feb 14 to lyrics_kodakblack_feb14.json.
# Wrote I N U to lyrics_kodakblack_inu.json.
# Wrote Chances to lyrics_kodakblack_chances.json.
# Wrote My Klik to lyrics_kodakblack_myklik.json.
# Wrote Ambition (I’m 14 And Already Thinking About Death) to lyrics_kodakblack_ambitionim14andalreadythinkingaboutdeath.json.
# Wrote Hate Being Alone to lyrics_kodakblack_hatebeingalone.json.
# Wrote Ran Up A Check to lyrics_kodakblack_ranupacheck.json.
# Wrote Boost My Ego to lyrics_kodakblack_boostmyego.json.
# Wrote Poetical G to lyrics_kodakblack_poeticalg.json.
# Wrote No Feelings to lyrics_kodakblack_nofeelings.json.
# Wrote Pride to lyrics_kodakblack_pride.json.
# Wrote Feeling Like to lyrics_kodakblack_feelinglike.json.
# Wrote Cell Therapy (Freestyle) to lyrics_kodakblack_celltherapyfreestyle.json.
# Wrote This Life to lyrics_kodakblack_thislife.json.
# Wrote I Need A Beat to lyrics_kodakblack_ineedabeat.json.
# Wrote You Do That Shit to lyrics_kodakblack_youdothatshit.json.
# Wrote Get Up to lyrics_kodakblack_getup.json.
# Wrote Free Cool to lyrics_kodakblack_freecool.json.
# Wrote Real Shit to lyrics_kodakblack_realshit.json.
# Wrote About You Without You to lyrics_kodakblack_aboutyouwithoutyou.json.
# Wrote Corrupted to lyrics_kodakblack_corrupted.json.
# Wrote Fed Up to lyrics_kodakblack_fedup.json.
# Wrote Letter to lyrics_kodakblack_letter.json.
# Wrote Blood Sweat Tears Revenge to lyrics_kodakblack_bloodsweattearsrevenge.json.
# Wrote 10 Toes Down to lyrics_kodakblack_10toesdown.json.
# Wrote Back On My Feet to lyrics_kodakblack_backonmyfeet.json.
# Wrote Project Baby 2 to lyrics_kodakblack_projectbaby2.json.
# Wrote Honest (Freestyle) to lyrics_kodakblack_honestfreestyle.json.
# Wrote Helluva Love to lyrics_kodakblack_helluvalove.json.
# Wrote Laudy to lyrics_kodakblack_laudy.json.
# Wrote Rock Bottom to lyrics_kodakblack_rockbottom.json.
# Wrote Kicking In to lyrics_kodakblack_kickingin.json.
# Wrote I Be On The Way to lyrics_kodakblack_ibeontheway.json.
# Wrote I Get Lonely to lyrics_kodakblack_igetlonely.json.
# Wrote Heart Of The Projects to lyrics_kodakblack_heartoftheprojects.json.
# Wrote Up Late to lyrics_kodakblack_uplate.json.
# Wrote I Wanna Rock to lyrics_kodakblack_iwannarock.json.
# Wrote Catch Flight to lyrics_kodakblack_catchflight.json.
# Wrote Call You to lyrics_kodakblack_callyou.json.
# Wrote Still in the Streets to lyrics_kodakblack_stillinthestreets.json.
# Wrote Str8 Bars Freestyle to lyrics_kodakblack_str8barsfreestyle.json.
# Wrote Believe This Shit to lyrics_kodakblack_believethisshit.json.
# Wrote Cognitive to lyrics_kodakblack_cognitive.json.
# Wrote Shake Back to lyrics_kodakblack_shakeback.json.
# Wrote My Cousin to lyrics_kodakblack_mycousin.json.
# Wrote Jewels (Whole Time) to lyrics_kodakblack_jewelswholetime.json.
# Wrote I Just Might to lyrics_kodakblack_ijustmight.json.
# Wrote Fuck It to lyrics_kodakblack_fuckit.json.
# Wrote Now Time to lyrics_kodakblack_nowtime.json.
# Wrote Killing It to lyrics_kodakblack_killingit.json.
# Wrote Manuvering to lyrics_kodakblack_manuvering.json.
# Wrote My Wrist to lyrics_kodakblack_mywrist.json.
# Wrote Yung Niggaz to lyrics_kodakblack_yungniggaz.json.
# Wrote Mama to lyrics_kodakblack_mama.json.
# Wrote Wake N Bake to lyrics_kodakblack_wakenbake.json.
# Wrote Pelican to lyrics_kodakblack_pelican.json.
# Wrote Shoulda Woulda to lyrics_kodakblack_shouldawoulda.json.
# Wrote Love Of My Life to lyrics_kodakblack_loveofmylife.json.
# Wrote Projects to lyrics_kodakblack_projects.json.
# Wrote M.O.H. (Money Over Hoes) to lyrics_kodakblack_m.o.h.moneyoverhoes.json.
# Wrote Black Cat (Kunta Kentae) to lyrics_kodakblack_blackcatkuntakentae.json.
# Wrote 18 to lyrics_kodakblack_18.json.
# Wrote Rugrats to lyrics_kodakblack_rugrats.json.
# Wrote 1k to lyrics_kodakblack_1k.json.
# Wrote Time and a Place to lyrics_kodakblack_timeandaplace.json.
# Wrote Here It Is to lyrics_kodakblack_hereitis.json.
# Wrote Sticky 1 to lyrics_kodakblack_sticky1.json.
# Wrote Meant For Me to lyrics_kodakblack_meantforme.json.
# Wrote Take Me Away to lyrics_kodakblack_takemeaway.json.
# Wrote Better Days to lyrics_kodakblack_betterdays.json.
# Wrote Never Imagine to lyrics_kodakblack_neverimagine.json.
# Wrote Again to lyrics_kodakblack_again.json.
# Wrote Benji’s to lyrics_kodakblack_benjis.json.
# Wrote Thug Holiday (Freestyle) to lyrics_kodakblack_thugholidayfreestyle.json.
# Wrote I Remember to lyrics_kodakblack_iremember.json.
# Wrote ProjectBaby Freestyle to lyrics_kodakblack_projectbabyfreestyle.json.
# Wrote Kill The Beat to lyrics_kodakblack_killthebeat.json.
# Wrote Switchin’ Gears to lyrics_kodakblack_switchingears.json.
# Wrote Talk About It to lyrics_kodakblack_talkaboutit.json.
# Wrote Hatin On Me to lyrics_kodakblack_hatinonme.json.
# Wrote Wet to lyrics_kodakblack_wet.json.
# Wrote Off A 14 to lyrics_kodakblack_offa14.json.
# Wrote Ain’t No Fakin’ It to lyrics_kodakblack_aintnofakinit.json.
# Wrote Crazy to lyrics_kodakblack_crazy.json.
# Wrote Paper Cha$in Haitian to lyrics_kodakblack_paperchainhaitian.json.
# Wrote I’m On to lyrics_kodakblack_imon.json.
# Wrote Stand Firm to lyrics_kodakblack_standfirm.json.
# Wrote Going Viral to lyrics_kodakblack_goingviral.json.
# Wrote Jail House Blues to lyrics_kodakblack_jailhouseblues.json.
# Wrote Rodeo to lyrics_kodakblack_rodeo.json.
# Wrote Get It Up to lyrics_kodakblack_getitup.json.
# Wrote Antisocial to lyrics_kodakblack_antisocial.json.
# Wrote Dead Time to lyrics_kodakblack_deadtime.json.
# Wrote The News to lyrics_kodakblack_thenews.json.
# Wrote 5 on it Freestyle to lyrics_kodakblack_5onitfreestyle.json.
# Wrote Right Now to lyrics_kodakblack_rightnow.json.
# Wrote Glow Up to lyrics_kodakblack_glowup.json.
# Wrote Broward Paradise to lyrics_kodakblack_browardparadise.json.
# Wrote Won’t Go Back to lyrics_kodakblack_wontgoback.json.
# Wrote Conditioned (10 Toes Down Challenge) to lyrics_kodakblack_conditioned10toesdownchallenge.json.
# Wrote Destin to lyrics_kodakblack_destin.json.
# Wrote Luv 2 Flex to lyrics_kodakblack_luv2flex.json.
# Wrote My Time to lyrics_kodakblack_mytime.json.
# Wrote I Get The Bag to lyrics_kodakblack_igetthebag.json.
# Wrote Mystery to lyrics_kodakblack_mystery.json.
# Wrote 4th of July to lyrics_kodakblack_4thofjuly.json.
# Wrote Paper Boy to lyrics_kodakblack_paperboy.json.
# Wrote Don’t Understand to lyrics_kodakblack_dontunderstand.json.
# Wrote Down N Out (Freestyle) to lyrics_kodakblack_downnoutfreestyle.json.
# Wrote 10ToesDown Challenge Conditioned to lyrics_kodakblack_10toesdownchallengeconditioned.json.
# Wrote Stay Solid to lyrics_kodakblack_staysolid.json.
# Wrote KKK to lyrics_kodakblack_kkk.json.
# Wrote Lil Shoota Love to lyrics_kodakblack_lilshootalove.json.
# Wrote Too Many Years (Baauer Rewind) to lyrics_kodakblack_toomanyyearsbaauerrewind.json.
# Wrote KoKo (CoCo Remix) to lyrics_kodakblack_kokococoremix.json.
# Wrote Heart & Mind to lyrics_kodakblack_heartmind.json.
# Wrote Team No Sleep to lyrics_kodakblack_teamnosleep.json.
# Wrote Where Ya At (First Day Out Anthem) to lyrics_kodakblack_whereyaatfirstdayoutanthem.json.
# Wrote Jail Cell Song (I Don’t Know Where I’m Heading) to lyrics_kodakblack_jailcellsongidontknowwhereimheading.json.
# Wrote MoshPit (Demo) to lyrics_kodakblack_moshpitdemo.json.
# Wrote Afterlife to lyrics_kodakblack_afterlife.json.
# Wrote No Flocking 2 to lyrics_kodakblack_noflocking2.json.
# Wrote Testimony (Traduzione Italiana) to lyrics_kodakblack_testimonytraduzioneitaliana.json.
# Wrote I Go to lyrics_kodakblack_igo.json.
# Wrote Tunnel Vision (Traduzione Italiana) to lyrics_kodakblack_tunnelvisiontraduzioneitaliana.json.
# Wrote Every Time to lyrics_kodakblack_everytime.json.
# Wrote Versace (Freestyle) to lyrics_kodakblack_versacefreestyle.json.
# Wrote Need to Blow to lyrics_kodakblack_needtoblow.json.
# Wrote Open Letter (Freestyle) to lyrics_kodakblack_openletterfreestyle.json.
# Wrote Idk to lyrics_kodakblack_idk.json.
# Wrote Untitled 2 to lyrics_kodakblack_untitled2.json.
# ----------Getting the # 143 artist----------
# Searching for songs by Inspectah Deck...
#
# Timeout raised and caught:
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ce28f6afa431> in <module>
#       3     time.sleep(0.5)
#       4     print('-'*10+'Getting the # '+ str(x+1)+' artist'+'-'*10)
# ----> 5     save_lyrics(artists_list[x],500)
#
# <ipython-input-5-15f565c8829c> in save_lyrics(artist, number_song)
#       1 #Function to find songs lyrics
#       2 def save_lyrics(artist,number_song):
# ----> 3     return search_song(artist,number_song).save_lyrics()
#
# <ipython-input-3-9ed02a29f5a8> in search_song(artist, number_song)
#       1 #building a search function to find a defined number of songs for an artist
#       2 def search_song(artist,number_song):
# ----> 3         results= api.search_artist(artist, max_songs=number_song)
#       4         return results
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id)
#     354                 else:
#     355                     info = {'song': song_info}
# --> 356                 song = Song(info, lyrics)
#     357
#     358                 # Attempt to add the Song to the Artist
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/song.py in __init__(self, json_dict, lyrics)
#      24             save_lyrics: Save the song lyrics to a JSON or TXT file.
#      25         """
# ---> 26         self._body = json_dict['song'] if 'song' in json_dict else json_dict
#      27         self._body['lyrics'] = lyrics
#      28         self._url = self._body['url']
#
# TypeError: argument of type 'NoneType' is not iterable
