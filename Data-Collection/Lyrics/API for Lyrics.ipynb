# %% [markdown]
# #### Helpers

# %%
import lyricsgenius as genius
from tqdm import tqdm
import time
import credentials as cd

# %%
#Authentification
api = genius.Genius(client_access_token=cd.access_token)

# %% [markdown]
# ### Functions

# %%
#building a search function to find a defined number of songs for an artist
def search_song(artist,number_song):
        results= api.search_artist(artist, max_songs=number_song)
        return results

# %%
#Function to find songs titles
def find_song_title(results):
    return [results.songs]

# %%
#Function to find songs lyrics
def save_lyrics(artist,number_song):
    return search_song(artist,number_song).save_lyrics()

# %% [markdown]
# ### Getting songs from the artists list

# %%
# Load file with all artists
import pickle

with open('../hip-hop-artist-ranker.pkl', 'rb') as f:
    artists_list = pickle.load(f)

# %%
#Checking correct list was imported
len(artists_list)
# Out:
# 814

# %%
#Saving lyrics for 100 artists
for x in tqdm(range(117,125)):
    time.sleep(0.5)
    print('-'*10+'Getting the # '+ str(x+1)+' artist'+'-'*10)
    save_lyrics(artists_list[x],500)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# ----------Getting the # 118 artist----------
# Searching for songs by Migos...
#
# Song 1: "Bad and Boujee"
# Song 2: "Versace (Remix)"
# Song 3: "T-Shirt"
# Song 4: "Slippery"
# Song 5: "Walk It Talk It"
# Song 6: "Stir Fry"
# Song 7: "Kelly Price"
# Song 8: "Narcos"
# Song 9: "Get Right Witcha"
# Song 10: "Fight Night"
# Song 11: "Handsome and Wealthy"
# Song 12: "Notice Me"
# Song 13: "Call Casting"
# Song 14: "Hannah Montana"
# Song 15: "Cocoon"
# Song 16: "Deadz"
# Song 17: "Freak No More"
# Song 18: "BBO (Bad Bitches Only)"
# Song 19: "Bando"
# Song 20: "China Town"
# Song 21: "What the Price"
# Song 22: "Gang Gang"
# Song 23: "Culture"
# Song 24: "Pipe It Up"
# Song 25: "Look At My Dab"
# Song 26: "Wishy Washy"
# Song 27: "Brown Paper Bag"
# Song 28: "White Sand"
# Song 29: "Cross The Country"
# Song 30: "Commando"
# Song 31: "Dab of Ranch"
# Song 32: "Antidope"
# Song 33: "Versace"
# Song 34: "All Ass"
# Song 35: "One Time"
# Song 36: "Big on Big"
# Song 37: "Supastars"
# Song 38: "Out Yo Way"
# Song 39: "Ounces"
# Song 40: "Higher We Go (Intro)"
# Song 41: "Birds"
# Song 42: "Emoji a Chain"
# Song 43: "Shooters"
# Song 44: "New Atlanta"
# Song 45: "Too Playa"
# Song 46: "Can’t Go Out Sad"
# Song 47: "Emmitt Smith"
# Song 48: "Beast"
# Song 49: "Movin’ Too Fast"
# Song 50: "Auto Pilot"
# Song 51: "CC"
# Song 52: "Pussy Ass Bitch Freestyle"
# Song 53: "Jealousy"
# Song 54: "Rich Then Famous (Intro)"
# Song 55: "Where Were You"
# Song 56: "First 48"
# Song 57: "Made Men"
# Song 58: "Islands"
# Song 59: "In Too Deep"
# Song 60: "Too Much Jewelry"
# Song 61: "Adios"
# Song 62: "John Wick"
# "I Decided. [Tracklist + Album Art]" is not valid. Skipping.
# Song 63: "Say Sum"
# Song 64: "Migo Dreams"
# Song 65: "Young Rich Niggas (No Label 2)"
# Song 66: "Chirpin’"
# Song 67: "3 Way (Intro)"
# Song 68: "WOA"
# Song 69: "Peek A Boo"
# Song 70: "Out The Gym (Remix)"
# Song 71: "Open It Up"
# Song 72: "Top Down on da NAWF"
# Song 73: "Culture National Anthem (Outro)"
# Song 74: "Fuck 12"
# Song 75: "Bakers Man"
# Song 76: "Copy Me"
# Song 77: "YRH"
# Song 78: "R.I.P"
# Song 79: "Work Hard"
# Song 80: "Hit Em"
# Song 81: "Bars"
# Song 82: "M&M’s"
# Song 83: "Hot Boy"
# Song 84: "Flooded"
# Song 85: "Cocaina"
# Song 86: "Brokanese"
# Song 87: "Highway 85"
# Song 88: "Cocoon (Remix)"
# Song 89: "No Label 2 (Intro)"
# Song 90: "Crown the Kings"
# Song 91: "YRN 2 (Intro)"
# Song 92: "Young Rich Niggas"
# Song 93: "Finesser"
# Song 94: "FEMA"
# Song 95: "Dab Daddy"
# Song 96: "We Ready (Remix)"
# Song 97: "All Good"
# Song 98: "Stripper Bowl"
# Song 99: "You Wanna See"
# Song 100: "Migos Origin"
# Song 101: "Fire In The Booth"
# Song 102: "Forest Whitaker"
# Song 103: "Contraband"
# Song 104: "Take Her"
# Song 105: "Slide On Em"
# Song 106: "Cook It Up"
# Song 107: "Tim Westwood Freestyle"
# Song 108: "YRN"
# Song 109: "Add It Up"
# Song 110: "Say So"
# Song 111: "Stay"
# Song 112: "9 On Me"
# Song 113: "No Fuckin Wit"
# Song 114: "Struggle"
# Song 115: "Rich Nigga Timeline"
# Song 116: "Trenchez"
# Song 117: "Plan B"
# Song 118: "Hoe On A Mission"
# Song 119: "Black Bottles"
# Song 120: "Trap Dab Freestyle"
# Song 121: "Who The Hell"
# Song 122: "Just for Tonight"
# Song 123: "Trippin"
# Song 124: "Body Parts"
# Song 125: "Dennis Rodman"
# Song 126: "Wrist Game"
# Song 127: "Computers (Freestyle)"
# Song 128: "Charles Barkley"
# Song 129: "Thank You God (Outro)"
# Song 130: "Pop That"
# Song 131: "MuhFuckn Tired"
# Song 132: "Pronto"
# Song 133: "Chances"
# Song 134: "Pretty Little Lady"
# Song 135: "Came From Nothing"
# Song 136: "Pound Cake (Freestyle)"
# Song 137: "Built Like Me"
# Song 138: "Trap Problems"
# Song 139: "Coppers and Robbers"
# Song 140: "Nawfside"
# Song 141: "11 Birds"
# Song 142: "Trap Queen (Remix)"
# Song 143: "Flying Coach"
# Song 144: "Just Wait On It"
# Song 145: "You A Foo"
# Song 146: "Pull Up"
# Song 147: "Seize the Block"
# Song 148: "Memoirs"
# Song 149: "Top Floor"
# Song 150: "Playa Playa"
# Song 151: "Move"
# Song 152: "Payola"
# Song 153: "1017"
# Song 154: "Switch A Roo"
# Song 155: "Unleashed"
# Song 156: "Fall Back"
# Song 157: "Is You Ready"
# Song 158: "Savages Only"
# Song 159: "Back To the Bando"
# Song 160: "Kidding Me"
# "OVO Sound Radio Episode 37 Tracklist" is not valid. Skipping.
# Song 161: "Apeshit (Demo)"
# Song 162: "Mama We Rich"
# Song 163: "What Y’all Doin"
# Song 164: "Story I Tell"
# Song 165: "Ain’t Mine"
# Song 166: "Snap Of My Sack"
# Song 167: "Position to Win"
# Song 168: "Came To Party"
# Song 169: "Check"
# Song 170: "Case Closed"
# Song 171: "Trouble"
# Song 172: "Hate It or Love It"
# Song 173: "Night Time"
# Song 174: "Can’t Believe It"
# Song 175: "Spray the Champagne"
# Song 176: "Chapter 1"
# Song 177: "OKC"
# Song 178: "Ran Up The Money"
# Song 179: "Where"
# Song 180: "Bachelor"
# Song 181: "Hannah Montana (Twerk Remix)"
# Song 182: "Fuck Up The Pot"
# Song 183: "Take My Soul"
# Song 184: "Get Down"
# Song 185: "Versace (G-Mix)"
# Song 186: ".Wav Radio Freestyle"
# Song 187: "First Day Out"
# Song 188: "They Can’t Win"
# Song 189: "See What I’m Saying (Intro)"
# Song 190: "Fake Watch Busta"
# Song 191: "They Don’t Know (Remix)"
# Song 192: "Shawn Kemp"
# Song 193: "Plug Talk"
# Song 194: "Problems"
# Song 195: "Aight"
# Song 196: "Dope In My Sock"
# Song 197: "Gangsta Rap"
# Song 198: "Now"
# Song 199: "Fucked Up The Kitchen"
# Song 200: "Pack Gone Missing"
# Song 201: "I’m Gucci"
# Song 202: "Rich Nigga Still Trappin’"
# Song 203: "Recognition"
# Song 204: "Do You Love Me"
# Song 205: "Street Nigga Sacrifice"
# Song 206: "Conversation"
# Song 207: "Fucking Up Profits"
# Song 208: "Clientele"
# Song 209: "New Time*"
# Song 210: "Roll On"
# Song 211: "Migo Pablo"
# Song 212: "Hotpocket"
# Song 213: "Neva Fall Off"
# Song 214: "Money Counter"
# Song 215: "Pamela"
# Song 216: "T-Shirt (Spotify Mix)"
# Song 217: "Think Twice"
# Song 218: "Bad and Boujee (ZHU Remix)"
# "Late Nights [Tracklist + Album Cover]" is not valid. Skipping.
# Song 219: "Dirty"
# Song 220: "People’s Elbow"
# Song 221: "What You Doin"
# Song 222: "Falisha"
# Song 223: "Mama We Made It"
# Song 224: "Buyin Em"
# Song 225: "2Pac & Biggie"
# Song 226: "Trap Funk"
# Song 227: "Undelay"
# Song 228: "Drip (Remix)"
# Song 229: "Asking For Money"
# Song 230: "Scooby & Shaggy"
# Song 231: "What a Feeling"
# Song 232: "I Just Wanna"
# Song 233: "Show’ll Is"
# "Streets on Lock 5 [Tracklist + Cover Art]" is not valid. Skipping.
# Song 234: "Naw For Real"
# Song 235: "Burnt Out"
# Song 236: "Dramatic"
# Song 237: "Yes Sir*"
# Song 238: "Pipe It Up (Remix)"
# Song 239: "Bad and Boujee (Remix)"
# Song 240: "Shmoney Never Stop"
# Song 241: "Talk More Than Bitches"
# Song 242: "Sway In The Morning Freestyle (1/25/17)"
# Song 243: "Bad and Boujee (Remix 2)"
# Song 244: "Neighborhood Scientists"
# Song 245: "Free Offset (Freestyle)"
# ".Wav Radio Episode 9 Tracklist" is not valid. Skipping.
# Song 246: "Facts"
# Song 247: "Send Me Pack"
# Song 248: "Trust Nobody"
# Song 249: "Huncho Season*"
# Song 250: "Dab"
# Song 251: "Kelly Price (Remix)"
# Song 252: "Trap Life"
# Song 253: "3 Mics"
# Song 254: "In Yo Life"
# Song 255: "Lambo Doors"
# Song 256: "Flexin’"
# Song 257: "Seen Alot"
# Song 258: "Life So Hard"
# Song 259: "No Cap"
# Song 260: "Camera Flash"
# Song 261: "50 Bitches (Lick It Off)"
# Song 262: "Jumpin’ Like Jordan Remix"
# Song 263: "Fly With A Fish"
# Song 264: "Dirk Nowitzki"
# Song 265: "Slanging"
# Song 266: "All Over Me"
# Song 267: "Days Of The Week"
# Song 268: "Since Day 1"
# Song 269: "No Mediocre (Remix)"
# Song 270: "Streets Need Us (Outro)"
# Song 271: "U Dnt Know"
# Song 272: "Kick the Door Down"
# Song 273: "Water Bitch"
# Song 274: "Dirty Stick"
# Song 275: "Goin’ Down"
# Song 276: "Bags"
# Song 277: "Sadam Usane"
# Song 278: "Flex"
# Song 279: "Phone Ringing"
# Song 280: "QC Addiction"
# Song 281: "Mr. Miyagi"
# Song 282: "Bedloo"
# Song 283: "Bankroll"
# Song 284: "Slam Dunk"
# Song 285: "Dirty Dancing"
# Song 286: "Wrist In The Water"
# Song 287: "Carbon"
# Song 288: "Rocky Balboa"
# Song 289: "Dr Dolittle"
# Song 290: "Pull Out"
# Song 291: "Quarter Million Dollars"
# Song 292: "Bando To Mansion"
# Song 293: "Richer Than Rappers"
# Song 294: "Juug Season"
# Song 295: "Lean like dis"
# Song 296: "Green Light District"
# "No Label [Tracklist + Album Art]" is not valid. Skipping.
# Song 297: "Wide Awake*"
# Song 298: "Nawf On Da Map"
# Song 299: "Harassing"
# Song 300: "Off The Road To The Trap"
# Song 301: "Wop"
# Song 302: "Intro (Takeoff Shooter)"
# Song 303: "Tony Tiger"
# Song 304: "Real Street Nigga"
# Song 305: "Goin’ Threw It"
# Song 306: "T-Shirt(Migos)"
# Song 307: "50 Chicks"
# Song 308: "Wide Open"
# Song 309: "Work"
# Song 310: "Ten Plus Ten"
# Song 311: "Smell Me"
# Song 312: "Water Whip"
# Song 313: "England"
# Song 314: "Getting To Tha Money"
# Song 315: "Holmes"
# Song 316: "No U Can’t"
# Song 317: "Packs"
# Song 318: "Hit Juug"
# Song 319: "Own Lane"
# Song 320: "Pour Out The Seal"
# Song 321: "Some Mo Shit"
# Song 322: "Story Of YRN"
# Song 323: "Stay Up"
# Song 324: "Ion Need No Label"
# Song 325: "I Told You"
# Song 326: "C O M I N G S O O N"
# Timeout raised and caught:
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-e6b8588591b6> in <module>
#       3     time.sleep(0.5)
#       4     print('-'*10+'Getting the # '+ str(x+1)+' artist'+'-'*10)
# ----> 5     save_lyrics(artists_list[x],500)
#
# <ipython-input-5-15f565c8829c> in save_lyrics(artist, number_song)
#       1 #Function to find songs lyrics
#       2 def save_lyrics(artist,number_song):
# ----> 3     return search_song(artist,number_song).save_lyrics()
#
# <ipython-input-3-9ed02a29f5a8> in search_song(artist, number_song)
#       1 #building a search function to find a defined number of songs for an artist
#       2 def search_song(artist,number_song):
# ----> 3         results= api.search_artist(artist, max_songs=number_song)
#       4         return results
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id)
#     354                 else:
#     355                     info = {'song': song_info}
# --> 356                 song = Song(info, lyrics)
#     357
#     358                 # Attempt to add the Song to the Artist
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/song.py in __init__(self, json_dict, lyrics)
#      24             save_lyrics: Save the song lyrics to a JSON or TXT file.
#      25         """
# ---> 26         self._body = json_dict['song'] if 'song' in json_dict else json_dict
#      27         self._body['lyrics'] = lyrics
#      28         self._url = self._body['url']
#
# TypeError: argument of type 'NoneType' is not iterable
