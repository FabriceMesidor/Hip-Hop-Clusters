# %% [markdown]
# #### Helpers

# %%
import lyricsgenius as genius
from tqdm import tqdm
import time
import credentials as cd

# %%
#Authentification
api = genius.Genius(client_access_token=cd.access_token)

# %% [markdown]
# ### Functions

# %%
#building a search function to find a defined number of songs for an artist
def search_song(artist,number_song):
        results= api.search_artist(artist, max_songs=number_song)
        return results

# %%
#Function to find songs titles
def find_song_title(results):
    return [results.songs]

# %%
#Function to find songs lyrics
def save_lyrics(artist,number_song):
    return search_song(artist,number_song).save_lyrics()

# %% [markdown]
# ### Getting songs from the artists list

# %%
# Load file with all artists
import pickle

with open('../hip-hop-artist-ranker.pkl', 'rb') as f:
    artists_list = pickle.load(f)

# %%
#Checking correct list was imported
len(artists_list)
# Out:
# 814

# %%
#Saving lyrics for 100 artists
for x in tqdm(range(166,200)):
    time.sleep(0.5)
    print('-'*10+'Getting the # '+ str(x+1)+' artist'+'-'*10)
    save_lyrics(artists_list[x],500)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ----------Getting the # 151 artist----------
# Searching for songs by Ab-Soul...
#
# Song 1: "Terrorist Threats"
# Song 2: "ILLuminate"
# Song 3: "Pineal Gland"
# Song 4: "Black Lip Bastard (Remix)"
# Song 5: "The Book of Soul"
# Song 6: "Turn Me Up"
# Song 7: "The End Is Near"
# Song 8: "Nibiru"
# Song 9: "D.R.U.G.S."
# Song 10: "Bohemian Grove"
# Song 11: "Huey Knew THEN"
# Song 12: "Track Two"
# Song 13: "SOPA"
# Song 14: "Tree of Life"
# Song 15: "W.R.O.H"
# Song 16: "Threatening Nature"
# Song 17: "Hunnid Stax"
# Song 18: "RAW (Backwards)"
# Song 19: "Double Standards"
# Song 20: "Stigmata"
# Song 21: "Empathy"
# Song 22: "Soulo Ho3"
# Song 23: "Mixed Emotions"
# Song 24: "Ride Slow"
# Song 25: "Gone Insane"
# Song 26: "The Law"
# Song 27: "God’s Reign"
# Song 28: "Closure"
# Song 29: "Beautiful Death"
# Song 30: "Just Have Fun"
# Song 31: "YMF"
# Song 32: "Only 1"
# Song 33: "These Days"
# Song 34: "Moscato"
# Song 35: "World Runners"
# Song 36: "Nothin’ New"
# Song 37: "Womanogamy"
# Song 38: "Kendrick Lamar’s Interlude"
# Song 39: "Dub Sac"
# Song 40: "Lust Demons"
# Song 41: "Braille"
# Song 42: "Rapper Shit"
# Song 43: "INvocation"
# Song 44: "Showin’ Love"
# Song 45: "Soul Cry"
# Song 46: "Sapiosexual"
# Song 47: "Evil Genius"
# Song 48: "Beat the Case / / / Straight Crooked"
# Song 49: "Wifey vs. WiFi / / / P.M.S."
# Song 50: "Nothing’s Something"
# Song 51: "Black Lip Bastard"
# Song 52: "A Rebellion"
# Song 53: "Lonely Soul / / / The Law (Prelude)"
# Song 54: "Christopher DRONEr"
# Song 55: "God’s a Girl?"
# Song 56: "Portishead in the Morning / / / HER World"
# Song 57: "Nevermind That"
# Song 58: "47 Bars"
# Song 59: "Now You Know"
# Song 60: "Pass The Blunt"
# Song 61: "Real Thinkers"
# Song 62: "Can Anybody Hear Me"
# Song 63: "Hell Yeah"
# Song 64: "Twact"
# Song 65: "Feelin’ Us"
# Song 66: "T.D.U.D."
# Song 67: "XXL Freshman Freestyle: Ab-Soul"
# Song 68: "Time is of the Essence"
# Song 69: "Mayday"
# Song 70: "Drift Away"
# Song 71: "Day in the Life"
# Song 72: "Dictionary Rap"
# Song 73: "Be A Man"
# Song 74: "Almost There"
# "Do What Thou Wilt. [Tracklist + Album Artwork]" is not valid. Skipping.
# Song 75: "Loosen my Tie"
# Song 76: "More of a Euphoria"
# Song 77: "Ab-Soul"
# Song 78: "Constipation"
# Song 79: "OnDaSpot Freestyle"
# Song 80: "#LTM"
# Song 81: "Passion"
# Song 82: "Long Term 2"
# Song 83: "Bankrupt"
# Song 84: "My Dream Girl"
# "Control System [Tracklist & Cover Art]" is not valid. Skipping.
# Song 85: "W.W.S.D."
# Song 86: "Back Then"
# Song 87: "Fame"
# Song 88: "Picture That"
# Song 89: "Rush"
# "C4 [Tracklist + Artwork]" is not valid. Skipping.
# Song 90: "Big Pay Back"
# Song 91: "Still A Regular Nigga"
# Song 92: "Thought It Was Love"
# Song 93: "100 Yard Dash"
# Song 94: "Absolute Assassin"
# Song 95: "No Pressure"
# Song 96: "Regular Nigga"
# Song 97: "Me & Ms. Pain"
# Song 98: "Livin’ Like"
# Song 99: "Ab-Soul’s Tattoos"
# Song 100: "All Feelin’"
# Song 101: "16 Bars (Freestyle)"
# Song 102: "Studio Life"
# Song 103: "Black & Mild"
# Song 104: "House Party 5"
# Song 105: "To The Max"
# Song 106: "Blow Them Horns II"
# "These Days Album Art" is not valid. Skipping.
# Song 107: "Watch Yo Lady"
# Song 108: "Lyrically Speaking"
# Song 109: "Life Is Crazy"
# Song 110: "Solo"
# Song 111: "Trouble"
# Song 112: "Run Tha Show"
# Song 113: "Rosemary’s Baby"
# Song 114: "Introduction"
# Song 115: "Budget Ballin"
# Song 116: "Writer’s Block"
# Song 117: "Murder You Rappers"
# Song 118: "Long Term"
# Song 119: "Mr. AB-SOULutely"
# "Longterm: The Mixtape Album Art & Tracklist" is not valid. Skipping.
# Song 120: "Incomplete Freestyle"
# Song 121: "Donnie Brasco"
# Song 122: "World Wide Web"
# Song 123: "Gutter"
# Song 124: "I’m a G"
# Song 125: "’07 Soulo (Unreleased)"
# Song 126: "Untold Story"
# Song 127: "Backroom Freestyle"
# "Long Term 2 - Album Art" is not valid. Skipping.
# Song 128: "Minneapolis Freestyle"
# Song 129: "Showoff Freestyle"
# Song 130: "MTV RapFix Live Freestyle"
# Song 131: "Shade 45 Freestyle"
# Song 132: "Dreamin’"
# Song 133: "Showoff Radio Freestyle"
# Song 134: "The Real Hip Hop (Freestyle)"
# "Control System [Credits]" is not valid. Skipping.
# Song 135: "The Notch"
# Song 136: "Untitled"
# "These Days [Credits]" is not valid. Skipping.
# Song 137: "Anything"
# Song 138: "King Of Carson"
# Song 139: "Free Verse"
# Song 140: "Lifestyle"
# Song 141: "The Sound"
# Song 142: "Kitty Flip"
# Song 143: "Titsenas"
# Song 144: "Take ’Em There"
# "Longterm Mentality [Credits]" is not valid. Skipping.
# Song 145: "DJ Escalade Freestyle"
# Song 146: "Toad’s Place Freestyle"
# Song 147: "Angel"
# Song 148: "Champagne Wishes"
# Song 149: "Ab 4 Pres"
# Song 150: "Chicks Be On Me"
# Song 151: "The Belasco Theater Freestyle"
# Song 152: "Empty Regrets"
# "Dat Good Sound (Instrumental)" is not valid. Skipping.
# Song 153: "You’re Gone Single Art"
# Song 154: "Cool Out"
# Song 155: "Everspinning Tide"
#   2%|▏         | 1/50 [10:33<8:37:28, 633.65s/it]
# Song 156: "The Headline Reads"
# Done. Found 156 songs.
# Wrote Terrorist Threats to lyrics_absoul_terroristthreats.json.
# Wrote ILLuminate to lyrics_absoul_illuminate.json.
# Wrote Pineal Gland to lyrics_absoul_pinealgland.json.
# Wrote Black Lip Bastard (Remix) to lyrics_absoul_blacklipbastardremix.json.
# Wrote The Book of Soul to lyrics_absoul_thebookofsoul.json.
# Wrote Turn Me Up to lyrics_absoul_turnmeup.json.
# Wrote The End Is Near to lyrics_absoul_theendisnear.json.
# Wrote Nibiru to lyrics_absoul_nibiru.json.
# Wrote D.R.U.G.S. to lyrics_absoul_d.r.u.g.s..json.
# Wrote Bohemian Grove to lyrics_absoul_bohemiangrove.json.
# Wrote Huey Knew THEN to lyrics_absoul_hueyknewthen.json.
# Wrote Track Two to lyrics_absoul_tracktwo.json.
# Wrote SOPA to lyrics_absoul_sopa.json.
# Wrote Tree of Life to lyrics_absoul_treeoflife.json.
# Wrote W.R.O.H to lyrics_absoul_w.r.o.h.json.
# Wrote Threatening Nature to lyrics_absoul_threateningnature.json.
# Wrote Hunnid Stax to lyrics_absoul_hunnidstax.json.
# Wrote RAW (Backwards) to lyrics_absoul_rawbackwards.json.
# Wrote Double Standards to lyrics_absoul_doublestandards.json.
# Wrote Stigmata to lyrics_absoul_stigmata.json.
# Wrote Empathy to lyrics_absoul_empathy.json.
# Wrote Soulo Ho3 to lyrics_absoul_souloho3.json.
# Wrote Mixed Emotions to lyrics_absoul_mixedemotions.json.
# Wrote Ride Slow to lyrics_absoul_rideslow.json.
# Wrote Gone Insane to lyrics_absoul_goneinsane.json.
# Wrote The Law to lyrics_absoul_thelaw.json.
# Wrote God’s Reign to lyrics_absoul_godsreign.json.
# Wrote Closure to lyrics_absoul_closure.json.
# Wrote Beautiful Death to lyrics_absoul_beautifuldeath.json.
# Wrote Just Have Fun to lyrics_absoul_justhavefun.json.
# Wrote YMF to lyrics_absoul_ymf.json.
# Wrote Only 1 to lyrics_absoul_only1.json.
# Wrote These Days to lyrics_absoul_thesedays.json.
# Wrote Moscato to lyrics_absoul_moscato.json.
# Wrote World Runners to lyrics_absoul_worldrunners.json.
# Wrote Nothin’ New to lyrics_absoul_nothinnew.json.
# Wrote Womanogamy to lyrics_absoul_womanogamy.json.
# Wrote Kendrick Lamar’s Interlude to lyrics_absoul_kendricklamarsinterlude.json.
# Wrote Dub Sac to lyrics_absoul_dubsac.json.
# Wrote Lust Demons to lyrics_absoul_lustdemons.json.
# Wrote Braille to lyrics_absoul_braille.json.
# Wrote Rapper Shit to lyrics_absoul_rappershit.json.
# Wrote INvocation to lyrics_absoul_invocation.json.
# Wrote Showin’ Love to lyrics_absoul_showinlove.json.
# Wrote Soul Cry to lyrics_absoul_soulcry.json.
# Wrote Sapiosexual to lyrics_absoul_sapiosexual.json.
# Wrote Evil Genius to lyrics_absoul_evilgenius.json.
# Wrote Beat the Case / / / Straight Crooked to lyrics_absoul_beatthecasestraightcrooked.json.
# Wrote Wifey vs. WiFi / / / P.M.S. to lyrics_absoul_wifeyvs.wifip.m.s..json.
# Wrote Nothing’s Something to lyrics_absoul_nothingssomething.json.
# Wrote Black Lip Bastard to lyrics_absoul_blacklipbastard.json.
# Wrote A Rebellion to lyrics_absoul_arebellion.json.
# Wrote Lonely Soul / / / The Law (Prelude) to lyrics_absoul_lonelysoulthelawprelude.json.
# Wrote Christopher DRONEr to lyrics_absoul_christopherdroner.json.
# Wrote God’s a Girl? to lyrics_absoul_godsagirl.json.
# Wrote Portishead in the Morning / / / HER World to lyrics_absoul_portisheadinthemorningherworld.json.
# Wrote Nevermind That to lyrics_absoul_nevermindthat.json.
# Wrote 47 Bars to lyrics_absoul_47bars.json.
# Wrote Now You Know to lyrics_absoul_nowyouknow.json.
# Wrote Pass The Blunt to lyrics_absoul_passtheblunt.json.
# Wrote Real Thinkers to lyrics_absoul_realthinkers.json.
# Wrote Can Anybody Hear Me to lyrics_absoul_cananybodyhearme.json.
# Wrote Hell Yeah to lyrics_absoul_hellyeah.json.
# Wrote Twact to lyrics_absoul_twact.json.
# Wrote Feelin’ Us to lyrics_absoul_feelinus.json.
# Wrote T.D.U.D. to lyrics_absoul_t.d.u.d..json.
# Wrote XXL Freshman Freestyle: Ab-Soul to lyrics_absoul_xxlfreshmanfreestyleabsoul.json.
# Wrote Time is of the Essence to lyrics_absoul_timeisoftheessence.json.
# Wrote Mayday to lyrics_absoul_mayday.json.
# Wrote Drift Away to lyrics_absoul_driftaway.json.
# Wrote Day in the Life to lyrics_absoul_dayinthelife.json.
# Wrote Dictionary Rap to lyrics_absoul_dictionaryrap.json.
# Wrote Be A Man to lyrics_absoul_beaman.json.
# Wrote Almost There to lyrics_absoul_almostthere.json.
# Wrote Loosen my Tie to lyrics_absoul_loosenmytie.json.
# Wrote More of a Euphoria to lyrics_absoul_moreofaeuphoria.json.
# Wrote Ab-Soul to lyrics_absoul_absoul.json.
# Wrote Constipation to lyrics_absoul_constipation.json.
# Wrote OnDaSpot Freestyle to lyrics_absoul_ondaspotfreestyle.json.
# Wrote #LTM to lyrics_absoul_ltm.json.
# Wrote Passion to lyrics_absoul_passion.json.
# Wrote Long Term 2 to lyrics_absoul_longterm2.json.
# Wrote Bankrupt to lyrics_absoul_bankrupt.json.
# Wrote My Dream Girl to lyrics_absoul_mydreamgirl.json.
# Wrote W.W.S.D. to lyrics_absoul_w.w.s.d..json.
# Wrote Back Then to lyrics_absoul_backthen.json.
# Wrote Fame to lyrics_absoul_fame.json.
# Wrote Picture That to lyrics_absoul_picturethat.json.
# Wrote Rush to lyrics_absoul_rush.json.
# Wrote Big Pay Back to lyrics_absoul_bigpayback.json.
# Wrote Still A Regular Nigga to lyrics_absoul_stillaregularnigga.json.
# Wrote Thought It Was Love to lyrics_absoul_thoughtitwaslove.json.
# Wrote 100 Yard Dash to lyrics_absoul_100yarddash.json.
# Wrote Absolute Assassin to lyrics_absoul_absoluteassassin.json.
# Wrote No Pressure to lyrics_absoul_nopressure.json.
# Wrote Regular Nigga to lyrics_absoul_regularnigga.json.
# Wrote Me & Ms. Pain to lyrics_absoul_mems.pain.json.
# Wrote Livin’ Like to lyrics_absoul_livinlike.json.
# Wrote Ab-Soul’s Tattoos to lyrics_absoul_absoulstattoos.json.
# Wrote All Feelin’ to lyrics_absoul_allfeelin.json.
# Wrote 16 Bars (Freestyle) to lyrics_absoul_16barsfreestyle.json.
# Wrote Studio Life to lyrics_absoul_studiolife.json.
# Wrote Black & Mild to lyrics_absoul_blackmild.json.
# Wrote House Party 5 to lyrics_absoul_houseparty5.json.
# Wrote To The Max to lyrics_absoul_tothemax.json.
# Wrote Blow Them Horns II to lyrics_absoul_blowthemhornsii.json.
# Wrote Watch Yo Lady to lyrics_absoul_watchyolady.json.
# Wrote Lyrically Speaking to lyrics_absoul_lyricallyspeaking.json.
# Wrote Life Is Crazy to lyrics_absoul_lifeiscrazy.json.
# Wrote Solo to lyrics_absoul_solo.json.
# Wrote Trouble to lyrics_absoul_trouble.json.
# Wrote Run Tha Show to lyrics_absoul_runthashow.json.
# Wrote Rosemary’s Baby to lyrics_absoul_rosemarysbaby.json.
# Wrote Introduction to lyrics_absoul_introduction.json.
# Wrote Budget Ballin to lyrics_absoul_budgetballin.json.
# Wrote Writer’s Block to lyrics_absoul_writersblock.json.
# Wrote Murder You Rappers to lyrics_absoul_murderyourappers.json.
# Wrote Long Term to lyrics_absoul_longterm.json.
# Wrote Mr. AB-SOULutely to lyrics_absoul_mr.absoulutely.json.
# Wrote Incomplete Freestyle to lyrics_absoul_incompletefreestyle.json.
# Wrote Donnie Brasco to lyrics_absoul_donniebrasco.json.
# Wrote World Wide Web to lyrics_absoul_worldwideweb.json.
# Wrote Gutter to lyrics_absoul_gutter.json.
# Wrote I’m a G to lyrics_absoul_imag.json.
# Wrote ’07 Soulo (Unreleased) to lyrics_absoul_07soulounreleased.json.
# Wrote Untold Story to lyrics_absoul_untoldstory.json.
# Wrote Backroom Freestyle to lyrics_absoul_backroomfreestyle.json.
# Wrote Minneapolis Freestyle to lyrics_absoul_minneapolisfreestyle.json.
# Wrote Showoff Freestyle to lyrics_absoul_showofffreestyle.json.
# Wrote MTV RapFix Live Freestyle to lyrics_absoul_mtvrapfixlivefreestyle.json.
# Wrote Shade 45 Freestyle to lyrics_absoul_shade45freestyle.json.
# Wrote Dreamin’ to lyrics_absoul_dreamin.json.
# Wrote Showoff Radio Freestyle to lyrics_absoul_showoffradiofreestyle.json.
# Wrote The Real Hip Hop (Freestyle) to lyrics_absoul_therealhiphopfreestyle.json.
# Wrote The Notch to lyrics_absoul_thenotch.json.
# Wrote Untitled to lyrics_absoul_untitled.json.
# Wrote Anything to lyrics_absoul_anything.json.
# Wrote King Of Carson to lyrics_absoul_kingofcarson.json.
# Wrote Free Verse to lyrics_absoul_freeverse.json.
# Wrote Lifestyle to lyrics_absoul_lifestyle.json.
# Wrote The Sound to lyrics_absoul_thesound.json.
# Wrote Kitty Flip to lyrics_absoul_kittyflip.json.
# Wrote Titsenas to lyrics_absoul_titsenas.json.
# Wrote Take ’Em There to lyrics_absoul_takeemthere.json.
# Wrote DJ Escalade Freestyle to lyrics_absoul_djescaladefreestyle.json.
# Wrote Toad’s Place Freestyle to lyrics_absoul_toadsplacefreestyle.json.
# Wrote Angel to lyrics_absoul_angel.json.
# Wrote Champagne Wishes to lyrics_absoul_champagnewishes.json.
# Wrote Ab 4 Pres to lyrics_absoul_ab4pres.json.
# Wrote Chicks Be On Me to lyrics_absoul_chicksbeonme.json.
# Wrote The Belasco Theater Freestyle to lyrics_absoul_thebelascotheaterfreestyle.json.
# Wrote Empty Regrets to lyrics_absoul_emptyregrets.json.
# Wrote You’re Gone Single Art to lyrics_absoul_youregonesingleart.json.
# Wrote Cool Out to lyrics_absoul_coolout.json.
# Wrote Everspinning Tide to lyrics_absoul_everspinningtide.json.
# Wrote The Headline Reads to lyrics_absoul_theheadlinereads.json.
# ----------Getting the # 152 artist----------
# Searching for songs by YBN Nahmir...
#
# Song 1: "Rubbin Off the Paint"
# Song 2: "Bounce Out With That"
# Song 3: "The Race (Remix)"
# Song 4: "I Got A Stick"
# Song 5: "Glizzy Hella Geekin"
# Song 6: "Letter To Valley Pt. 5"
# Song 7: "Gucci Gang (Remix)"
# Song 8: "No Relations"
# Song 9: "Change"
# Song 10: "Bail Out"
# Song 11: "Opp Stoppa"
# Song 12: "Up-Top Baby"
# Song 13: "Bounce Out With That (Remix)"
# Song 14: "Fuck It Up"
# Song 15: "Man Down"
# Song 16: "Popped Up"
# Song 17: "Sticked Up"
# Song 18: "If I Wanna"
# Song 19: "Cake"
# Song 20: "YBN Nahmir - Faneto Remix"
# Song 21: "YBN Nahmir freestyle 92.3"
# Song 22: "Automatic"
# Song 23: "Have You Ever"
# Song 24: "Double Back"
# Song 25: "Letter To Valley Pt. 4"
# Song 26: "Teach You How"
# Song 27: "Baby 8"
# Song 28: "Feel Like"
# Song 29: "XXL Freshman Freestyle: YBN Nahmir"
# Song 30: "Act Up"
# Song 31: "Rock tha Party (Freestyle)"
# Song 32: "Ride 4 Me"
# Song 33: "All In"
# Song 34: "Stains"
# Song 35: "Get Rich"
# Song 36: "Traffic"
# Song 37: "Applying Pressure"
# Song 38: "Callin My Line"
# Song 39: "Bands"
# Song 40: "Back to Back"
# Song 41: "Tweak"
# Song 42: "Don’t Got Time"
# Song 43: "Mopsticks"
# Song 44: "The Mud"
# Song 45: "Letter 2 Valley Part. 5"
# Song 46: "OVO"
# Song 47: "Untouched"
# Song 48: "I Got A Bag"
# Song 49: "Two Seater*"
# Song 50: "Paper Route"
# Song 51: "Why You Bullshittin (Unreleased)"
# Song 52: "Co x Quad Studios B2 1*"
# Song 53: "Fetti"
# Song 54: "Press Up"
# Song 55: "LA Fitness"
# Song 56: "Twenty Foe’."
# Song 57: "Real Live"
# Song 58: "YBN"
# Song 59: "Low-Key"
# Song 60: "Say Bro"
# Song 61: "Gunna Niggas"
# Song 62: "Ride Tonight"
# Song 63: "Bounce 0ut With That"
# Song 64: "Spinnin"
# Song 65: "I Stamp"
# Song 66: "Off The Blessing"
# Song 67: "Out The Mud"
# Song 68: "I’m Still Stuck"
#   4%|▍         | 2/50 [13:52<6:42:28, 503.10s/it]
# Song 69: "Rubbin Off The Paint (Remix)*"
# Done. Found 69 songs.
# Wrote Rubbin Off the Paint to lyrics_ybnnahmir_rubbinoffthepaint.json.
# Wrote Bounce Out With That to lyrics_ybnnahmir_bounceoutwiththat.json.
# Wrote The Race (Remix) to lyrics_ybnnahmir_theraceremix.json.
# Wrote I Got A Stick to lyrics_ybnnahmir_igotastick.json.
# Wrote Glizzy Hella Geekin to lyrics_ybnnahmir_glizzyhellageekin.json.
# Wrote Letter To Valley Pt. 5 to lyrics_ybnnahmir_lettertovalleypt.5.json.
# Wrote Gucci Gang (Remix) to lyrics_ybnnahmir_guccigangremix.json.
# Wrote No Relations to lyrics_ybnnahmir_norelations.json.
# Wrote Change to lyrics_ybnnahmir_change.json.
# Wrote Bail Out to lyrics_ybnnahmir_bailout.json.
# Wrote Opp Stoppa to lyrics_ybnnahmir_oppstoppa.json.
# Wrote Up-Top Baby to lyrics_ybnnahmir_uptopbaby.json.
# Wrote Bounce Out With That (Remix) to lyrics_ybnnahmir_bounceoutwiththatremix.json.
# Wrote Fuck It Up to lyrics_ybnnahmir_fuckitup.json.
# Wrote Man Down to lyrics_ybnnahmir_mandown.json.
# Wrote Popped Up to lyrics_ybnnahmir_poppedup.json.
# Wrote Sticked Up to lyrics_ybnnahmir_stickedup.json.
# Wrote If I Wanna to lyrics_ybnnahmir_ifiwanna.json.
# Wrote Cake to lyrics_ybnnahmir_cake.json.
# Wrote YBN Nahmir - Faneto Remix to lyrics_ybnnahmir_ybnnahmirfanetoremix.json.
# Wrote YBN Nahmir freestyle 92.3 to lyrics_ybnnahmir_ybnnahmirfreestyle92.3.json.
# Wrote Automatic to lyrics_ybnnahmir_automatic.json.
# Wrote Have You Ever to lyrics_ybnnahmir_haveyouever.json.
# Wrote Double Back to lyrics_ybnnahmir_doubleback.json.
# Wrote Letter To Valley Pt. 4 to lyrics_ybnnahmir_lettertovalleypt.4.json.
# Wrote Teach You How to lyrics_ybnnahmir_teachyouhow.json.
# ----------Getting the # 153 artist----------
# Searching for songs by MC Ride...
#
# "Cut Throat (Instrumental)" is not valid. Skipping.
# Song 1: "Civic Duties"
# Song 2: "Aß"
#   6%|▌         | 3/50 [17:10<5:22:31, 411.74s/it]
# Done. Found 2 songs.
# Wrote Civic Duties to lyrics_mcride_civicduties.json.
# Wrote Aß to lyrics_mcride_aß.json.
# ----------Getting the # 154 artist----------
# Searching for songs by Young Buck...
#
# Song 1: "Stomp (Remix)"
# Song 2: "Get Buck"
# Song 3: "Shorty Wanna Ride"
# Song 4: "Let Me In"
# Song 5: "Bonafide Hustler"
# Song 6: "Bang Bang"
# Song 7: "Cocaine"
# Song 8: "Loco"
# Song 9: "Do It Like Me"
# Song 10: "Lose My Mind"
# Song 11: "U Ain’t Goin’ Nowhere"
# Song 12: "Don’t Need No Help"
# Song 13: "Prices on My Head"
# Song 14: "Black Gloves"
# Song 15: "Go Loco"
# Song 16: "I’m a Soldier"
# Song 17: "Life"
# Song 18: "Buss Yo’ Head"
# Song 19: "Taped Conversation"
# Song 20: "Come and Catch Me Nigga"
# Song 21: "Stomp"
# Song 22: "4 Kings"
# Song 23: "Foofy Freestyle (50 Cent Diss)"
# Song 24: "Slow Ya Roll"
# Song 25: "Hold On"
# Song 26: "Not This Time"
# Song 27: "Look at Me Now"
# Song 28: "Got Me On It"
# Song 29: "Trained To Go"
# Song 30: "The Bag Way"
# Song 31: "Back To The Old Me"
# Song 32: "Thou Shall"
# Song 33: "Count me out"
# Song 34: "Drug Money"
# Song 35: "Dope Boy"
# Song 36: "Stomp (feat. T.I. & Ludacris)"
# Song 37: "I Know You Want Me"
# Song 38: "Buck the World"
# Song 39: "Since Way Back"
# Song 40: "Can’t Lose"
# Song 41: "Free Young Buck (Freestyle)"
# Song 42: "Say It to My Face"
# Song 43: "I Ain’t Fucking Wit U!"
# Song 44: "Puff Puff Pass"
# Song 45: "Walk With Me"
# Song 46: "Proud Of You"
# Song 47: "Do it Myself"
# Song 48: "Laugh Now, Cry Later"
# Song 49: "Welcome to the South"
# Song 50: "Taking Hits"
# Song 51: "Lean And Molly"
# Song 52: "Lemme See It"
# Song 53: "Get Ya Money Right"
# Song 54: "Im Done With Yall"
# Song 55: "I Need a Freak"
# Song 56: "Driving Down the Freeway"
# Song 57: "Myself"
# Song 58: "Shooters"
# Song 59: "Project Niggas"
# Song 60: "Buss It Down"
# Song 61: "This Is Murder Not Music (Remix)"
# Song 62: "Push ’Em Back"
# Song 63: "Another Bird"
# Song 64: "Flex"
# Song 65: "Ten Toes Down"
# Song 66: "DPG Unit"
# Song 67: "Prepare for War"
# Song 68: "50 cent diss"
# Song 69: "Don’t Come Around"
# Song 70: "Boom"
# Song 71: "Too Rich"
# Song 72: "Turn Up On Dat"
# Song 73: "Run Off"
# Song 74: "Guns Go Bang"
# Song 75: "Amber Alert"
# Song 76: "Always Stay Strap’d"
# Song 77: "Smoke Our Life Away"
# Song 78: "Refill"
# Song 79: "Narcos"
# Song 80: "New York City"
# Song 81: "Haters"
# Song 82: "Money Good"
# Song 83: "Like I Love Her"
# Song 84: "No Place For Me"
# Song 85: "Move Around"
# Song 86: "No Pain"
# Song 87: "WTF"
# Song 88: "Geeked"
# Song 89: "Exclusive"
# Song 90: "Hoes And A Ounce"
# Song 91: "Lawd How Mercy"
# Song 92: "Up There"
# Song 93: "Out The Streets"
# Song 94: "Can’t Lose Ft. Twanee"
# Song 95: "Craccin And Poppin"
# Song 96: "Runnin That Check Up"
# Song 97: "Timeout"
# Song 98: "Clean Up Man"
# Song 99: "Push"
# Song 100: "Oh Boy Part 4"
# Song 101: "Oh Lord"
# Song 102: "I’m Taxin"
# Song 103: "Blood in Blood Out"
# Song 104: "Hos Hos"
# Song 105: "Skyscraper"
# Song 106: "Pocket Full of Paper"
# Song 107: "When the Rain Stops"
# Song 108: "Addicted"
# Song 109: "Bury The Bag"
# Song 110: "200 MPH"
# Song 111: "I’m Working"
# Song 112: "I’m Ready For War"
# Song 113: "Double Back"
# Song 114: "I’ll Whip Ya Head Boy"
# Song 115: "It’s Not OK"
# Song 116: "Dope 2 Ya"
# Song 117: "Can’t Keep Livin"
# Song 118: "Dead or Alive (Fuck the Police)"
# Song 119: "Man Down"
# Song 120: "Yasss Bitch Remix"
# Song 121: "Smoke"
# Song 122: "All Night"
# Song 123: "Road Trip"
# Song 124: "Happy New Year"
# Song 125: "Paperwork"
# Song 126: "Lose My Mind / 50 Cent - Funeral Music"
# Song 127: "Cant Catch Me"
# Song 128: "Ups and Downs (feat. Lil Wayne)"
# Song 129: "Check"
# Song 130: "Black Clouds"
# Song 131: "Terminate On Sight"
# Song 132: "All My Life"
# Song 133: "All About Money"
# Song 134: "I Want It All"
# Song 135: "The Get Back"
# Song 136: "Not Coming Home"
# Song 137: "Move"
# Song 138: "Your Hood"
# Song 139: "Hard Hitters"
# Song 140: "Where She At"
# Song 141: "Came Back"
# Song 142: "Kill Me a Nigga"
# Song 143: "Wit Dat Choppa"
# Song 144: "Caption This"
# Song 145: "Rage"
# Song 146: "Lord Have Mercy (Lawd How Mercy)"
# Song 147: "Separation"
# Song 148: "Keep It Moving"
# Song 149: "Sleep With An Ak"
# Song 150: "Where The Haters At?"
# Song 151: "I Shoot You Shoot"
# Song 152: "Money Talk"
# Song 153: "Reaching"
# Song 154: "Move On"
# Song 155: "I Ball Hard"
# Song 156: "You Can Get it Too"
# Song 157: "So Gone"
# Song 158: "Appreciate Me"
# Song 159: "Niggas a Change on You"
# Song 160: "Rollin’"
# Song 161: "Push da Line"
# Song 162: "Doin’ My Thing"
# Song 163: "Emoji Mad"
# Song 164: "Hood Love"
# Song 165: "Prices on My Head (feat. Lloyd Banks & D-Tay)"
# Song 166: "It’s Alright"
# Song 167: "Got 5 On It"
# Song 168: "Im A Soldier Ft. 50 Cent"
# Song 169: "Did You Miss Me"
# Song 170: "Died and Came Back"
# Song 171: "Roll Up"
# Song 172: "The City"
# Song 173: "This Shit Rough"
# Song 174: "Bonofide Hustler (feat. 50 Cent & Tony Yayo)"
# Song 175: "Club Sensations"
# Song 176: "Gettin High"
# Song 177: "Swag on Em"
# Song 178: "2nd Chance"
# Song 179: "Riot"
# Song 180: "Thug In The Club"
# Song 181: "I Don’t Want No Problems"
# Song 182: "Stick"
# Song 183: "Ride"
# Song 184: "Get Your Murder On"
# Song 185: "Walk With Me (feat. Stat Quo)"
# Song 186: "Streets Sour"
# Song 187: "They Pulling Me Back"
# Song 188: "Problems"
# Song 189: "Somebody"
# Song 190: "Slow Ya Roll [Explicit]"
# Song 191: "For The Low"
# Song 192: "Taxin’"
# Song 193: "War Witcha Homeboy"
# Song 194: "New Years Cake"
# Song 195: "Paycheck"
# Song 196: "Ghetto superstar"
# Song 197: "Nothing For You"
# Song 198: "Ya Betta Know It"
# Song 199: "Lights On"
# Song 200: "I Do"
# Song 201: "I Told Y’all"
# Song 202: "Don’t Make Me Hurt You!"
# Song 203: "Eviction Notice"
# Song 204: "My Campaign"
# Song 205: "Project Niggas (feat. Mobb Deep)"
# Song 206: "Switch It Up"
# "My Interview" is not valid. Skipping.
# Song 207: "No B.S."
# Song 208: "Penitentiary Pics"
# Song 209: "Look at Me Now (feat. Mr. Porter)"
# Song 210: "No Emotions"
# Song 211: "One More Night"
# Song 212: "Soundscan"
# Song 213: "G-Shit"
# Song 214: "Penny Pinchin"
# Song 215: "Pop a Pill (feat. D-Tay Lil’ Murder & Hi-C)"
# Song 216: "Down wit em"
# Song 217: "Crime Pays"
# Song 218: "Funeral Music"
# Song 219: "I Got It"
# Song 220: "Energy"
# Song 221: "Thugged Out"
# Song 222: "To All My Haters"
# Song 223: "Driving Down the Freeway (G-mix)"
# Song 224: "Rubberband Banks"
# Song 225: "Check Up"
# Song 226: "Shorty Wanna Ride (Texas Blend)"
# Song 227: "Get That Brick"
# Song 228: "Buy Your Dope From Me"
# Song 229: "I’ll Be Back"
# Song 230: "Married to My Gun"
# Song 231: "Shorty Wanna Ride (club mix)"
# Song 232: "Caught in the Wind"
# Song 233: "Taking Hits (feat. D-Tay)"
# Song 234: "Heavenly Father"
# Song 235: "Purse First"
# Song 236: "Return of Tha Project Nigga"
# Song 237: "No Direction"
# Song 238: "Stay the Same"
# Song 239: "Put Me In The Projects"
# Song 240: "Dickie Fits"
# Song 241: "Stomp That Snitch (feat. Hi-C & Lil Murda)"
# Song 242: "I Know You Want Me (PO clean edit)"
# Song 243: "Guns Go Bang (feat. MOP)"
# Song 244: "On The Corner"
# Song 245: "Push ’Em Back [Explicit]"
# Song 246: "Take Your Time"
# Song 247: "Out Here Grindin’"
# Song 248: "I see why"
# Song 249: "Come and Catch Me (feat. Lil’ Scrappy & Allstar)"
# Song 250: "The Blues"
# Song 251: "Shout Out to Pimp C & Project Pat!!"
# Song 252: "Can’t Slow My Roll"
# Song 253: "Started Out With Love"
# Song 254: "Pullin’ Me Back"
# Song 255: "Welcome to the South (feat. Lil’ Flip & David Banner)"
# Song 256: "Bury Me Alive"
# Song 257: "Postin Up (feat. Shannon Sanders)"
# Song 258: "Shit Remix"
# Song 259: "Move It Like I Do"
# Song 260: "Blood in Blood Out (feat. Rizin Sun)"
# Song 261: "Air Yeezys"
# Song 262: "Freak (Classic) (feat. DJ Drama)"
# "I Know You Want Me (instrumental)" is not valid. Skipping.
# Song 263: "Put It On Me"
# Song 264: "Penny Pinchin’ (feat. D-Tay)"
# Song 265: "The Projects (feat. Tony Yayo & Lil Murda)"
# Song 266: "Push ’Em Back [Clean]"
# Song 267: "Money in the Bank (feat. Lil’ Scrappy)"
# Song 268: "Live In Sumfest 2006 Jamaica"
# Song 269: "Hold U Down"
# Song 270: "High Than A Muthafucka"
# Song 271: "Clean Up Man [Explicit]"
# Song 272: "Cashville Solid"
# Song 273: "When The Rain Stops (Single)"
# Song 274: "Freestyle"
# Song 275: "Where Ya Money At"
# "Skit" is not valid. Skipping.
# Song 276: "Throwed off"
# Song 277: "All About Money (feat. D-Tay)"
# Song 278: "Slow Ya Roll [Clean]"
# Song 279: "Thug in the Club (feat. Bun B & Smoov Jizzel)"
# Song 280: "Hard Hitters (feat. D-Tay and Rizin Sun)"
# "Vibe Awards Skit" is not valid. Skipping.
# Song 281: "Get That Brick (feat. Hi-C)"
# Song 282: "There Will Be Blood"
# Song 283: "Move It Like I Do (feat. D-Tay & Hi-C)"
# Song 284: "Hold On (Alternate Version)"
# "Vibe Awards Skit 2" is not valid. Skipping.
# Song 285: "Live in Sumfest 2006 Jamaica (Weed Break) (feat. Marley Family & Bounty Killer)"
# Song 286: "G Shit - All Star"
# "Vibe Awards Skit 3" is not valid. Skipping.
# Song 287: "Nothing For You [Dupe]"
# Song 288: "Young Buck Speaks"
# Song 289: "TheFutureProducer@gmail.com"
# Song 290: "All Eyez on Me"
# Song 291: "Chevy Music"
# Song 292: "Where the Hoes At"
# Song 293: "Everybody Do It"
# Song 294: "Re Up"
# Song 295: "Money Rite"
# Song 296: "Turn Ya Back"
# Song 297: "Strip Club"
# Song 298: "Git It Back"
#   8%|▊         | 4/50 [31:06<6:53:06, 538.84s/it]
# Done. Found 298 songs.
# Wrote Stomp (Remix) to lyrics_youngbuck_stompremix.json.
# Wrote Get Buck to lyrics_youngbuck_getbuck.json.
# Wrote Shorty Wanna Ride to lyrics_youngbuck_shortywannaride.json.
# Wrote Let Me In to lyrics_youngbuck_letmein.json.
# Wrote Bonafide Hustler to lyrics_youngbuck_bonafidehustler.json.
# Wrote Bang Bang to lyrics_youngbuck_bangbang.json.
# Wrote Cocaine to lyrics_youngbuck_cocaine.json.
# Wrote Loco to lyrics_youngbuck_loco.json.
# Wrote Do It Like Me to lyrics_youngbuck_doitlikeme.json.
# Wrote Lose My Mind to lyrics_youngbuck_losemymind.json.
# Wrote U Ain’t Goin’ Nowhere to lyrics_youngbuck_uaintgoinnowhere.json.
# Song 9: "Big Daddy (Remix)"
# Song 10: "We Got Our Own Thang"
# Song 11: "Jam Session"
# Song 12: "This is Your Night"
# Song 13: "Peaceful Journey"
# Song 14: "Is it Good to You?"
# Song 15: "Queen Majesty"
# Song 16: "On Point"
# Song 17: "Sex Wit You"
# Song 18: "Chunky But Funky (Remix)"
# Song 19: "Keep it Comin"
# Song 20: "Moneyearnin’ Mount Vernon"
# Song 21: "You Can Get It"
# Song 22: "I Know You Love Me"
# Song 23: "More Bounce"
# Song 24: "Friends & Respect"
# Song 25: "Get Fresh Hev"
# Song 26: "Let It Rain"
# ...
# Song 117: "Keep it hype - dirty version"
# Song 118: "Civics"
# Song 119: "Respect my mind - dirty version"
# Song 120: "Sleepin’ With Me Featuring O’Dell"
#  32%|███▏      | 16/50 [3:27:43<6:45:37, 715.82s/it]
# Song 121: "Lookin’ For Me"
# Done. Found 121 songs.
# Wrote Shake Ya Ass to lyrics_mystikal_shakeyaass.json.
# Wrote Original to lyrics_mystikal_original.json.
# Wrote BET Cypher 2012: The Raw to lyrics_mystikal_betcypher2012theraw.json.
# Wrote Danger (Been So Long) to lyrics_mystikal_dangerbeensolong.json.
# Wrote Shake It Fast to lyrics_mystikal_shakeitfast.json.
# Wrote Here I Go to lyrics_mystikal_hereigo.json.
# Wrote I Smell Smoke to lyrics_mystikal_ismellsmoke.json.
# Wrote One night to lyrics_mystikal_onenight.json.
# Wrote Short Story to lyrics_mystikal_shortstory.json.
# Wrote Y’all Ain’t Ready Yet to lyrics_mystikal_yallaintreadyyet.json.
# Wrote Bouncin’ Back (Bumpin’ Me Against The Wall) to lyrics_mystikal_bouncinbackbumpinmeagainstthewall.json.
# Wrote Hit Me to lyrics_mystikal_hitme.json.
# Wrote The Man Right ’Chea to lyrics_mystikal_themanrightchea.json.
# Wrote Mamma Cry to lyrics_mystikal_mammacry.json.
# Wrote Tarantula to lyrics_mystikal_tarantula.json.
# Wrote Neck Uv Da Woods to lyrics_mystikal_neckuvdawoods.json.
# Wrote Pussy Crook to lyrics_mystikal_pussycrook.json.
# Wrote Murderer III to lyrics_mystikal_murdereriii.json.
# Wrote Still Smokin’ to lyrics_mystikal_stillsmokin.json.
# Wrote Round Out Tha Tank to lyrics_mystikal_roundoutthatank.json.
# Wrote Ghetto Child to lyrics_mystikal_ghettochild.json.
# Wrote Bullshit to lyrics_mystikal_bullshit.json.
# Wrote Here We Go to lyrics_mystikal_herewego.json.
# Wrote Not That Nigga to lyrics_mystikal_notthatnigga.json.
# Wrote Murderer to lyrics_mystikal_murderer.json.
# Wrote Smashing The Gas (Get Faster) to lyrics_mystikal_smashingthegasgetfaster.json.
# Wrote That’s the Nigga to lyrics_mystikal_thatsthenigga.json.
# Wrote Murderer 2 to lyrics_mystikal_murderer2.json.
# Wrote Ain’t No Limit to lyrics_mystikal_aintnolimit.json.
# Wrote If It Ain’t Live, It Ain’t Me to lyrics_mystikal_ifitaintliveitaintme.json.
# Wrote Unpredictable to lyrics_mystikal_unpredictable.json.
# Wrote Out That Boot Camp Clicc to lyrics_mystikal_outthatbootcampclicc.json.
# Wrote That Nigga Ain’t Shit! to lyrics_mystikal_thatniggaaintshit.json.
# Wrote Big Truck Driver to lyrics_mystikal_bigtruckdriver.json.
# Wrote I’m to lyrics_mystikal_im.json.
# Wrote Mystikal Fever to lyrics_mystikal_mystikalfever.json.
# Wrote Mind of Mystikal to lyrics_mystikal_mindofmystikal.json.
# Wrote Beware to lyrics_mystikal_beware.json.
# Wrote I’m On Fire to lyrics_mystikal_imonfire.json.
# Wrote Ghetto Fabulous to lyrics_mystikal_ghettofabulous.json.
# Wrote Ain’t Gonna See Tomorrow to lyrics_mystikal_aintgonnaseetomorrow.json.
# Wrote Born 2 Be A Soldier to lyrics_mystikal_born2beasoldier.json.
# Wrote Shake Somethin’ to lyrics_mystikal_shakesomethin.json.
# Wrote I’m Throwed Off (Bonus Track) to lyrics_mystikal_imthrowedoffbonustrack.json.
# Wrote Smoke One to lyrics_mystikal_smokeone.json.
# Wrote U Would If U Could to lyrics_mystikal_uwouldifucould.json.
# Wrote Go ’Head to lyrics_mystikal_gohead.json.
# Wrote Danger (Radio Edit) to lyrics_mystikal_dangerradioedit.json.
# Wrote There He Go to lyrics_mystikal_therehego.json.
# Wrote Settle the Score to lyrics_mystikal_settlethescore.json.
# Wrote 13 Years to lyrics_mystikal_13years.json.
# Wrote Shine to lyrics_mystikal_shine.json.
# Wrote Ooooh Yeah to lyrics_mystikal_oooohyeah.json.
# Wrote Jump to lyrics_mystikal_jump.json.
# Wrote Lookin’ For Me (Bonus Track) to lyrics_mystikal_lookinformebonustrack.json.
# Wrote Family to lyrics_mystikal_family.json.
# Wrote U Can’t Handle This to lyrics_mystikal_ucanthandlethis.json.
# Wrote Ready to Rumble to lyrics_mystikal_readytorumble.json.
# Wrote Shake It Fast - Cleaner Radio Edit to lyrics_mystikal_shakeitfastcleanerradioedit.json.
# Wrote Smoked Out to lyrics_mystikal_smokedout.json.
# Wrote The Braids to lyrics_mystikal_thebraids.json.
# Wrote Dedicated to Michelle Tyler to lyrics_mystikal_dedicatedtomichelletyler.json.
# Wrote Game [Triple H Theme] to lyrics_mystikal_gametriplehtheme.json.
# Wrote The Edge of the Blade to lyrics_mystikal_theedgeoftheblade.json.
# Wrote Mr. Hood Critic to lyrics_mystikal_mr.hoodcritic.json.
# Wrote Not That Nigga (Remix) to lyrics_mystikal_notthatniggaremix.json.
# Wrote Did I Do It to lyrics_mystikal_dididoit.json.
# Wrote Dick on the track to lyrics_mystikal_dickonthetrack.json.
# Wrote Life Ain’t Cool to lyrics_mystikal_lifeaintcool.json.
# Wrote We Got the Clout to lyrics_mystikal_wegottheclout.json.
# Wrote Stack Yo Chips to lyrics_mystikal_stackyochips.json.
# Wrote Come See About Me to lyrics_mystikal_comeseeaboutme.json.
# Wrote Big Truck Boys to lyrics_mystikal_bigtruckboys.json.
# Wrote Back from the River to lyrics_mystikal_backfromtheriver.json.
# Wrote Alright to lyrics_mystikal_alright.json.
# Wrote What’s Your Alias? to lyrics_mystikal_whatsyouralias.json.
# Wrote Keep it Hype to lyrics_mystikal_keepithype.json.
# Wrote That’s That Shit to lyrics_mystikal_thatsthatshit.json.
# Wrote Dirty South, Dirty Jerz to lyrics_mystikal_dirtysouthdirtyjerz.json.
# Wrote I Ain’t Playin to lyrics_mystikal_iaintplayin.json.
# Wrote Let’s Go Do It to lyrics_mystikal_letsgodoit.json.
# Wrote Respect My Mind to lyrics_mystikal_respectmymind.json.
# Wrote Here i go - dirty to lyrics_mystikal_hereigodirty.json.
# Wrote I Get it Started to lyrics_mystikal_igetitstarted.json.
# Wrote Smoke Something to lyrics_mystikal_smokesomething.json.
# Wrote I Rock, I Roll to lyrics_mystikal_irockiroll.json.
# Wrote What Cha Think to lyrics_mystikal_whatchathink.json.
# Wrote Whacha Want, Whacha Need to lyrics_mystikal_whachawantwhachaneed.json.
# Wrote Pussy Pop to lyrics_mystikal_pussypop.json.
# Wrote Sleepin’ With Me to lyrics_mystikal_sleepinwithme.json.
# Wrote Never Gonna Bounce (The Dream) to lyrics_mystikal_nevergonnabouncethedream.json.
# Wrote Robert Dinero to lyrics_mystikal_robertdinero.json.
# Wrote Y’all Ain’t Ready Yet (Remix) to lyrics_mystikal_yallaintreadyyetremix.json.
# Wrote I’m Throwed Off to lyrics_mystikal_imthrowedoff.json.
# Wrote The new guy to lyrics_mystikal_thenewguy.json.
# Wrote Yahh! to lyrics_mystikal_yahh.json.
# Wrote It Yearns to lyrics_mystikal_ityearns.json.
# Wrote Gangstas to lyrics_mystikal_gangstas.json.
# Wrote Mr. Shittalker to lyrics_mystikal_mr.shittalker.json.
# Wrote Who Rock This? to lyrics_mystikal_whorockthis.json.
# Wrote The Stick Up to lyrics_mystikal_thestickup.json.
# Wrote The Return to lyrics_mystikal_thereturn.json.
# Wrote That’s The Ni**a to lyrics_mystikal_thatsthenia.json.
# Wrote Gettin’ Aggressive (Mowo! Remix) to lyrics_mystikal_gettinaggressivemoworemix.json.
# Wrote Round out the tank - dirty version to lyrics_mystikal_roundoutthetankdirtyversion.json.
# Wrote Uh Oh to lyrics_mystikal_uhoh.json.
# Wrote Danger (Been So Long) - Dirty LP Version to lyrics_mystikal_dangerbeensolongdirtylpversion.json.
# Wrote Bouncin’ Back (Bumpin’ Me Against The Wall) - Extended Version to lyrics_mystikal_bouncinbackbumpinmeagainstthewallextendedversion.json.
# Wrote Murder 2 - dirty to lyrics_mystikal_murder2dirty.json.
# Wrote If it ain’t live, it ain’t me - clean album version to lyrics_mystikal_ifitaintliveitaintmecleanalbumversion.json.
# Wrote Keep Doin’ It to lyrics_mystikal_keepdoinit.json.
# Wrote I’m on fire - dirty version to lyrics_mystikal_imonfiredirtyversion.json.
# Wrote If it ain’t live, it ain’t me - dirty album version to lyrics_mystikal_ifitaintliveitaintmedirtyalbumversion.json.
# Wrote I’m Throwed Off (Hidden) to lyrics_mystikal_imthrowedoffhidden.json.
# Wrote Never Gonna Bounce to lyrics_mystikal_nevergonnabounce.json.
# Wrote Stack yo chips - dirty version to lyrics_mystikal_stackyochipsdirtyversion.json.
# Wrote Keep it hype - dirty version to lyrics_mystikal_keepithypedirtyversion.json.
# Wrote Civics to lyrics_mystikal_civics.json.
# Wrote Respect my mind - dirty version to lyrics_mystikal_respectmyminddirtyversion.json.
# Wrote Sleepin’ With Me Featuring O’Dell to lyrics_mystikal_sleepinwithmefeaturingodell.json.
# Wrote Lookin’ For Me to lyrics_mystikal_lookinforme.json.
# ----------Getting the # 167 artist----------
# Searching for songs by DJ Quik...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-cbd0e997524d> in <module>
#       3     time.sleep(0.5)
#       4     print('-'*10+'Getting the # '+ str(x+1)+' artist'+'-'*10)
# ----> 5     save_lyrics(artists_list[x],500)
#
# <ipython-input-6-15f565c8829c> in save_lyrics(artist, number_song)
#       1 #Function to find songs lyrics
#       2 def save_lyrics(artist,number_song):
# ----> 3     return search_song(artist,number_song).save_lyrics()
#
# <ipython-input-4-9ed02a29f5a8> in search_song(artist, number_song)
#       1 #building a search function to find a defined number of songs for an artist
#       2 def search_song(artist,number_song):
# ----> 3         results= api.search_artist(artist, max_songs=number_song)
#       4         return results
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id)
#     351                 lyrics = self._scrape_song_lyrics_from_url(song_info['url'])
#     352                 if get_full_info:
# --> 353                     info = self.get_song(song_info['id'])
#     354                 else:
#     355                     info = {'song': song_info}
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in get_song(self, id_)
#      69         """Data for a specific song."""
#      70         endpoint = "songs/{id}".format(id=id_)
# ---> 71         return self._make_request(endpoint)
#      72
#      73     def get_artist(self, id_):
#
# ~/anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in _make_request(self, path, method, params_)
#      58             response = self._session.request(method, uri,
#      59                                             timeout=self.timeout,
# ---> 60                                             params=params_)
#      61         except Timeout as e:
#      62             print("Timeout raised and caught:\n{e}".format(e=e))
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
