# %% [markdown]
# #### Helpers

# %%
import lyricsgenius as genius
from tqdm import tqdm
import time

# %%
#to be moved to get ignore
client_id = "Q53fYZR3PDQwVOePYcvxwg6VwWvcrNyc6x2vtbkmY17UxCDumQXdW231ZvMwDDLP"
api_key = "uQsB27xuJNJjdZaXzxQZSDe9nUsCmF1Wg5rse88OSO0KYROZbhaBrheo60vC3ZedPxuq1ajURIb1mKs7nEionw"
access_token = "GMDZNVgU2OcDjuRLzboZObyAhQH5j1ezWUX238sZe_vpvOtsEpIoT92WvupiYYAU"

# %%
#Authentification
api = genius.Genius(client_access_token=access_token)

# %% [markdown]
# ### Functions

# %%
#building a search function to find a defined number of songs for an artist
def search_song(artist,number_song):
        results= api.search_artist(artist, max_songs=number_song)
        return results

# %%
#Function to find songs titles
def find_song_title(results):
    return [results.songs]

# %%
#Function to find songs lyrics
def save_lyrics(artist,number_song):
    return search_song(artist,number_song).save_lyrics()

# %% [markdown]
# ### Getting songs from the artists list

# %%
# Load file with all artists
import pickle

with open('../hip-hop-artist.pkl', 'rb') as f:
    artists_list = pickle.load(f)

# %%
len(artists_list)
# Out:
# 1394

# %%
#Saving lyrics for 100 artists
for x in tqdm(range(8,100)):
    time.sleep(1)
    save_lyrics(artists_list[x],50)
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]
# Searching for songs by 21 Savage...
#
# Song 1: "Bank Account"
# Song 2: "​a lot"
# Song 3: "Red Opps"
# Song 4: "​ball w/o you"
# Song 5: "​can’t leave without it"
# Song 6: "​monster"
# Song 7: "Issa"
# Song 8: "Numb"
# Song 9: "​all my friends"
# Song 10: "​asmr"
# Song 11: "4L"
# Song 12: "Dip Dip"
# Song 13: "Famous"
# Song 14: "Nothin New"
# Song 15: "7 Min Freestyle"
# Song 16: "​a&t"
# Song 17: "All The Smoke"
# Song 18: "​out for the night"
# Song 19: "1.5"
# Song 20: "FaceTime"
# Song 21: "Special"
# Song 22: "​out for the night, pt. 2"
# Song 23: "Skrrt Skrrt"
# Song 24: "Whole Lot"
# Song 25: "​good day"
# Song 26: "​break da law"
# Song 27: "Baby Girl"
# Song 28: "Dead People"
# Song 29: "Thug Life"
# Song 30: "Dirty K"
# Song 31: "Close My Eyes"
# Song 32: "​gun smoke"
# Song 33: "​letter 2 my momma"
# Song 34: "Mind Yo Business"
# Song 35: "Bad Business"
# Song 36: "Immortal"
# Song 37: "Money Convo"
# Song 38: "​pad lock"
# Song 39: "Air It Out"
# Song 40: "Lord Forgive Me"
# Song 41: "Slaughter Ya Daughter"
# Song 42: "Motorcycle"
# Song 43: "21 Way (Freestyle)"
# Song 44: "Oh Ok"
# Song 45: "Gang"
# Song 46: "Wow"
# Song 47: "12 AM"
# Song 48: "Woah"
# Song 49: "Who Run It (Freestyle)"
#   1%|          | 1/92 [03:43<5:38:43, 223.34s/it]
# Song 50: "Drip"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Wrote Bank Account to lyrics_21savage_bankaccount.json.
# Wrote ​a lot to lyrics_21savage_alot.json.
# Wrote Red Opps to lyrics_21savage_redopps.json.
# Wrote ​ball w/o you to lyrics_21savage_ballwoyou.json.
# Wrote ​can’t leave without it to lyrics_21savage_cantleavewithoutit.json.
# Wrote ​monster to lyrics_21savage_monster.json.
# Wrote Issa to lyrics_21savage_issa.json.
# Wrote Numb to lyrics_21savage_numb.json.
# Wrote ​all my friends to lyrics_21savage_allmyfriends.json.
# Wrote ​asmr to lyrics_21savage_asmr.json.
# Wrote 4L to lyrics_21savage_4l.json.
# Wrote Dip Dip to lyrics_21savage_dipdip.json.
# Wrote Famous to lyrics_21savage_famous.json.
# Wrote Nothin New to lyrics_21savage_nothinnew.json.
# Wrote 7 Min Freestyle to lyrics_21savage_7minfreestyle.json.
# Wrote ​a&t to lyrics_21savage_at.json.
# Wrote All The Smoke to lyrics_21savage_allthesmoke.json.
# Wrote ​out for the night to lyrics_21savage_outforthenight.json.
# Wrote 1.5 to lyrics_21savage_1.5.json.
# Wrote FaceTime to lyrics_21savage_facetime.json.
# Wrote Special to lyrics_21savage_special.json.
# Wrote ​out for the night, pt. 2 to lyrics_21savage_outforthenightpt.2.json.
# Wrote Skrrt Skrrt to lyrics_21savage_skrrtskrrt.json.
# Wrote Whole Lot to lyrics_21savage_wholelot.json.
# Wrote ​good day to lyrics_21savage_goodday.json.
# Wrote ​break da law to lyrics_21savage_breakdalaw.json.
# Wrote Baby Girl to lyrics_21savage_babygirl.json.
# Wrote Dead People to lyrics_21savage_deadpeople.json.
# Wrote Thug Life to lyrics_21savage_thuglife.json.
# Wrote Dirty K to lyrics_21savage_dirtyk.json.
# Wrote Close My Eyes to lyrics_21savage_closemyeyes.json.
# Wrote ​gun smoke to lyrics_21savage_gunsmoke.json.
# Wrote ​letter 2 my momma to lyrics_21savage_letter2mymomma.json.
# Wrote Mind Yo Business to lyrics_21savage_mindyobusiness.json.
# Wrote Bad Business to lyrics_21savage_badbusiness.json.
# Wrote Immortal to lyrics_21savage_immortal.json.
# Wrote Money Convo to lyrics_21savage_moneyconvo.json.
# Wrote ​pad lock to lyrics_21savage_padlock.json.
# Wrote Air It Out to lyrics_21savage_airitout.json.
# Wrote Lord Forgive Me to lyrics_21savage_lordforgiveme.json.
# Wrote Slaughter Ya Daughter to lyrics_21savage_slaughteryadaughter.json.
# Wrote Motorcycle to lyrics_21savage_motorcycle.json.
# Wrote 21 Way (Freestyle) to lyrics_21savage_21wayfreestyle.json.
# Wrote Oh Ok to lyrics_21savage_ohok.json.
# Wrote Gang to lyrics_21savage_gang.json.
# Wrote Wow to lyrics_21savage_wow.json.
# Wrote 12 AM to lyrics_21savage_12am.json.
# Wrote Woah to lyrics_21savage_woah.json.
# Wrote Who Run It (Freestyle) to lyrics_21savage_whorunitfreestyle.json.
# Wrote Drip to lyrics_21savage_drip.json.
# Searching for songs by 2Mex...
#
# Song 1: "Doctors, Drums and Danger"
# Song 2: "Rollercoaster"
# Song 3: "Baby I Ain’t Joking"
# Song 4: "Shades of Orange"
# Song 5: "Only as Good as Goodbye"
# Song 6: "It Will"
# Song 7: "The Return of Fernando Mania"
# Song 8: "Alive-a-Cation"
# Song 9: "Falcon Gentle"
# Song 10: "Friday Rich"
# Song 11: "Treesun (Leave Her to Fall)"
# Song 12: "Obey"
# Song 13: "Outro"
#   2%|▏         | 2/92 [04:49<4:24:12, 176.14s/it]
# Done. Found 13 songs.
# Wrote Doctors, Drums and Danger to lyrics_2mex_doctorsdrumsanddanger.json.
# Wrote Rollercoaster to lyrics_2mex_rollercoaster.json.
# Wrote Baby I Ain’t Joking to lyrics_2mex_babyiaintjoking.json.
# Wrote Shades of Orange to lyrics_2mex_shadesoforange.json.
# Wrote Only as Good as Goodbye to lyrics_2mex_onlyasgoodasgoodbye.json.
# Wrote It Will to lyrics_2mex_itwill.json.
# Wrote The Return of Fernando Mania to lyrics_2mex_thereturnoffernandomania.json.
# Wrote Alive-a-Cation to lyrics_2mex_aliveacation.json.
# Wrote Falcon Gentle to lyrics_2mex_falcongentle.json.
# Wrote Friday Rich to lyrics_2mex_fridayrich.json.
# Wrote Treesun (Leave Her to Fall) to lyrics_2mex_treesunleavehertofall.json.
# Wrote Obey to lyrics_2mex_obey.json.
# Wrote Outro to lyrics_2mex_outro.json.
# Searching for songs by 360...
#
# Song 1: "Price of Fame"
# Song 2: "Died This Way"
# Song 3: "Sixavelli"
# Song 4: "I’m Sorry"
# Song 5: "Tiny Angel"
# Song 6: "Boys Like You"
# Song 7: "Coup De Grâce"
# Song 8: "My Favourite Downfall"
# Song 9: "Child"
# Song 10: "Yesterday"
# Song 11: "In Da Chub"
# Song 12: "Live It Up"
# Song 13: "Hope You Don’t Mind"
# Song 14: "Unborn Child"
# Song 15: "Dem Gainz"
# Song 16: "God Mode"
# Song 17: "Shutterbug"
# Song 18: "Run Alone"
# Song 19: "Way Out"
# Song 20: "Early Warning"
# Song 21: "Lights Out"
# Song 22: "White Lies"
# Song 23: "Drugs"
# Song 24: "Top Billin’ [Freestyle]"
# Song 25: "Just A Thought"
# Song 26: "Hectickest"
# Song 27: "Devil’s Advocate"
# Song 28: "Hammer Head"
# Song 29: "If You Love Them You Never Hit Them"
# Song 30: "Letters"
# Song 31: "So Fake"
# Song 32: "Still Rap"
# Song 33: "Real Friends"
# Song 34: "Trouble"
# Song 35: "Money"
# Song 36: "Eddie Jones"
# Song 37: "Closer"
# Song 38: "Spiral Down"
# Song 39: "By All Means"
# Song 40: "Must Come Down"
# Song 41: "Meant To Do"
# Song 42: "Witness"
# Song 43: "2 Dogs"
# Song 44: "Man On The Moon"
# Song 45: "Admission"
# Song 46: "Lemme Go"
# Song 47: "Floorless"
# Song 48: "Falling & Flying"
# Song 49: "You And I"
#   3%|▎         | 3/92 [07:05<4:03:32, 164.19s/it]
# Song 50: "Just Got Started"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Wrote Price of Fame to lyrics_360_priceoffame.json.
# Wrote Died This Way to lyrics_360_diedthisway.json.
# Wrote Sixavelli to lyrics_360_sixavelli.json.
# Wrote I’m Sorry to lyrics_360_imsorry.json.
# Wrote Tiny Angel to lyrics_360_tinyangel.json.
# Wrote Boys Like You to lyrics_360_boyslikeyou.json.
# Wrote Coup De Grâce to lyrics_360_coupdegrâce.json.
# Wrote My Favourite Downfall to lyrics_360_myfavouritedownfall.json.
# Wrote Child to lyrics_360_child.json.
# Wrote Yesterday to lyrics_360_yesterday.json.
# Wrote In Da Chub to lyrics_360_indachub.json.
# Wrote Live It Up to lyrics_360_liveitup.json.
# Wrote Hope You Don’t Mind to lyrics_360_hopeyoudontmind.json.
# Wrote Unborn Child to lyrics_360_unbornchild.json.
# Wrote Dem Gainz to lyrics_360_demgainz.json.
# Wrote God Mode to lyrics_360_godmode.json.
# Wrote Shutterbug to lyrics_360_shutterbug.json.
# Wrote Run Alone to lyrics_360_runalone.json.
# Wrote Way Out to lyrics_360_wayout.json.
# Wrote Early Warning to lyrics_360_earlywarning.json.
# Wrote Lights Out to lyrics_360_lightsout.json.
# Wrote White Lies to lyrics_360_whitelies.json.
# Wrote Drugs to lyrics_360_drugs.json.
# Wrote Top Billin’ [Freestyle] to lyrics_360_topbillinfreestyle.json.
# Wrote Just A Thought to lyrics_360_justathought.json.
# Wrote Hectickest to lyrics_360_hectickest.json.
# Wrote Devil’s Advocate to lyrics_360_devilsadvocate.json.
# Wrote Hammer Head to lyrics_360_hammerhead.json.
# Wrote If You Love Them You Never Hit Them to lyrics_360_ifyoulovethemyouneverhitthem.json.
# Wrote Letters to lyrics_360_letters.json.
# Wrote So Fake to lyrics_360_sofake.json.
# Wrote Still Rap to lyrics_360_stillrap.json.
# Wrote Real Friends to lyrics_360_realfriends.json.
# Wrote Trouble to lyrics_360_trouble.json.
# Wrote Money to lyrics_360_money.json.
# Wrote Eddie Jones to lyrics_360_eddiejones.json.
# Wrote Closer to lyrics_360_closer.json.
# Wrote Spiral Down to lyrics_360_spiraldown.json.
# Wrote By All Means to lyrics_360_byallmeans.json.
# Wrote Must Come Down to lyrics_360_mustcomedown.json.
# Wrote Meant To Do to lyrics_360_meanttodo.json.
# Wrote Witness to lyrics_360_witness.json.
# Wrote 2 Dogs to lyrics_360_2dogs.json.
# Wrote Man On The Moon to lyrics_360_manonthemoon.json.
# Wrote Admission to lyrics_360_admission.json.
# Wrote Lemme Go to lyrics_360_lemmego.json.
# Wrote Floorless to lyrics_360_floorless.json.
# Wrote Falling & Flying to lyrics_360_fallingflying.json.
# Wrote You And I to lyrics_360_youandi.json.
# Wrote Just Got Started to lyrics_360_justgotstarted.json.
# Searching for songs by 3rd Bass...
#
# Song 1: "The Gas Face"
# Song 2: "Pop Goes the Weasel"
# Song 3: "Steppin’ To The A.M."
# Song 4: "Sons of 3rd Bass"
# Song 5: "Wordz of Wizdom"
# Song 6: "Brooklyn-Queens"
# Song 7: "The Cactus"
# Song 8: "Product of the Environment"
# Song 9: "Flippin’ Off the Wall Like Lucy Ball"
# Song 10: "Triple Stage Darkness"
# Song 11: "Herbalz in Your Mouth"
# Song 12: "Kick Em in the Grill"
# Song 13: "Derelicts of Dialect"
# Song 14: "Ace in the Hole"
# Song 15: "Soul in the Hole"
# Song 16: "The Gas Face (Remix)"
# Song 17: "Product of the Environment (Remix)"
# Song 18: "Al’z A-B-Cee’z"
# Song 19: "Portrait of the Artist as a Hood"
# Song 20: "French Toast"
# Song 21: "Microphone Techniques"
# Song 22: "Oval Office"
# Song 23: "Monte Hall"
# Song 24: "Pop Goes the Weasel (Radio Edit)"
# Song 25: "Green Eggs and Swine"
# Song 26: "Word To The Third"
# Song 27: "No Master Plan No Master Race"
# Song 28: "3 Strikes 5000"
# Song 29: "Problem Child"
# Song 30: "Daddy Rich in the Land of 1210"
# Song 31: "No Static at All"
# Song 32: "Brooklyn-Queens (Remix)"
# Song 33: "Come In"
# Song 34: "Wordz Of Wizdom (II)"
# Song 35: "Eye Jammie"
# Song 36: "3rd Bass Theme aka Portrait of the Artist as a Hood Remix"
# Song 37: "M.C. Disagree"
# Song 38: "Russel Rush"
# Song 39: "Stymie’s Theme"
# Song 40: "Steppin’ to the A.M. (Remix)"
# Song 41: "Who’s On Third"
# Song 42: "The Merchant Of Grooves"
# Song 43: "Desert Boots"
# Song 44: "Hoods"
# Song 45: "The Cactus (Remix)"
# Song 46: "Jim Backus"
# Song 47: "Sea Vessel Soliloquy"
# Song 48: "Episode #3"
# Song 49: "M.C. Disagree And The Re-Animator"
#   4%|▍         | 4/92 [08:48<3:33:50, 145.81s/it]
# Song 50: "Derelicts Of Dialect (SD50 Remix)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Wrote The Gas Face to lyrics_3rdbass_thegasface.json.
# Wrote Pop Goes the Weasel to lyrics_3rdbass_popgoestheweasel.json.
# Wrote Steppin’ To The A.M. to lyrics_3rdbass_steppintothea.m..json.
# Wrote Sons of 3rd Bass to lyrics_3rdbass_sonsof3rdbass.json.
# Wrote Wordz of Wizdom to lyrics_3rdbass_wordzofwizdom.json.
# Wrote Brooklyn-Queens to lyrics_3rdbass_brooklynqueens.json.
# Wrote The Cactus to lyrics_3rdbass_thecactus.json.
# Wrote Product of the Environment to lyrics_3rdbass_productoftheenvironment.json.
# Wrote Flippin’ Off the Wall Like Lucy Ball to lyrics_3rdbass_flippinoffthewalllikelucyball.json.
# Wrote Triple Stage Darkness to lyrics_3rdbass_triplestagedarkness.json.
# Wrote Herbalz in Your Mouth to lyrics_3rdbass_herbalzinyourmouth.json.
# Wrote Kick Em in the Grill to lyrics_3rdbass_kickeminthegrill.json.
# Wrote Derelicts of Dialect to lyrics_3rdbass_derelictsofdialect.json.
# Wrote Ace in the Hole to lyrics_3rdbass_aceinthehole.json.
# Wrote Soul in the Hole to lyrics_3rdbass_soulinthehole.json.
# Wrote The Gas Face (Remix) to lyrics_3rdbass_thegasfaceremix.json.
# Wrote Product of the Environment (Remix) to lyrics_3rdbass_productoftheenvironmentremix.json.
# Wrote Al’z A-B-Cee’z to lyrics_3rdbass_alzabceez.json.
# Wrote Portrait of the Artist as a Hood to lyrics_3rdbass_portraitoftheartistasahood.json.
# Wrote French Toast to lyrics_3rdbass_frenchtoast.json.
# Wrote Microphone Techniques to lyrics_3rdbass_microphonetechniques.json.
# Wrote Oval Office to lyrics_3rdbass_ovaloffice.json.
# Wrote Monte Hall to lyrics_3rdbass_montehall.json.
# Wrote Pop Goes the Weasel (Radio Edit) to lyrics_3rdbass_popgoestheweaselradioedit.json.
# Wrote Green Eggs and Swine to lyrics_3rdbass_greeneggsandswine.json.
# Wrote Word To The Third to lyrics_3rdbass_wordtothethird.json.
# Wrote No Master Plan No Master Race to lyrics_3rdbass_nomasterplannomasterrace.json.
# Wrote 3 Strikes 5000 to lyrics_3rdbass_3strikes5000.json.
# Wrote Problem Child to lyrics_3rdbass_problemchild.json.
# Wrote Daddy Rich in the Land of 1210 to lyrics_3rdbass_daddyrichinthelandof1210.json.
# Wrote No Static at All to lyrics_3rdbass_nostaticatall.json.
# Wrote Brooklyn-Queens (Remix) to lyrics_3rdbass_brooklynqueensremix.json.
# Wrote Come In to lyrics_3rdbass_comein.json.
# Wrote Wordz Of Wizdom (II) to lyrics_3rdbass_wordzofwizdomii.json.
# Wrote Eye Jammie to lyrics_3rdbass_eyejammie.json.
# Wrote 3rd Bass Theme aka Portrait of the Artist as a Hood Remix to lyrics_3rdbass_3rdbassthemeakaportraitoftheartistasahoodremix.json.
# Wrote M.C. Disagree to lyrics_3rdbass_m.c.disagree.json.
# Wrote Russel Rush to lyrics_3rdbass_russelrush.json.
# Wrote Stymie’s Theme to lyrics_3rdbass_stymiestheme.json.
# Wrote Steppin’ to the A.M. (Remix) to lyrics_3rdbass_steppintothea.m.remix.json.
# Wrote Who’s On Third to lyrics_3rdbass_whosonthird.json.
# Wrote The Merchant Of Grooves to lyrics_3rdbass_themerchantofgrooves.json.
# Wrote Desert Boots to lyrics_3rdbass_desertboots.json.
# Wrote Hoods to lyrics_3rdbass_hoods.json.
# Wrote The Cactus (Remix) to lyrics_3rdbass_thecactusremix.json.
# Wrote Jim Backus to lyrics_3rdbass_jimbackus.json.
# Wrote Sea Vessel Soliloquy to lyrics_3rdbass_seavesselsoliloquy.json.
# Wrote Episode #3 to lyrics_3rdbass_episode3.json.
# Wrote M.C. Disagree And The Re-Animator to lyrics_3rdbass_m.c.disagreeandthereanimator.json.
# Wrote Derelicts Of Dialect (SD50 Remix) to lyrics_3rdbass_derelictsofdialectsd50remix.json.
# Searching for songs by 3X Krazy...
#
# Song 1: "Keep It On the Real"
# Song 2: "Immortalized"
# Song 3: "Stackin’ Chips"
# Song 4: "West Coast"
# Song 5: "Pistols Blazin"
# Song 6: "Sickkaluffa"
# Song 7: "Reactions"
# Song 8: "In The Name Of Rame"
# Song 9: "Thug Money"
# Song 10: "Sunshine in the O"
# Song 11: "Kaviealstars"
#   5%|▌         | 5/92 [09:19<2:41:18, 111.25s/it]
# Song 12: "The Sickness"
# Done. Found 12 songs.
# Wrote Keep It On the Real to lyrics_3xkrazy_keepitonthereal.json.
# Wrote Immortalized to lyrics_3xkrazy_immortalized.json.
# Wrote Stackin’ Chips to lyrics_3xkrazy_stackinchips.json.
# Wrote West Coast to lyrics_3xkrazy_westcoast.json.
# Wrote Pistols Blazin to lyrics_3xkrazy_pistolsblazin.json.
# Wrote Sickkaluffa to lyrics_3xkrazy_sickkaluffa.json.
# Wrote Reactions to lyrics_3xkrazy_reactions.json.
# Wrote In The Name Of Rame to lyrics_3xkrazy_inthenameoframe.json.
# Wrote Thug Money to lyrics_3xkrazy_thugmoney.json.
# Wrote Sunshine in the O to lyrics_3xkrazy_sunshineintheo.json.
# Wrote Kaviealstars to lyrics_3xkrazy_kaviealstars.json.
# Wrote The Sickness to lyrics_3xkrazy_thesickness.json.
# Searching for songs by 40 Glocc...
#
# Song 1: "We Just Came to Party"
# Song 2: "Welcome to California (Remix)"
# Song 3: "Where Them Hammers At"
# Song 4: "Leave Me Alone (Little Bitty Box)"
# Song 5: "Borrow You"
# Song 6: "Finer Thangz"
# Song 7: "You Know What It Is"
# Song 8: "Damn (Remix)"
# Song 9: "Came to party"
#   7%|▋         | 6/92 [09:51<2:05:34, 87.60s/it]
# Done. Found 9 songs.
# Wrote We Just Came to Party to lyrics_40glocc_wejustcametoparty.json.
# Wrote Welcome to California (Remix) to lyrics_40glocc_welcometocaliforniaremix.json.
# Wrote Where Them Hammers At to lyrics_40glocc_wherethemhammersat.json.
# Wrote Leave Me Alone (Little Bitty Box) to lyrics_40glocc_leavemealonelittlebittybox.json.
# Wrote Borrow You to lyrics_40glocc_borrowyou.json.
# Wrote Finer Thangz to lyrics_40glocc_finerthangz.json.
# Wrote You Know What It Is to lyrics_40glocc_youknowwhatitis.json.
# Wrote Damn (Remix) to lyrics_40glocc_damnremix.json.
# Wrote Came to party to lyrics_40glocc_cametoparty.json.
# Searching for songs by 50 Cent...
#
# Song 1: "In Da Club"
# Song 2: "21 Questions"
# Song 3: "Many Men (Wish Death)"
# Song 4: "My Life"
# Song 5: "Patiently Waiting"
# Song 6: "P.I.M.P."
# Song 7: "We Up"
# Song 8: "I’m the Man"
# Song 9: "Candy Shop"
# Song 10: "Best Friend"
# Song 11: "Wanksta"
# Song 12: "Ghetto Qu’ran (Forgive Me)"
# Song 13: "I’m the Man (Remix)"
# Song 14: "Hustler’s Ambition"
# Song 15: "Big Rich Town"
# Song 16: "Window Shopper"
# Song 17: "Heat"
# Song 18: "If I Can’t"
# Song 19: "Back Down"
# Song 20: "What Up Gangsta"
# Song 21: "No Romeo No Juliet"
# Song 22: "Don’t Push Me"
# Song 23: "Your Life’s on the Line"
# Song 24: "High All the Time"
# Song 25: "How to Rob"
# Song 26: "I’ll Whip Ya Head Boy"
# Song 27: "Ayo Technology"
# Song 28: "Just a Lil’ Bit"
# Song 29: "When it Rains it Pours"
# Song 30: "U Not Like Me"
# Song 31: "Major Distribution"
# Song 32: "Too Rich for the Bitch"
# Song 33: "I Get Money"
# Song 34: "Tryna Fuck Me Over"
# Song 35: "Piggy Bank"
# Song 36: "9 Shots"
# Song 37: "Places to Go"
